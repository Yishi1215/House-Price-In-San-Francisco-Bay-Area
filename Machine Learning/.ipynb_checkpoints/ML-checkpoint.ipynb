# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import Imputer, scale
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV
from sklearn.metrics import mean_squared_error, accuracy_score
import statsmodels.api as sm

# %% [markdown]
# # 1. Prepare regression functions

# %%
def split(var, res, t_size, r_state):
    X_train, X_test, y_train, y_test = train_test_split(var, res, test_size=t_size, random_state=r_state)
    return X_train, X_test, y_train, y_test

# %%
def linear_regression(X_train, X_test, y_train, y_test):
    reg = LinearRegression()
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print('Simple Linear Regression')
    print('R^2: {}'.format(reg.score(X_train, y_train)))
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error: {}'.format(rmse))
    return reg.coef_

# %%
def ridge(X_train, X_test, y_train, y_test, alpha):
    regr_cv = RidgeCV(alphas=alpha, normalize=True)
    ridge = regr_cv.fit(X_train, y_train)
    ridge_pred=ridge.predict(X_test)
    print('Ridge')
    print('R^2: {}'.format(ridge.score(X_train, y_train)))
    rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))
    print('Root Mean Squared Error: {}'.format(rmse))
    print('Alpha: {}'.format(ridge.alpha_))
    return ridge.coef_

# %%
def lasso(X_train, X_test, y_train, y_test, alpha):
    regr_cv = LassoCV(alphas=alpha, normalize=True)
    lasso = regr_cv.fit(X_train, y_train)
    lasso_pred=lasso.predict(X_test)
    print('Lasso')
    print('R^2: {}'.format(lasso.score(X_train, y_train)))
    rmse = np.sqrt(mean_squared_error(y_test, lasso_pred))
    print('Root Mean Squared Error: {}'.format(rmse))
    print('Alpha: {}'.format(lasso.alpha_))
    return lasso.coef_

# %% [markdown]
# # 2. Preprocessing the data

# %%
filename = 'Preprocessing Data/cleaned_data.csv'
df = pd.read_csv(filename, index_col=0)
df['ZIP'] = df['ZIP'].astype(str)

# %% [markdown]
# ## 2.1 Seperate property type

# %%
df_sfh = df.loc[df['PROPERTY TYPE'] == 'SFH']
df_th = df.loc[df['PROPERTY TYPE'] == 'TH']
df_condo = df.loc[df['PROPERTY TYPE'] == 'Condo']

df_sfh = df_sfh.drop(['PROPERTY TYPE'], axis=1)
df_th = df_th.drop(['PROPERTY TYPE'], axis=1)
df_condo = df_condo.drop(['PROPERTY TYPE'], axis=1)

# %%
df_condo.loc[df_condo.ZIP=='95148']
# Out:
#         ZIP  PRICE IN K  BEDS  BATHS  SQUARE FEET  YEAR BUILT  HOA/MONTH
# 1397  95148       372.0   2.0    1.0        841.0      1979.0      225.0

# %%
#delete some columns are not available for the specific property type
df_sfh = df_sfh.drop(['HOA/MONTH', 'COUNTY', 'CITY', 'LOT', 'HOA'], axis=1)
df_th = df_th.drop(['LOT SIZE', 'COUNTY', 'CITY', 'LOT', 'HOA'], axis=1)
df_condo = df_condo.drop(['LOT SIZE', 'COUNTY', 'CITY', 'LOT', 'HOA'], axis=1)

# %%
#encoding dummy variables
df_sfh_dummies = pd.get_dummies(df_sfh)
df_th_dummies = pd.get_dummies(df_th)
df_condo_dummies = pd.get_dummies(df_condo)
df_sfh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26790 entries, 0 to 32413
# Data columns (total 7 columns):
# ZIP            26790 non-null object
# PRICE IN K     26790 non-null float64
# BEDS           26790 non-null float64
# BATHS          26790 non-null float64
# SQUARE FEET    26790 non-null float64
# LOT SIZE       26790 non-null float64
# YEAR BUILT     26790 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 1.6+ MB

# %%
#split dataset into feature variables and results
df_sfh_y = df_sfh_dummies['PRICE IN K'].values.ravel() 
df_sfh_X = df_sfh_dummies.drop(['PRICE IN K'], axis=1)
sfh_col = df_sfh_X.columns

df_th_y = df_th_dummies['PRICE IN K'].values.ravel()
df_th_X = df_th_dummies.drop(['PRICE IN K'], axis=1)
th_col = df_th_X.columns

df_condo_y = df_condo_dummies['PRICE IN K'].values.ravel()
df_condo_X = df_condo_dummies.drop(['PRICE IN K'], axis=1)
condo_col = df_condo_X.columns

# %%
# scaling the data
df_sfh_X = scale(df_sfh_X)
df_th_X = scale(df_th_X)
df_condo_X = scale(df_condo_X)

# %% [markdown]
# ## 2.2 Use different location info but keep three property types together

# %% [markdown]
# 2.2.1 Using county as the only location info

# %%
df_county = df.drop(['CITY', 'ZIP'], axis=1)
df_county_dummies = pd.get_dummies(df_county)
#split dataset into feature variables and results
df_county_y = df_county_dummies['PRICE IN K']
df_county_X = df_county_dummies.drop(['PRICE IN K'], axis=1)
county_col = df_county_X.columns
# scaling the data
df_county_X = scale(df_county_X)

# %% [markdown]
# 2.2.2 Using city as the only location info

# %%
df_city = df.drop(['COUNTY', 'ZIP'], axis=1)
df_city_dummies = pd.get_dummies(df_city)
#split dataset into feature variables and results
df_city_y = df_city_dummies['PRICE IN K']
df_city_X = df_city_dummies.drop(['PRICE IN K'], axis=1)
city_col = df_city_X.columns
# scaling the data
df_city_X = scale(df_city_X)

# %% [markdown]
# 2.2.3 Using zip as the only location info

# %%
df_zip = df.drop(['COUNTY', 'CITY'], axis=1)
df_zip_dummies = pd.get_dummies(df_zip)
#split dataset into feature variables and results
df_zip_y = df_zip_dummies['PRICE IN K']
df_zip_X = df_zip_dummies.drop(['PRICE IN K'], axis=1)
zip_col = df_zip_X.columns
# scaling the data
df_zip_X = scale(df_zip_X)

# %% [markdown]
# ## 2.3 Keep all location info

# %%
df_dummies = pd.get_dummies(df)
df_y = df_dummies['PRICE IN K']
df_X = df_dummies.drop(['PRICE IN K'], axis=1)
df_col = df_X.columns
df_X = scale(df_X)

# %% [markdown]
# # 3. Regression

# %%
alpha = 10**np.linspace(10,-2,100)*0.5

# %% [markdown]
# ## 3.1 Based on different property type, no city or county, only zip is included for location

# %% [markdown]
# 3.1.1 Single family house

# %%
X_train, X_test, y_train, y_test = split(df_sfh_X, df_sfh_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":sfh_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7107405373123307
# Root Mean Squared Error: 635.1811327822406
#      Coefficients      Feature
# 0   -1.233617e+02         BEDS
# 1   -1.784841e+00        BATHS
# 2    8.719384e+02  SQUARE FEET
# 3    6.223245e+01     LOT SIZE
# 4   -9.086694e+01   YEAR BUILT
# 5    9.428849e+13    ZIP_94002
# 6    4.800715e+13    ZIP_94005
# 7    1.110637e+14    ZIP_94010
# 8    7.332316e+13    ZIP_94014
# 9    9.048697e+13    ZIP_94015
# 10   3.930803e+13    ZIP_94018
# 11   9.603295e+13    ZIP_94019
# 12   3.467810e+13    ZIP_94020
# 13   1.071330e+13    ZIP_94021
# 14   8.767865e+13    ZIP_94022
# 15   8.037470e+13    ZIP_94024
# 16   1.130100e+14    ZIP_94025
# 17   6.268983e+13    ZIP_94027
# 18   6.605229e+13    ZIP_94028
# 19   8.002594e+13    ZIP_94030
# 20   4.557474e+13    ZIP_94037
# 21   4.002709e+13    ZIP_94038
# 22   4.557474e+13    ZIP_94040
# 23   3.356167e+13    ZIP_94041
# 24   4.255854e+13    ZIP_94043
# 25   9.923806e+13    ZIP_94044
# 26   2.354291e+13    ZIP_94060
# 27   9.130138e+13    ZIP_94061
# 28   9.849405e+13    ZIP_94062
# 29   5.395085e+13    ZIP_94063
# 30   2.931821e+13    ZIP_94065
# 31   8.520859e+13    ZIP_94066
# 32   1.101588e+14    ZIP_94070
# 33   9.780042e+12    ZIP_94074
# 34   9.840062e+13    ZIP_94080
# 35   4.741095e+13    ZIP_94085
# 36   4.473404e+13    ZIP_94086
# 37   6.504795e+13    ZIP_94087
# 38   2.394493e+13    ZIP_94089
# 39   6.185788e+12    ZIP_94102
# 40   7.575871e+12    ZIP_94103
# 41   1.157147e+13    ZIP_94107
# 42   8.747699e+12    ZIP_94109
# 43   3.181297e+13    ZIP_94110
# 44   5.125242e+13    ZIP_94112
# 45   2.548942e+13    ZIP_94114
# 46   1.237019e+13    ZIP_94115
# 47   3.467810e+13    ZIP_94116
# 48   1.514920e+13    ZIP_94117
# 49   1.693637e+13    ZIP_94118
# 50   2.003714e+13    ZIP_94121
# 51   3.059122e+13    ZIP_94122
# 52   1.514920e+13    ZIP_94123
# 53   2.931821e+13    ZIP_94124
# 54   3.298915e+13    ZIP_94127
# 55   3.706621e+13    ZIP_94131
# 56   2.271743e+13    ZIP_94132
# 57   2.996152e+13    ZIP_94134
# 58   4.859591e+13    ZIP_94301
# 59   9.821348e+13    ZIP_94303
# 60   1.237019e+13    ZIP_94304
# 61   6.185788e+12    ZIP_94305
# 62   6.193390e+13    ZIP_94306
# 63   6.358471e+13    ZIP_94401
# 64   7.669038e+13    ZIP_94402
# 65   8.553506e+13    ZIP_94403
# 66   6.590978e+13    ZIP_94404
# 67   9.632039e+13    ZIP_94501
# 68   5.069512e+13    ZIP_94502
# 69   7.777891e+13    ZIP_94536
# 70   7.138073e+13    ZIP_94538
# 71   7.138073e+13    ZIP_94539
# 72   8.049060e+13    ZIP_94541
# 73   5.125242e+13    ZIP_94542
# 74   7.729711e+13    ZIP_94544
# 75   5.913010e+13    ZIP_94545
# 76   2.931821e+13    ZIP_94546
# 77   1.049848e+14    ZIP_94550
# 78   9.160479e+13    ZIP_94551
# 79   1.855182e+13    ZIP_94552
# 80   6.519240e+13    ZIP_94555
# 81   1.035807e+14    ZIP_94560
# 82   9.250863e+13    ZIP_94566
# 83   9.574458e+13    ZIP_94568
# 84   8.704146e+13    ZIP_94577
# 85   6.661916e+13    ZIP_94578
# 86   4.917748e+13    ZIP_94579
# 87   3.356167e+13    ZIP_94580
# 88   6.185788e+12    ZIP_94586
# 89   1.019758e+14    ZIP_94587
# 90   7.632392e+13    ZIP_94588
# 91   3.930803e+13    ZIP_94601
# 92   4.300258e+13    ZIP_94602
# 93   5.198600e+13    ZIP_94603
# 94   6.253940e+13    ZIP_94605
# 95   2.996152e+13    ZIP_94606
# 96   2.186067e+13    ZIP_94607
# 97   3.906536e+13    ZIP_94608
# 98   2.729683e+13    ZIP_94609
# 99   5.198600e+13    ZIP_94610
# 100  8.025863e+13    ZIP_94611
# 101  9.780042e+12    ZIP_94612
# 102  2.764406e+13    ZIP_94618
# 103  4.639996e+13    ZIP_94619
# 104  3.930803e+13    ZIP_94621
# 105  5.584506e+13    ZIP_94702
# 106  4.639996e+13    ZIP_94703
# 107  1.749148e+13    ZIP_94704
# 108  4.639996e+13    ZIP_94705
# 109  7.111756e+13    ZIP_94706
# 110  5.270915e+13    ZIP_94707
# 111  5.125242e+13    ZIP_94708
# 112  2.003714e+13    ZIP_94709
# 113  2.899116e+13    ZIP_94710
# 114  4.374094e+12    ZIP_94979
# 115  4.374094e+12    ZIP_94980
# 116  7.575871e+12    ZIP_95002
# 117  8.914659e+13    ZIP_95008
# 118  8.466149e+13    ZIP_95014
# 119  1.228145e+14    ZIP_95020
# 120  4.374094e+12    ZIP_95025
# 121  7.370524e+13    ZIP_95030
# 122  7.242345e+13    ZIP_95032
# 123  5.252932e+13    ZIP_95033
# 124  9.487381e+13    ZIP_95035
# 125  1.039336e+14    ZIP_95037
# 126  1.450452e+13    ZIP_95046
# 127  6.759935e+13    ZIP_95050
# 128  6.402731e+13    ZIP_95051
# 129  2.586107e+13    ZIP_95054
# 130  9.220841e+13    ZIP_95070
# 131  2.899116e+13    ZIP_95110
# 132  2.313387e+13    ZIP_95111
# 133  3.906536e+13    ZIP_95112
# 134  3.211109e+13    ZIP_95116
# 135  2.141940e+13    ZIP_95117
# 136  2.622742e+13    ZIP_95118
# 137  1.636239e+13    ZIP_95119
# 138  2.050828e+13    ZIP_95120
# 139  1.955461e+13    ZIP_95121
# 140  3.732202e+13    ZIP_95122
# 141  2.622742e+13    ZIP_95123
# 142  4.994218e+13    ZIP_95124
# 143  5.013149e+13    ZIP_95125
# 144  3.575937e+13    ZIP_95126
# 145  5.234885e+13    ZIP_95127
# 146  4.936979e+13    ZIP_95128
# 147  3.495159e+13    ZIP_95129
# 148  3.782841e+13    ZIP_95130
# 149  1.237019e+13    ZIP_95131
# 150  2.931821e+13    ZIP_95132
# 151  1.450452e+13    ZIP_95133
# 152  1.312032e+13    ZIP_95135
# 153  1.855182e+13    ZIP_95136
# 154  1.636239e+13    ZIP_95138
# 155  1.071330e+13    ZIP_95139
# 156  2.186067e+13    ZIP_95148
# 157  4.374094e+12    ZIP_95391

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":sfh_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7107016083096023
# Root Mean Squared Error: 634.4700482990442
# Alpha: 0.005
#      Coefficients      Feature
# 0     -119.932414         BEDS
# 1        9.080075        BATHS
# 2      856.247734  SQUARE FEET
# 3       62.661550     LOT SIZE
# 4      -89.922958   YEAR BUILT
# 5       29.535828    ZIP_94002
# 6      -21.025422    ZIP_94005
# 7      119.475792    ZIP_94010
# 8      -31.698351    ZIP_94014
# 9      -23.422644    ZIP_94015
# 10     -21.640423    ZIP_94018
# 11     -52.865100    ZIP_94019
# 12     -25.410860    ZIP_94020
# 13      -7.300918    ZIP_94021
# 14     167.073072    ZIP_94022
# 15     121.353910    ZIP_94024
# 16     134.106685    ZIP_94025
# 17     316.646199    ZIP_94027
# 18      84.914109    ZIP_94028
# 19      14.606943    ZIP_94030
# 20     -17.909046    ZIP_94037
# 21     -14.229805    ZIP_94038
# 22      54.119043    ZIP_94040
# 23      24.850119    ZIP_94041
# 24      36.075377    ZIP_94043
# 25     -26.640033    ZIP_94044
# 26      -7.004421    ZIP_94060
# 27      31.050077    ZIP_94061
# 28     117.646609    ZIP_94062
# 29      -4.092673    ZIP_94063
# 30      12.413165    ZIP_94065
# 31     -17.960430    ZIP_94066
# 32      48.082366    ZIP_94070
# 33      -7.192062    ZIP_94074
# 34     -31.091516    ZIP_94080
# 35      12.165693    ZIP_94085
# 36      22.687580    ZIP_94086
# 37      65.790169    ZIP_94087
# 38      21.776397    ZIP_94089
# 39       1.269903    ZIP_94102
# 40      -1.069522    ZIP_94103
# 41       5.932564    ZIP_94107
# 42      17.152463    ZIP_94109
# 43      10.954452    ZIP_94110
# 44     -15.225208    ZIP_94112
# 45      25.806296    ZIP_94114
# 46       8.188379    ZIP_94115
# 47       1.300751    ZIP_94116
# 48      12.337140    ZIP_94117
# 49      32.002926    ZIP_94118
# 50      -0.410394    ZIP_94121
# 51      -2.317041    ZIP_94122
# 52      52.921175    ZIP_94123
# 53     -15.998939    ZIP_94124
# 54       9.290193    ZIP_94127
# 55      29.872742    ZIP_94131
# 56      -0.802271    ZIP_94132
# 57      -7.816271    ZIP_94134
# 58     177.782935    ZIP_94301
# 59      40.809756    ZIP_94303
# 60      22.664812    ZIP_94304
# 61      -3.717188    ZIP_94305
# 62     117.655597    ZIP_94306
# 63      -2.046749    ZIP_94401
# 64      34.158839    ZIP_94402
# 65      20.541628    ZIP_94403
# 66      20.038224    ZIP_94404
# 67     -58.573961    ZIP_94501
# 68     -22.377212    ZIP_94502
# 69     -26.841024    ZIP_94536
# 70     -14.562869    ZIP_94538
# 71      -7.960719    ZIP_94539
# 72     -64.969835    ZIP_94541
# 73     -81.097740    ZIP_94542
# 74     -52.220060    ZIP_94544
# 75     -40.613855    ZIP_94545
# 76     -26.283898    ZIP_94546
# 77     -94.212669    ZIP_94550
# 78     -60.295629    ZIP_94551
# 79     -20.048528    ZIP_94552
# 80     -24.809117    ZIP_94555
# 81     -50.606836    ZIP_94560
# 82     -78.944427    ZIP_94566
# 83     -79.432220    ZIP_94568
# 84     -73.682428    ZIP_94577
# 85     -47.297671    ZIP_94578
# 86     -32.422169    ZIP_94579
# 87     -18.003214    ZIP_94580
# 88      -5.488063    ZIP_94586
# 89     -68.313297    ZIP_94587
# 90     -44.738136    ZIP_94588
# 91     -34.290656    ZIP_94601
# 92     -22.922131    ZIP_94602
# 93     -41.287897    ZIP_94603
# 94     -52.307398    ZIP_94605
# 95     -26.026220    ZIP_94606
# 96     -18.100500    ZIP_94607
# 97     -23.594182    ZIP_94608
# 98     -12.092261    ZIP_94609
# 99     -15.316484    ZIP_94610
# 100    -27.036155    ZIP_94611
# 101     -6.513281    ZIP_94612
# 102     -7.598317    ZIP_94618
# 103    -31.321921    ZIP_94619
# 104    -34.068801    ZIP_94621
# 105    -14.833701    ZIP_94702
# 106    -21.358862    ZIP_94703
# 107     -6.923573    ZIP_94704
# 108    -26.557697    ZIP_94705
# 109    -17.106004    ZIP_94706
# 110    -21.057090    ZIP_94707
# 111    -29.388316    ZIP_94708
# 112    -14.940255    ZIP_94709
# 113     -2.739627    ZIP_94710
# 114     -3.082698    ZIP_94979
# 115     -3.036791    ZIP_94980
# 116     -1.080509    ZIP_95002
# 117      4.956715    ZIP_95008
# 118     66.817464    ZIP_95014
# 119   -115.688868    ZIP_95020
# 120     10.085783    ZIP_95025
# 121     33.515128    ZIP_95030
# 122     22.082482    ZIP_95032
# 123    -33.168653    ZIP_95033
# 124    -27.177507    ZIP_95035
# 125    -81.767005    ZIP_95037
# 126    -14.019144    ZIP_95046
# 127     -0.542428    ZIP_95050
# 128     27.498818    ZIP_95051
# 129     -0.981032    ZIP_95054
# 130     69.940720    ZIP_95070
# 131    -13.157589    ZIP_95110
# 132     -7.925391    ZIP_95111
# 133    -21.356522    ZIP_95112
# 134    -17.717612    ZIP_95116
# 135     -0.758077    ZIP_95117
# 136      3.042928    ZIP_95118
# 137     -2.891256    ZIP_95119
# 138     -0.667172    ZIP_95120
# 139     -8.359160    ZIP_95121
# 140    -13.382700    ZIP_95122
# 141     -3.283264    ZIP_95123
# 142      7.679873    ZIP_95124
# 143     -0.609398    ZIP_95125
# 144     -8.628227    ZIP_95126
# 145    -26.669946    ZIP_95127
# 146     -7.556471    ZIP_95128
# 147     27.184975    ZIP_95129
# 148     13.247868    ZIP_95130
# 149      4.361845    ZIP_95131
# 150     -3.322900    ZIP_95132
# 151    -10.135719    ZIP_95133
# 152     -4.895326    ZIP_95135
# 153     -4.784046    ZIP_95136
# 154     -4.077589    ZIP_95138
# 155     -1.955999    ZIP_95139
# 156    -10.221470    ZIP_95148
# 157     -2.111297    ZIP_95391

# %%
def coef_df(coefficients):
    other_coef = coefficients[:5]
    other_coef = other_coef.sort_values(by=['Coefficients'], ascending = False)
    zip_coef = coefficients[5:]
    zip_coef = zip_coef.sort_values(by=['Coefficients'], ascending = False)
    coef = pd.concat([other_coef, zip_coef])
    return coef

# %%
coef_df(coefficients)
coef_df(coefficients).to_csv('Coef results/sfh_ridge_coef.csv')

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":sfh_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7106659003436058
# Root Mean Squared Error: 634.8508099403866
# Alpha: 0.006609705742330144
#      Coefficients      Feature
# 0     -121.319300         BEDS
# 1        0.000000        BATHS
# 2      869.364880  SQUARE FEET
# 3       61.176652     LOT SIZE
# 4      -90.509318   YEAR BUILT
# 5       53.442352    ZIP_94002
# 6       -7.573918    ZIP_94005
# 7      147.313398    ZIP_94010
# 8      -11.610079    ZIP_94014
# 9        0.000000    ZIP_94015
# 10     -10.422977    ZIP_94018
# 11     -27.220202    ZIP_94019
# 12     -15.502542    ZIP_94020
# 13      -3.591074    ZIP_94021
# 14     189.273834    ZIP_94022
# 15     141.609337    ZIP_94024
# 16     163.352991    ZIP_94025
# 17     332.136469    ZIP_94027
# 18     101.153558    ZIP_94028
# 19      34.594917    ZIP_94030
# 20      -5.094361    ZIP_94037
# 21      -2.895654    ZIP_94038
# 22      65.329562    ZIP_94040
# 23      32.734106    ZIP_94041
# 24      46.541700    ZIP_94043
# 25      -0.000000    ZIP_94044
# 26      -0.000000    ZIP_94060
# 27      54.314672    ZIP_94061
# 28     142.232938    ZIP_94062
# 29       9.072123    ZIP_94063
# 30      19.245466    ZIP_94065
# 31       3.632138    ZIP_94066
# 32      76.122601    ZIP_94070
# 33      -3.781596    ZIP_94074
# 34      -4.290912    ZIP_94080
# 35      23.670365    ZIP_94085
# 36      33.555600    ZIP_94086
# 37      82.323449    ZIP_94087
# 38      27.415140    ZIP_94089
# 39       2.021788    ZIP_94102
# 40       0.000000    ZIP_94103
# 41       8.057864    ZIP_94107
# 42      18.197172    ZIP_94109
# 43      18.509152    ZIP_94110
# 44      -0.932287    ZIP_94112
# 45      31.605001    ZIP_94114
# 46      10.498034    ZIP_94115
# 47       9.437819    ZIP_94116
# 48      15.128266    ZIP_94117
# 49      35.543110    ZIP_94118
# 50       3.790129    ZIP_94121
# 51       4.695662    ZIP_94122
# 52      56.066709    ZIP_94123
# 53      -7.413442    ZIP_94124
# 54      16.962026    ZIP_94127
# 55      38.791184    ZIP_94131
# 56       4.227923    ZIP_94132
# 57       0.000000    ZIP_94134
# 58     190.234360    ZIP_94301
# 59      65.862544    ZIP_94303
# 60      25.090758    ZIP_94304
# 61      -1.380391    ZIP_94305
# 62     133.536610    ZIP_94306
# 63      13.593711    ZIP_94401
# 64      53.301940    ZIP_94402
# 65      42.233959    ZIP_94403
# 66      36.459062    ZIP_94404
# 67     -32.897339    ZIP_94501
# 68      -8.164046    ZIP_94502
# 69      -5.312322    ZIP_94536
# 70       3.570663    ZIP_94538
# 71       9.839607    ZIP_94539
# 72     -43.171179    ZIP_94541
# 73     -67.388566    ZIP_94542
# 74     -31.011969    ZIP_94544
# 75     -24.043819    ZIP_94545
# 76     -17.815356    ZIP_94546
# 77     -66.126035    ZIP_94550
# 78     -35.311184    ZIP_94551
# 79     -14.343527    ZIP_94552
# 80      -6.614844    ZIP_94555
# 81     -22.284555    ZIP_94560
# 82     -54.499386    ZIP_94566
# 83     -53.515704    ZIP_94568
# 84     -50.472788    ZIP_94577
# 85     -29.078104    ZIP_94578
# 86     -18.592654    ZIP_94579
# 87      -8.300518    ZIP_94580
# 88      -2.993045    ZIP_94586
# 89     -40.620007    ZIP_94587
# 90     -23.911777    ZIP_94588
# 91     -23.285900    ZIP_94601
# 92     -10.926150    ZIP_94602
# 93     -26.949441    ZIP_94603
# 94     -35.270584    ZIP_94605
# 95     -17.367167    ZIP_94606
# 96     -11.366220    ZIP_94607
# 97     -12.564215    ZIP_94608
# 98      -4.034750    ZIP_94609
# 99      -1.135505    ZIP_94610
# 100     -5.735055    ZIP_94611
# 101     -3.134266    ZIP_94612
# 102     -0.000000    ZIP_94618
# 103    -18.369553    ZIP_94619
# 104    -22.920827    ZIP_94621
# 105     -0.000000    ZIP_94702
# 106     -8.469297    ZIP_94703
# 107     -1.503232    ZIP_94704
# 108    -13.796200    ZIP_94705
# 109      0.443087    ZIP_94706
# 110     -6.654605    ZIP_94707
# 111    -15.262286    ZIP_94708
# 112     -8.950461    ZIP_94709
# 113      3.945916    ZIP_94710
# 114     -1.124614    ZIP_94979
# 115     -0.978661    ZIP_94980
# 116      0.049202    ZIP_95002
# 117     27.488741    ZIP_95008
# 118     88.427132    ZIP_95014
# 119    -83.084741    ZIP_95020
# 120     10.396189    ZIP_95025
# 121     51.474727    ZIP_95030
# 122     40.082033    ZIP_95032
# 123    -18.627622    ZIP_95033
# 124     -1.045816    ZIP_95035
# 125    -54.017668    ZIP_95037
# 126     -9.328893    ZIP_95046
# 127     16.140255    ZIP_95050
# 128     43.654370    ZIP_95051
# 129      4.990409    ZIP_95054
# 130     93.126561    ZIP_95070
# 131     -4.773503    ZIP_95110
# 132     -0.812748    ZIP_95111
# 133    -10.439175    ZIP_95112
# 134     -8.493495    ZIP_95116
# 135      3.935884    ZIP_95117
# 136      9.093121    ZIP_95118
# 137      0.445650    ZIP_95119
# 138      3.725076    ZIP_95120
# 139     -2.305925    ZIP_95121
# 140     -2.611504    ZIP_95122
# 141      2.721490    ZIP_95123
# 142     19.937740    ZIP_95124
# 143     11.322705    ZIP_95125
# 144      0.000000    ZIP_95126
# 145    -12.267241    ZIP_95127
# 146      4.301335    ZIP_95128
# 147     35.693521    ZIP_95129
# 148     22.423830    ZIP_95130
# 149      6.763910    ZIP_95131
# 150      3.483160    ZIP_95132
# 151     -5.398044    ZIP_95133
# 152     -0.431951    ZIP_95135
# 153      0.000000    ZIP_95136
# 154      0.000000    ZIP_95138
# 155      0.019543    ZIP_95139
# 156     -3.547482    ZIP_95148
# 157     -0.085007    ZIP_95391

# %% [markdown]
# 3.1.2 Townhouse

# %%
X_train, X_test, y_train, y_test = split(df_th_X, df_th_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":th_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.8460596238597562
# Root Mean Squared Error: 571077151924571.6
#      Coefficients      Feature
# 0    1.330961e+01         BEDS
# 1    5.425633e+01        BATHS
# 2    1.341800e+02  SQUARE FEET
# 3    3.583562e+01   YEAR BUILT
# 4    8.911092e+00    HOA/MONTH
# 5    3.349869e+14    ZIP_94002
# 6    2.094262e+14    ZIP_94005
# 7    3.615787e+14    ZIP_94010
# 8    2.238351e+14    ZIP_94014
# 9    3.862781e+14    ZIP_94015
# 10   4.241258e+14    ZIP_94019
# 11   2.957010e+14    ZIP_94022
# 12   1.770780e+14    ZIP_94024
# 13   6.481681e+14    ZIP_94025
# 14   3.615787e+14    ZIP_94040
# 15   1.939351e+14    ZIP_94041
# 16   7.207349e+14    ZIP_94043
# 17   5.805831e+14    ZIP_94044
# 18   4.094277e+14    ZIP_94061
# 19   3.111060e+14    ZIP_94062
# 20   2.094262e+14    ZIP_94063
# 21   3.700028e+14    ZIP_94065
# 22   3.782318e+14    ZIP_94070
# 23   3.862781e+14    ZIP_94080
# 24   2.622905e+14    ZIP_94085
# 25   4.168449e+14    ZIP_94086
# 26   5.147863e+14    ZIP_94087
# 27   1.584194e+14    ZIP_94089
# 28   1.865231e+14    ZIP_94102
# 29   7.926373e+13    ZIP_94111
# 30   7.926373e+13    ZIP_94124
# 31   7.926373e+13    ZIP_94131
# 32   7.926373e+13    ZIP_94133
# 33   1.120704e+14    ZIP_94134
# 34   2.238351e+14    ZIP_94301
# 35   2.373589e+14    ZIP_94303
# 36   2.622905e+14    ZIP_94306
# 37   3.060097e+14    ZIP_94401
# 38   3.349869e+14    ZIP_94402
# 39   3.700028e+14    ZIP_94403
# 40   9.373591e+14    ZIP_94404
# 41   4.452160e+14    ZIP_94501
# 42   7.085538e+14    ZIP_94502
# 43   5.487655e+14    ZIP_94536
# 44   5.263781e+14    ZIP_94538
# 45   4.452160e+14    ZIP_94539
# 46   5.857009e+14    ZIP_94541
# 47   2.957010e+14    ZIP_94544
# 48   3.529456e+14    ZIP_94545
# 49   2.373589e+14    ZIP_94550
# 50   5.701945e+14    ZIP_94551
# 51   1.584194e+14    ZIP_94552
# 52   2.957010e+14    ZIP_94555
# 53   5.957904e+14    ZIP_94560
# 54   4.968487e+14    ZIP_94566
# 55   3.349869e+14    ZIP_94568
# 56   3.256233e+14    ZIP_94577
# 57   2.501412e+14    ZIP_94578
# 58   1.120704e+14    ZIP_94579
# 59   7.926373e+13    ZIP_94586
# 60   7.596854e+14    ZIP_94587
# 61   6.919213e+14    ZIP_94588
# 62   7.926373e+13    ZIP_94603
# 63   2.957010e+14    ZIP_94605
# 64   7.926373e+13    ZIP_94606
# 65   2.094262e+14    ZIP_94608
# 66   1.584194e+14    ZIP_94618
# 67   1.372265e+14    ZIP_94619
# 68   1.120704e+14    ZIP_94703
# 69   7.926373e+13    ZIP_94706
# 70   1.120704e+14    ZIP_94709
# 71   6.105771e+14    ZIP_95008
# 72   7.405144e+14    ZIP_95014
# 73   3.440876e+14    ZIP_95020
# 74   3.349869e+14    ZIP_95030
# 75   6.343663e+14    ZIP_95032
# 76   7.482532e+14    ZIP_95035
# 77   6.105771e+14    ZIP_95037
# 78   2.622905e+14    ZIP_95050
# 79   2.622905e+14    ZIP_95051
# 80   3.349869e+14    ZIP_95054
# 81   4.452160e+14    ZIP_95070
# 82   7.926373e+13    ZIP_95110
# 83   2.501412e+14    ZIP_95111
# 84   1.120704e+14    ZIP_95112
# 85   1.372265e+14    ZIP_95116
# 86   2.738910e+14    ZIP_95117
# 87   1.770780e+14    ZIP_95118
# 88   7.926373e+13    ZIP_95119
# 89   1.120704e+14    ZIP_95120
# 90   2.094262e+14    ZIP_95121
# 91   2.094262e+14    ZIP_95122
# 92   2.738910e+14    ZIP_95123
# 93   1.120704e+14    ZIP_95124
# 94   2.238351e+14    ZIP_95125
# 95   1.770780e+14    ZIP_95126
# 96   2.094262e+14    ZIP_95127
# 97   7.926373e+13    ZIP_95128
# 98   2.738910e+14    ZIP_95129
# 99   1.120704e+14    ZIP_95130
# 100  2.094262e+14    ZIP_95131
# 101  4.452160e+14    ZIP_95132
# 102  1.584194e+14    ZIP_95133
# 103  1.939351e+14    ZIP_95134
# 104  1.584194e+14    ZIP_95136
# 105  7.926373e+13    ZIP_95138
# 106  1.939351e+14    ZIP_95139
# 107  1.372265e+14    ZIP_95148

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":th_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.8460431758761433
# Root Mean Squared Error: 141001.67967930826
# Alpha: 0.01155064850041579
#      Coefficients      Feature
# 0       14.600450         BEDS
# 1       54.425817        BATHS
# 2      131.734608  SQUARE FEET
# 3       36.334099   YEAR BUILT
# 4       10.658488    HOA/MONTH
# 5       11.045973    ZIP_94002
# 6       -8.271434    ZIP_94005
# 7       20.578974    ZIP_94010
# 8       -3.012672    ZIP_94014
# 9      -19.221647    ZIP_94015
# 10     -14.482672    ZIP_94019
# 11      63.597879    ZIP_94022
# 12      21.981987    ZIP_94024
# 13     118.666802    ZIP_94025
# 14      45.591873    ZIP_94040
# 15      26.733932    ZIP_94041
# 16      62.860959    ZIP_94043
# 17     -16.703942    ZIP_94044
# 18      11.158658    ZIP_94061
# 19  -44599.931977    ZIP_94062
# 20      12.068056    ZIP_94063
# 21      32.690307    ZIP_94065
# 22      16.558174    ZIP_94070
# 23     -11.997863    ZIP_94080
# 24      11.090467    ZIP_94085
# 25      24.057883    ZIP_94086
# 26      35.231463    ZIP_94087
# 27       7.623887    ZIP_94089
# 28  -44599.931977    ZIP_94102
# 29      -1.233163    ZIP_94111
# 30      -5.537004    ZIP_94124
# 31       0.221408    ZIP_94131
# 32      38.016145    ZIP_94133
# 33     -22.571914    ZIP_94134
# 34      54.849416    ZIP_94301
# 35      34.492421    ZIP_94303
# 36      51.784817    ZIP_94306
# 37       3.027277    ZIP_94401
# 38      17.925191    ZIP_94402
# 39      31.012271    ZIP_94403
# 40      56.781678    ZIP_94404
# 41     -19.359309    ZIP_94501
# 42     -45.128836    ZIP_94502
# 43     -21.232818    ZIP_94536
# 44     -20.880928    ZIP_94538
# 45       1.237923    ZIP_94539
# 46     -67.220835    ZIP_94541
# 47     -31.794667    ZIP_94544
# 48     -28.808984    ZIP_94545
# 49     -23.771248    ZIP_94550
# 50     -55.557217    ZIP_94551
# 51      -8.879612    ZIP_94552
# 52     -10.406058    ZIP_94555
# 53     -46.176449    ZIP_94560
# 54     -24.635953    ZIP_94566
# 55     -24.754274    ZIP_94568
# 56     -33.401078    ZIP_94577
# 57     -22.806772    ZIP_94578
# 58     -10.327001    ZIP_94579
# 59      -5.876976    ZIP_94586
# 60     -52.962948    ZIP_94587
# 61     -42.158550    ZIP_94588
# 62      -9.821878    ZIP_94603
# 63     -36.157254    ZIP_94605
# 64      -8.473998    ZIP_94606
# 65     -10.141508    ZIP_94608
# 66      -6.230886    ZIP_94618
# 67     -11.995043    ZIP_94619
# 68       4.045407    ZIP_94703
# 69      -0.660617    ZIP_94706
# 70      10.804213    ZIP_94709
# 71      -6.573484    ZIP_95008
# 72      71.889214    ZIP_95014
# 73     -33.625661    ZIP_95020
# 74      19.133016    ZIP_95030
# 75      26.119607    ZIP_95032
# 76     -29.661696    ZIP_95035
# 77     -54.530383    ZIP_95037
# 78       5.358305    ZIP_95050
# 79      23.131047    ZIP_95051
# 80      17.177380    ZIP_95054
# 81      43.803176    ZIP_95070
# 82       0.352685    ZIP_95110
# 83     -13.086664    ZIP_95111
# 84      -0.879653    ZIP_95112
# 85      -9.237291    ZIP_95116
# 86       5.416130    ZIP_95117
# 87      -2.745192    ZIP_95118
# 88      -3.220744    ZIP_95119
# 89       1.480896    ZIP_95120
# 90     -10.162700    ZIP_95121
# 91     -11.252479    ZIP_95122
# 92      -9.767822    ZIP_95123
# 93      -1.737298    ZIP_95124
# 94       1.012469    ZIP_95125
# 95      -2.220834    ZIP_95126
# 96      -7.791471    ZIP_95127
# 97       2.231275    ZIP_95128
# 98      33.679035    ZIP_95129
# 99      -5.537972    ZIP_95130
# 100     -3.929850    ZIP_95131
# 101    -14.019793    ZIP_95132
# 102     -3.959434    ZIP_95133
# 103     -3.809951    ZIP_95134
# 104    -10.431295    ZIP_95136
# 105     -5.469659    ZIP_95138
# 106     -8.424376    ZIP_95139
# 107     -8.512105    ZIP_95148

# %%
coef_df(coefficients)
coef_df(coefficients).to_csv('Coef results/th_ridge_coef.csv')

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":th_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.845664953990548
# Root Mean Squared Error: 163.42760530068205
# Alpha: 0.020185086292982747
#      Coefficients      Feature
# 0       10.804771         BEDS
# 1       54.468769        BATHS
# 2      136.789477  SQUARE FEET
# 3       34.572114   YEAR BUILT
# 4        9.218730    HOA/MONTH
# 5       19.964231    ZIP_94002
# 6       -1.731916    ZIP_94005
# 7       30.202591    ZIP_94010
# 8        2.649123    ZIP_94014
# 9       -7.597881    ZIP_94015
# 10      -1.685519    ZIP_94019
# 11      71.709356    ZIP_94022
# 12      26.551763    ZIP_94024
# 13     136.721746    ZIP_94025
# 14      55.448413    ZIP_94040
# 15      31.662113    ZIP_94041
# 16      83.622678    ZIP_94043
# 17      -0.000000    ZIP_94044
# 18      21.783856    ZIP_94061
# 19       0.000000    ZIP_94062
# 20      17.555115    ZIP_94063
# 21      42.758217    ZIP_94065
# 22      25.970025    ZIP_94070
# 23      -0.183900    ZIP_94080
# 24      17.975302    ZIP_94085
# 25      35.480155    ZIP_94086
# 26      49.677182    ZIP_94087
# 27      11.397339    ZIP_94089
# 28       0.000000    ZIP_94102
# 29       0.127371    ZIP_94111
# 30      -2.587568    ZIP_94124
# 31       1.497499    ZIP_94131
# 32      39.408849    ZIP_94133
# 33     -18.411153    ZIP_94134
# 34      60.944853    ZIP_94301
# 35      40.959034    ZIP_94303
# 36      58.897586    ZIP_94306
# 37      10.861278    ZIP_94401
# 38      26.624789    ZIP_94402
# 39      41.020117    ZIP_94403
# 40      83.213207    ZIP_94404
# 41      -6.231358    ZIP_94501
# 42     -24.757126    ZIP_94502
# 43      -4.683103    ZIP_94536
# 44      -5.081581    ZIP_94538
# 45      13.203440    ZIP_94539
# 46     -50.230466    ZIP_94541
# 47     -22.812495    ZIP_94544
# 48     -17.945759    ZIP_94545
# 49     -16.396703    ZIP_94550
# 50     -38.706827    ZIP_94551
# 51      -3.576328    ZIP_94552
# 52      -1.110484    ZIP_94555
# 53     -28.610991    ZIP_94560
# 54      -9.873185    ZIP_94566
# 55     -14.608475    ZIP_94568
# 56     -23.821342    ZIP_94577
# 57     -15.103036    ZIP_94578
# 58      -6.143396    ZIP_94579
# 59      -2.825633    ZIP_94586
# 60     -30.506725    ZIP_94587
# 61     -22.112666    ZIP_94588
# 62      -6.823708    ZIP_94603
# 63     -27.369540    ZIP_94605
# 64      -5.523133    ZIP_94606
# 65      -3.556976    ZIP_94608
# 66      -1.393377    ZIP_94618
# 67      -7.432583    ZIP_94619
# 68       6.497046    ZIP_94703
# 69       0.785256    ZIP_94706
# 70      12.933913    ZIP_94709
# 71       9.963223    ZIP_95008
# 72      92.867315    ZIP_95014
# 73     -23.475117    ZIP_95020
# 74      27.790718    ZIP_95030
# 75      43.680627    ZIP_95032
# 76      -7.295720    ZIP_95035
# 77     -37.054683    ZIP_95037
# 78      11.937185    ZIP_95050
# 79      30.076467    ZIP_95051
# 80      26.017319    ZIP_95054
# 81      55.859051    ZIP_95070
# 82       1.815134    ZIP_95110
# 83      -4.787472    ZIP_95111
# 84       1.529214    ZIP_95112
# 85      -4.578318    ZIP_95116
# 86      12.158280    ZIP_95117
# 87       1.502751    ZIP_95118
# 88      -0.245073    ZIP_95119
# 89       3.354729    ZIP_95120
# 90      -3.108913    ZIP_95121
# 91      -4.266604    ZIP_95122
# 92      -1.173051    ZIP_95123
# 93       0.761346    ZIP_95124
# 94       6.814861    ZIP_95125
# 95       1.989404    ZIP_95126
# 96      -1.037855    ZIP_95127
# 97       3.849189    ZIP_95128
# 98      41.235333    ZIP_95129
# 99      -1.558389    ZIP_95130
# 100      1.271054    ZIP_95131
# 101     -0.342541    ZIP_95132
# 102      0.000000    ZIP_95133
# 103      0.692413    ZIP_95134
# 104     -5.210333    ZIP_95136
# 105     -2.428810    ZIP_95138
# 106     -1.998822    ZIP_95139
# 107     -3.916506    ZIP_95148

# %% [markdown]
# 3.1.3 Condo

# %%
X_train, X_test, y_train, y_test = split(df_condo_X, df_condo_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":condo_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.8496948460291343
# Root Mean Squared Error: 3644034738581744.0
#      Coefficients      Feature
# 0    1.036645e+01         BEDS
# 1    3.884442e+01        BATHS
# 2    1.446641e+02  SQUARE FEET
# 3    2.052097e+01   YEAR BUILT
# 4    6.677334e+00    HOA/MONTH
# 5   -1.935417e+14    ZIP_94002
# 6   -3.000973e+14    ZIP_94005
# 7   -4.665498e+14    ZIP_94010
# 8   -2.788029e+14    ZIP_94014
# 9   -3.561724e+14    ZIP_94015
# 10  -2.842811e+14    ZIP_94019
# 11  -4.792161e+14    ZIP_94022
# 12  -1.118766e+14    ZIP_94024
# 13  -3.340035e+14    ZIP_94025
# 14  -3.604347e+14    ZIP_94030
# 15  -5.921934e+14    ZIP_94040
# 16  -1.581218e+14    ZIP_94041
# 17  -6.346895e+14    ZIP_94043
# 18  -2.014141e+14    ZIP_94044
# 19  -2.788029e+14    ZIP_94061
# 20  -1.369789e+14    ZIP_94062
# 21  -1.479318e+14    ZIP_94063
# 22  -2.233473e+14    ZIP_94065
# 23  -4.331141e+14    ZIP_94066
# 24  -4.567979e+14    ZIP_94070
# 25  -4.665498e+14    ZIP_94080
# 26  -3.688039e+14    ZIP_94085
# 27  -4.116412e+14    ZIP_94086
# 28  -2.732115e+14    ZIP_94087
# 29  -5.596365e+13    ZIP_94089
# 30  -5.596365e+13    ZIP_94102
# 31  -1.544241e+14    ZIP_94105
# 32  -9.690263e+13    ZIP_94107
# 33  -5.596365e+13    ZIP_94109
# 34   4.219143e+13    ZIP_94110
# 35  -1.701949e+15    ZIP_94115
# 36  -5.596365e+13    ZIP_94117
# 37  -5.596365e+13    ZIP_94121
# 38  -5.596365e+13    ZIP_94122
# 39  -7.913261e+13    ZIP_94131
# 40  -1.250630e+14    ZIP_94134
# 41  -2.788029e+14    ZIP_94301
# 42  -3.688039e+14    ZIP_94303
# 43  -7.913261e+13    ZIP_94305
# 44  -3.646446e+14    ZIP_94306
# 45  -6.115071e+14    ZIP_94401
# 46  -3.561724e+14    ZIP_94402
# 47  -3.561724e+14    ZIP_94403
# 48  -5.591574e+14    ZIP_94404
# 49  -5.797427e+14    ZIP_94501
# 50  -1.250630e+14    ZIP_94502
# 51  -2.732115e+14    ZIP_94536
# 52  -2.162879e+14    ZIP_94538
# 53  -1.767321e+14    ZIP_94539
# 54  -2.432763e+14    ZIP_94541
# 55  -7.913261e+13    ZIP_94542
# 56  -2.014141e+14    ZIP_94544
# 57  -1.250630e+14    ZIP_94545
# 58  -1.581218e+14    ZIP_94546
# 59  -1.479318e+14    ZIP_94550
# 60  -1.250630e+14    ZIP_94551
# 61  -1.767321e+14    ZIP_94555
# 62  -3.729143e+14    ZIP_94560
# 63  -1.581218e+14    ZIP_94566
# 64  -2.556824e+14    ZIP_94568
# 65  -2.842811e+14    ZIP_94577
# 66  -1.676881e+14    ZIP_94578
# 67  -9.690263e+13    ZIP_94579
# 68  -3.293822e+14    ZIP_94587
# 69  -1.581218e+14    ZIP_94588
# 70  -1.118766e+14    ZIP_94601
# 71  -7.913261e+13    ZIP_94602
# 72  -7.913261e+13    ZIP_94605
# 73  -7.913261e+13    ZIP_94606
# 74  -1.118766e+14    ZIP_94607
# 75  -4.116412e+14    ZIP_94608
# 76  -7.913261e+13    ZIP_94609
# 77  -1.767321e+14    ZIP_94610
# 78  -1.581218e+14    ZIP_94611
# 79  -5.596365e+13    ZIP_94612
# 80  -7.913261e+13    ZIP_94618
# 81  -9.690263e+13    ZIP_94619
# 82  -1.250630e+14    ZIP_94702
# 83  -7.913261e+13    ZIP_94703
# 84  -1.479318e+14    ZIP_94704
# 85  -1.581218e+14    ZIP_94705
# 86  -2.368237e+14    ZIP_94706
# 87  -7.913261e+13    ZIP_94707
# 88  -5.596365e+13    ZIP_94708
# 89  -1.369789e+14    ZIP_94709
# 90  -1.118766e+14    ZIP_94710
# 91  -5.485338e+14    ZIP_95008
# 92  -4.600735e+14    ZIP_95014
# 93  -3.101785e+14    ZIP_95020
# 94  -1.767321e+14    ZIP_95030
# 95  -3.430513e+14    ZIP_95032
# 96  -7.008477e+14    ZIP_95035
# 97  -3.688039e+14    ZIP_95037
# 98  -5.005390e+14    ZIP_95050
# 99  -5.721224e+14    ZIP_95051
# 100 -3.729143e+14    ZIP_95054
# 101 -4.225241e+14    ZIP_95070
# 102 -3.809946e+14    ZIP_95110
# 103 -3.101785e+14    ZIP_95111
# 104 -3.101785e+14    ZIP_95112
# 105 -1.369789e+14    ZIP_95113
# 106 -2.842811e+14    ZIP_95116
# 107 -2.301862e+14    ZIP_95117
# 108 -2.732115e+14    ZIP_95118
# 109 -5.596365e+13    ZIP_95119
# 110 -1.369789e+14    ZIP_95121
# 111 -2.432763e+14    ZIP_95122
# 112 -6.278405e+14    ZIP_95123
# 113 -3.051810e+14    ZIP_95124
# 114 -2.495584e+14    ZIP_95125
# 115 -2.432763e+14    ZIP_95126
# 116 -1.935417e+14    ZIP_95127
# 117 -3.246921e+14    ZIP_95128
# 118 -3.101785e+14    ZIP_95129
# 119 -1.853301e+14    ZIP_95131
# 120 -2.301862e+14    ZIP_95132
# 121 -2.556824e+14    ZIP_95133
# 122 -1.581218e+14    ZIP_95134
# 123 -2.432763e+14    ZIP_95135
# 124 -1.935417e+14    ZIP_95136
# 125 -7.913261e+13    ZIP_95138
# 126 -9.692623e+12    ZIP_95148

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":condo_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.8496215978131213
# Root Mean Squared Error: 760143.627684709
# Alpha: 0.020185086292982747
#       Coefficients      Feature
# 0        13.832355         BEDS
# 1        40.741630        BATHS
# 2       137.109573  SQUARE FEET
# 3        19.527121   YEAR BUILT
# 4         8.555912    HOA/MONTH
# 5         4.752227    ZIP_94002
# 6       -13.918438    ZIP_94005
# 7        20.209264    ZIP_94010
# 8        -7.136609    ZIP_94014
# 9        -9.822517    ZIP_94015
# 10       -7.091406    ZIP_94019
# 11       87.195582    ZIP_94022
# 12       12.396733    ZIP_94024
# 13       34.049178    ZIP_94025
# 14       18.327655    ZIP_94030
# 15       29.287463    ZIP_94040
# 16       21.866163    ZIP_94041
# 17       28.568439    ZIP_94043
# 18       -7.248851    ZIP_94044
# 19       -0.661913    ZIP_94061
# 20       -5.412824    ZIP_94062
# 21        8.896197    ZIP_94063
# 22       14.820429    ZIP_94065
# 23       -3.397499    ZIP_94066
# 24       16.231758    ZIP_94070
# 25      -10.512185    ZIP_94080
# 26        6.969426    ZIP_94085
# 27        6.728614    ZIP_94086
# 28       12.151522    ZIP_94087
# 29        3.865688    ZIP_94089
# 30        4.318182    ZIP_94102
# 31        0.000000    ZIP_94105
# 32        5.345078    ZIP_94107
# 33        3.717562    ZIP_94109
# 34        0.000000    ZIP_94110
# 35     1878.111045    ZIP_94115
# 36        7.360117    ZIP_94117
# 37        3.676829    ZIP_94121
# 38       -1.547074    ZIP_94122
# 39        7.299312    ZIP_94131
# 40       -1.710699    ZIP_94134
# 41       63.973477    ZIP_94301
# 42       12.911698    ZIP_94303
# 43        2.244093    ZIP_94305
# 44       47.268802    ZIP_94306
# 45        7.143206    ZIP_94401
# 46       30.415231    ZIP_94402
# 47        9.773106    ZIP_94403
# 48       11.619201    ZIP_94404
# 49      -23.917262    ZIP_94501
# 50       -7.846974    ZIP_94502
# 51      -13.782361    ZIP_94536
# 52       -9.739334    ZIP_94538
# 53       -5.095675    ZIP_94539
# 54      -28.833229    ZIP_94541
# 55       -9.640794    ZIP_94542
# 56      -20.207391    ZIP_94544
# 57      -11.689132    ZIP_94545
# 58      -15.289521    ZIP_94546
# 59      -13.577635    ZIP_94550
# 60      -12.832543    ZIP_94551
# 61       -5.938294    ZIP_94555
# 62      -34.505380    ZIP_94560
# 63      -11.995022    ZIP_94566
# 64      -23.474041    ZIP_94568
# 65      -31.345367    ZIP_94577
# 66      -15.467692    ZIP_94578
# 67       -9.982894    ZIP_94579
# 68      -20.418309    ZIP_94587
# 69       -6.666579    ZIP_94588
# 70      -10.987333    ZIP_94601
# 71       -1.105588    ZIP_94602
# 72       -4.118953    ZIP_94605
# 73       -0.953835    ZIP_94606
# 74       -1.930621    ZIP_94607
# 75      -11.067230    ZIP_94608
# 76       -3.164624    ZIP_94609
# 77       -4.632314    ZIP_94610
# 78        1.642377    ZIP_94611
# 79       -6.550242    ZIP_94612
# 80        2.955788    ZIP_94618
# 81       -7.082526    ZIP_94619
# 82        4.072302    ZIP_94702
# 83       -4.777362    ZIP_94703
# 84        4.076234    ZIP_94704
# 85       10.191323    ZIP_94705
# 86      -15.141031    ZIP_94706
# 87        0.129421    ZIP_94707
# 88        1.243646    ZIP_94708
# 89        4.786356    ZIP_94709
# 90       -2.673814    ZIP_94710
# 91      -10.024235    ZIP_95008
# 92       33.754707    ZIP_95014
# 93      -33.307697    ZIP_95020
# 94        7.322999    ZIP_95030
# 95       -3.875119    ZIP_95032
# 96      -34.490470    ZIP_95035
# 97      -31.566858    ZIP_95037
# 98       -9.173390    ZIP_95050
# 99       -8.428983    ZIP_95051
# 100       2.839511    ZIP_95054
# 101      14.480025    ZIP_95070
# 102      -9.979972    ZIP_95110
# 103     -18.126714    ZIP_95111
# 104      -9.952876    ZIP_95112
# 105      -4.243248    ZIP_95113
# 106     -15.162416    ZIP_95116
# 107      -4.740476    ZIP_95117
# 108      -8.727111    ZIP_95118
# 109      -1.259281    ZIP_95119
# 110      -6.789822    ZIP_95121
# 111     -11.510140    ZIP_95122
# 112     -26.408494    ZIP_95123
# 113      -6.918021    ZIP_95124
# 114      -1.451060    ZIP_95125
# 115      -2.318078    ZIP_95126
# 116     -10.297874    ZIP_95127
# 117       3.249436    ZIP_95128
# 118       0.072641    ZIP_95129
# 119      -1.348929    ZIP_95131
# 120      -4.131233    ZIP_95132
# 121     -11.152476    ZIP_95133
# 122      -0.795919    ZIP_95134
# 123     -12.667576    ZIP_95135
# 124      -7.348479    ZIP_95136
# 125      -4.515979    ZIP_95138
# 126  339938.099084    ZIP_95148

# %%
coef_df(coefficients)
coef_df(coefficients).to_csv('Coef results/condo_ridge_coef.csv')

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":condo_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.8485672614942809
# Root Mean Squared Error: 144.0289072351488
# Alpha: 0.020185086292982747
#      Coefficients      Feature
# 0        6.728324         BEDS
# 1       38.439442        BATHS
# 2      146.945118  SQUARE FEET
# 3       15.727651   YEAR BUILT
# 4        7.443958    HOA/MONTH
# 5        6.966574    ZIP_94002
# 6       -7.766122    ZIP_94005
# 7       27.154104    ZIP_94010
# 8       -1.240450    ZIP_94014
# 9       -2.978768    ZIP_94015
# 10      -0.974181    ZIP_94019
# 11      95.335704    ZIP_94022
# 12      13.347716    ZIP_94024
# 13      38.921431    ZIP_94025
# 14      23.852957    ZIP_94030
# 15      38.233910    ZIP_94040
# 16      23.926205    ZIP_94041
# 17      38.750200    ZIP_94043
# 18      -2.915584    ZIP_94044
# 19       3.009959    ZIP_94061
# 20      -3.368535    ZIP_94062
# 21      10.803870    ZIP_94063
# 22      17.935319    ZIP_94065
# 23       2.449094    ZIP_94066
# 24      23.221181    ZIP_94070
# 25      -1.246833    ZIP_94080
# 26      12.680858    ZIP_94085
# 27      13.136105    ZIP_94086
# 28      16.247800    ZIP_94087
# 29       4.142555    ZIP_94089
# 30       4.577824    ZIP_94102
# 31      -0.000000    ZIP_94105
# 32       6.223581    ZIP_94107
# 33       3.488719    ZIP_94109
# 34      -0.000000    ZIP_94110
# 35       0.000000    ZIP_94115
# 36       7.117387    ZIP_94117
# 37       3.899029    ZIP_94121
# 38      -0.104479    ZIP_94122
# 39       7.684483    ZIP_94131
# 40       0.000000    ZIP_94134
# 41      68.915890    ZIP_94301
# 42      18.773588    ZIP_94303
# 43       2.564583    ZIP_94305
# 44      53.181692    ZIP_94306
# 45      15.896894    ZIP_94401
# 46      34.814722    ZIP_94402
# 47      15.033725    ZIP_94403
# 48      19.755062    ZIP_94404
# 49     -14.093247    ZIP_94501
# 50      -5.086093    ZIP_94502
# 51      -8.258658    ZIP_94536
# 52      -5.063818    ZIP_94538
# 53      -1.095355    ZIP_94539
# 54     -23.712360    ZIP_94541
# 55      -7.511327    ZIP_94542
# 56     -16.107006    ZIP_94544
# 57      -8.598267    ZIP_94545
# 58     -11.763424    ZIP_94546
# 59     -10.319481    ZIP_94550
# 60      -9.989929    ZIP_94551
# 61      -1.709346    ZIP_94555
# 62     -26.921485    ZIP_94560
# 63      -8.255652    ZIP_94566
# 64     -18.452179    ZIP_94568
# 65     -26.183795    ZIP_94577
# 66     -11.707240    ZIP_94578
# 67      -7.236264    ZIP_94579
# 68     -13.443108    ZIP_94587
# 69      -2.865916    ZIP_94588
# 70      -7.971814    ZIP_94601
# 71       0.000000    ZIP_94602
# 72      -2.290519    ZIP_94605
# 73       0.000000    ZIP_94606
# 74       0.000000    ZIP_94607
# 75      -3.434542    ZIP_94608
# 76      -0.842809    ZIP_94609
# 77      -1.463349    ZIP_94610
# 78       2.984980    ZIP_94611
# 79      -5.010667    ZIP_94612
# 80       3.425934    ZIP_94618
# 81      -4.418411    ZIP_94619
# 82       5.164964    ZIP_94702
# 83      -2.692510    ZIP_94703
# 84       5.726987    ZIP_94704
# 85      11.299332    ZIP_94705
# 86     -10.529920    ZIP_94706
# 87       0.494758    ZIP_94707
# 88       1.048751    ZIP_94708
# 89       5.548157    ZIP_94709
# 90      -0.160729    ZIP_94710
# 91      -0.000000    ZIP_95008
# 92      41.368558    ZIP_95014
# 93     -27.630624    ZIP_95020
# 94       8.871094    ZIP_95030
# 95       0.690221    ZIP_95032
# 96     -20.796315    ZIP_95035
# 97     -24.959766    ZIP_95037
# 98      -0.000000    ZIP_95050
# 99       0.186225    ZIP_95051
# 100      8.362438    ZIP_95054
# 101     20.614045    ZIP_95070
# 102     -2.434128    ZIP_95110
# 103    -11.903448    ZIP_95111
# 104     -3.779323    ZIP_95112
# 105     -0.828400    ZIP_95113
# 106     -9.200208    ZIP_95116
# 107     -0.000000    ZIP_95117
# 108     -3.066006    ZIP_95118
# 109     -0.000000    ZIP_95119
# 110     -3.010084    ZIP_95121
# 111     -6.484482    ZIP_95122
# 112    -14.936585    ZIP_95123
# 113     -0.706557    ZIP_95124
# 114      1.816656    ZIP_95125
# 115      0.795220    ZIP_95126
# 116     -6.077112    ZIP_95127
# 117      8.105867    ZIP_95128
# 118      4.123802    ZIP_95129
# 119      0.658557    ZIP_95131
# 120     -0.000000    ZIP_95132
# 121     -5.856465    ZIP_95133
# 122      0.677204    ZIP_95134
# 123     -7.973963    ZIP_95135
# 124     -3.094114    ZIP_95136
# 125     -2.348747    ZIP_95138
# 126     -0.000000    ZIP_95148

# %% [markdown]
# ##  3.2 Use different location info but keep three property types together

# %% [markdown]
# 3.2.1 Using county as the only location info

# %%
X_train, X_test, y_train, y_test = split(df_county_X, df_county_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":county_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.5851520349151621
# Root Mean Squared Error: 765.0968022095226
#     Coefficients               Feature
# 0  -1.765056e+02                  BEDS
# 1   1.060228e+02                 BATHS
# 2   9.600034e+02           SQUARE FEET
# 3   4.802615e+01              LOT SIZE
# 4  -1.851334e+02            YEAR BUILT
# 5  -2.059250e+01             HOA/MONTH
# 6   3.910678e+10                   LOT
# 7  -1.112986e+02                   HOA
# 8  -6.128437e+13   PROPERTY TYPE_Condo
# 9  -7.600896e+13     PROPERTY TYPE_SFH
# 10 -5.091506e+13      PROPERTY TYPE_TH
# 11  1.098049e+14        COUNTY_ALAMEDA
# 12  3.380108e+13  COUNTY_SAN FRANCISCO
# 13  1.090363e+14      COUNTY_SAN MATEO
# 14  1.087984e+14    COUNTY_SANTA CLARA

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":county_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.585105582997862
# Root Mean Squared Error: 765.8331897241667
# Alpha: 0.005
#     Coefficients               Feature
# 0    -170.127741                  BEDS
# 1     114.977471                 BATHS
# 2     944.245164           SQUARE FEET
# 3      48.712810              LOT SIZE
# 4    -183.924129            YEAR BUILT
# 5     -19.749787             HOA/MONTH
# 6       0.000000                   LOT
# 7    -110.334505                   HOA
# 8      33.315795   PROPERTY TYPE_Condo
# 9     -41.664836     PROPERTY TYPE_SFH
# 10     22.122749      PROPERTY TYPE_TH
# 11   -193.674915        COUNTY_ALAMEDA
# 12      7.480368  COUNTY_SAN FRANCISCO
# 13     88.545106      COUNTY_SAN MATEO
# 14    104.165951    COUNTY_SANTA CLARA

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":county_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.5851346658427818
# Root Mean Squared Error: 765.0708774329421
# Alpha: 0.006609705742330144
#     Coefficients               Feature
# 0    -171.855657                  BEDS
# 1     103.415231                 BATHS
# 2     958.186597           SQUARE FEET
# 3      47.347250              LOT SIZE
# 4    -183.190383            YEAR BUILT
# 5     -15.865885             HOA/MONTH
# 6       0.000000                   LOT
# 7    -108.701302                   HOA
# 8       4.757650   PROPERTY TYPE_Condo
# 9     -71.606231     PROPERTY TYPE_SFH
# 10      0.000000      PROPERTY TYPE_TH
# 11   -282.453731        COUNTY_ALAMEDA
# 12    -18.728239  COUNTY_SAN FRANCISCO
# 13      0.000000      COUNTY_SAN MATEO
# 14     15.343432    COUNTY_SANTA CLARA

# %% [markdown]
# 3.2.2 Using city as the only location info

# %%
X_train, X_test, y_train, y_test = split(df_city_X, df_city_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":city_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7180658626116141
# Root Mean Squared Error: 7525830022314.006
#     Coefficients                   Feature
# 0  -1.051020e+02                      BEDS
# 1   4.418583e+01                     BATHS
# 2   7.459662e+02               SQUARE FEET
# 3   5.478715e+01                  LOT SIZE
# 4  -6.952767e+01                YEAR BUILT
# 5  -5.634454e+01                 HOA/MONTH
# 6   2.481204e+12                       LOT
# 7  -3.086323e+01                       HOA
# 8  -3.490498e+13       PROPERTY TYPE_Condo
# 9  -4.329148e+13         PROPERTY TYPE_SFH
# 10 -2.899906e+13          PROPERTY TYPE_TH
# 11 -3.472799e+13              CITY_ALAMEDA
# 12 -2.024382e+13               CITY_ALBANY
# 13 -1.704780e+13             CITY_ATHERTON
# 14 -2.670950e+13              CITY_BELMONT
# 15 -3.328053e+13             CITY_BERKELEY
# 16 -1.500311e+13             CITY_BRISBANE
# 17 -1.697425e+12            CITY_BROADMOOR
# 18 -2.547732e+13           CITY_BURLINGAME
# 19 -2.869480e+13             CITY_CAMPBELL
# 20 -9.211243e+12        CITY_CASTRO VALLEY
# 21 -5.366235e+12                CITY_COLMA
# 22 -2.765832e+13            CITY_CUPERTINO
# 23 -3.342431e+13            CITY_DALY CITY
# 24 -2.735445e+13               CITY_DUBLIN
# 25 -2.362008e+13       CITY_EAST PALO ALTO
# 26 -1.560874e+13           CITY_EL GRANADA
# 27 -3.795089e+12        CITY_EMERALD HILLS
# 28 -1.010277e+13           CITY_EMERYVILLE
# 29 -2.449572e+13          CITY_FOSTER CITY
# 30 -4.209963e+13              CITY_FREMONT
# 31 -3.478685e+13               CITY_GILROY
# 32 -2.544983e+13        CITY_HALF MOON BAY
# 33 -3.956900e+13              CITY_HAYWARD
# 34 -2.055589e+13         CITY_HILLSBOROUGH
# 35 -9.517778e+12             CITY_LA HONDA
# 36 -3.927987e+13            CITY_LIVERMORE
# 37 -2.939845e+12             CITY_LOMA MAR
# 38 -2.837833e+13            CITY_LOS ALTOS
# 39 -1.996218e+13      CITY_LOS ALTOS HILLS
# 40 -3.152047e+13            CITY_LOS GATOS
# 41 -3.348572e+13           CITY_MENLO PARK
# 42 -2.329033e+13             CITY_MILLBRAE
# 43 -3.221157e+13             CITY_MILPITAS
# 44 -1.251032e+13              CITY_MONTARA
# 45 -1.396827e+13         CITY_MONTE SERENO
# 46 -3.101332e+13          CITY_MORGAN HILL
# 47 -1.098660e+13           CITY_MOSS BEACH
# 48 -2.992472e+13        CITY_MOUNTAIN VIEW
# 49 -3.090187e+13               CITY_NEWARK
# 50 -4.012339e+13              CITY_OAKLAND
# 51 -2.893570e+13             CITY_PACIFICA
# 52 -2.903146e+13            CITY_PALO ALTO
# 53 -6.460902e+12            CITY_PESCADERO
# 54 -2.204764e+13             CITY_PIEDMONT
# 55 -3.548468e+13           CITY_PLEASANTON
# 56 -1.802067e+13       CITY_PORTOLA VALLEY
# 57 -3.765281e+13         CITY_REDWOOD CITY
# 58 -2.517317e+13            CITY_SAN BRUNO
# 59 -3.229682e+13           CITY_SAN CARLOS
# 60 -3.130107e+13        CITY_SAN FRANCISCO
# 61 -2.683741e+12         CITY_SAN GREGORIO
# 62 -5.258137e+13             CITY_SAN JOSE
# 63 -3.415318e+13          CITY_SAN LEANDRO
# 64 -9.132990e+12          CITY_SAN LORENZO
# 65 -3.980261e+12           CITY_SAN MARTIN
# 66 -4.135138e+13            CITY_SAN MATEO
# 67 -3.284501e+13          CITY_SANTA CLARA
# 68 -2.770862e+13             CITY_SARATOGA
# 69 -2.941115e+13  CITY_SOUTH SAN FRANCISCO
# 70 -2.400448e+12             CITY_STANFORD
# 71 -3.110217e+13            CITY_SUNNYVALE
# 72  2.165478e+12                CITY_SUNOL
# 73 -3.110217e+13           CITY_UNION CITY
# 74 -1.864030e+13             CITY_WOODSIDE

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":city_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7180331347175828
# Root Mean Squared Error: 537738.2516947543
# Alpha: 0.005
#      Coefficients                   Feature
# 0      -99.892865                      BEDS
# 1       51.218471                     BATHS
# 2      732.568660               SQUARE FEET
# 3       55.098070                  LOT SIZE
# 4      -68.829297                YEAR BUILT
# 5      -54.815072                 HOA/MONTH
# 6        0.000000                       LOT
# 7      -31.604363                       HOA
# 8       -6.895872       PROPERTY TYPE_Condo
# 9        1.463955         PROPERTY TYPE_SFH
# 10       5.959007          PROPERTY TYPE_TH
# 11     -55.883245              CITY_ALAMEDA
# 12     -14.268473               CITY_ALBANY
# 13     287.176256             CITY_ATHERTON
# 14      21.990370              CITY_BELMONT
# 15     -45.053143             CITY_BERKELEY
# 16     -20.154658             CITY_BRISBANE
# 17      -3.682889            CITY_BROADMOOR
# 18      52.686607           CITY_BURLINGAME
# 19       1.160133             CITY_CAMPBELL
# 20     -22.511828        CITY_CASTRO VALLEY
# 21      -4.325851                CITY_COLMA
# 22      60.271683            CITY_CUPERTINO
# 23     -36.575962            CITY_DALY CITY
# 24     -74.291739               CITY_DUBLIN
# 25     -26.593087       CITY_EAST PALO ALTO
# 26     -25.769213           CITY_EL GRANADA
# 27       4.465436        CITY_EMERALD HILLS
# 28      -6.932193           CITY_EMERYVILLE
# 29      21.210793          CITY_FOSTER CITY
# 30     -39.730554              CITY_FREMONT
# 31    -103.365429               CITY_GILROY
# 32     -44.842623        CITY_HALF MOON BAY
# 33    -109.472931              CITY_HAYWARD
# 34     112.851600         CITY_HILLSBOROUGH
# 35     -16.052556             CITY_LA HONDA
# 36    -104.127151            CITY_LIVERMORE
# 37      -8.209629             CITY_LOMA MAR
# 38     149.848347            CITY_LOS ALTOS
# 39     131.023804      CITY_LOS ALTOS HILLS
# 40      10.249975            CITY_LOS GATOS
# 41     127.387553           CITY_MENLO PARK
# 42      12.450983             CITY_MILLBRAE
# 43     -29.519296             CITY_MILPITAS
# 44     -21.377047              CITY_MONTARA
# 45      28.126466         CITY_MONTE SERENO
# 46     -75.739584          CITY_MORGAN HILL
# 47     -15.215717           CITY_MOSS BEACH
# 48      57.569062        CITY_MOUNTAIN VIEW
# 49     -51.321209               CITY_NEWARK
# 50     -94.998686              CITY_OAKLAND
# 51     -27.450009             CITY_PACIFICA
# 52     203.756256            CITY_PALO ALTO
# 53     -12.115184            CITY_PESCADERO
# 54      -7.480315             CITY_PIEDMONT
# 55     -74.117979           CITY_PLEASANTON
# 56      86.552118       CITY_PORTOLA VALLEY
# 57      25.582355         CITY_REDWOOD CITY
# 58     -19.234631            CITY_SAN BRUNO
# 59      43.695107           CITY_SAN CARLOS
# 60      23.908943        CITY_SAN FRANCISCO
# 61      -6.142022         CITY_SAN GREGORIO
# 62     -23.258333             CITY_SAN JOSE
# 63     -86.877125          CITY_SAN LEANDRO
# 64     -18.086078          CITY_SAN LORENZO
# 65     -11.189335           CITY_SAN MARTIN
# 66      32.602120            CITY_SAN MATEO
# 67      11.359166          CITY_SANTA CLARA
# 68      58.954438             CITY_SARATOGA
# 69     -28.326696  CITY_SOUTH SAN FRANCISCO
# 70      -0.516931             CITY_STANFORD
# 71      56.834099            CITY_SUNNYVALE
# 72  240487.484990                CITY_SUNOL
# 73     -67.435172           CITY_UNION CITY
# 74     149.649509             CITY_WOODSIDE

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":city_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7180362512589095
# Root Mean Squared Error: 633.3845667903529
# Alpha: 0.005
#     Coefficients                   Feature
# 0    -100.817034                      BEDS
# 1      41.351065                     BATHS
# 2     746.368168               SQUARE FEET
# 3      53.949119                  LOT SIZE
# 4     -69.745118                YEAR BUILT
# 5     -54.085885                 HOA/MONTH
# 6       0.000000                       LOT
# 7     -31.285434                       HOA
# 8      -6.393752       PROPERTY TYPE_Condo
# 9       0.000000         PROPERTY TYPE_SFH
# 10      5.114289          PROPERTY TYPE_TH
# 11    -30.945792              CITY_ALAMEDA
# 12     -0.000000               CITY_ALBANY
# 13    298.521517             CITY_ATHERTON
# 14     40.316749              CITY_BELMONT
# 15    -21.243943             CITY_BERKELEY
# 16     -8.810169             CITY_BRISBANE
# 17     -1.835482            CITY_BROADMOOR
# 18     70.007890           CITY_BURLINGAME
# 19     20.804858             CITY_CAMPBELL
# 20    -15.219256        CITY_CASTRO VALLEY
# 21     -0.000000                CITY_COLMA
# 22     79.500017            CITY_CUPERTINO
# 23    -11.865929            CITY_DALY CITY
# 24    -54.236688               CITY_DUBLIN
# 25     -9.067012       CITY_EAST PALO ALTO
# 26    -13.916579           CITY_EL GRANADA
# 27      6.362092        CITY_EMERALD HILLS
# 28      0.000000           CITY_EMERYVILLE
# 29     37.958623          CITY_FOSTER CITY
# 30     -8.658044              CITY_FREMONT
# 31    -78.347773               CITY_GILROY
# 32    -26.359495        CITY_HALF MOON BAY
# 33    -80.831953              CITY_HAYWARD
# 34    126.168809         CITY_HILLSBOROUGH
# 35     -8.554168             CITY_LA HONDA
# 36    -75.612096            CITY_LIVERMORE
# 37     -5.200789             CITY_LOMA MAR
# 38    169.539147            CITY_LOS ALTOS
# 39    144.288037      CITY_LOS ALTOS HILLS
# 40     31.604627            CITY_LOS GATOS
# 41    150.843221           CITY_MENLO PARK
# 42     28.169276             CITY_MILLBRAE
# 43     -5.632186             CITY_MILPITAS
# 44    -11.727785              CITY_MONTARA
# 45     36.955206         CITY_MONTE SERENO
# 46    -53.333630          CITY_MORGAN HILL
# 47     -6.711062           CITY_MOSS BEACH
# 48     78.128985        CITY_MOUNTAIN VIEW
# 49    -28.268351               CITY_NEWARK
# 50    -66.403136              CITY_OAKLAND
# 51     -5.959805             CITY_PACIFICA
# 52    224.416827            CITY_PALO ALTO
# 53     -6.640511            CITY_PESCADERO
# 54      6.662924             CITY_PIEDMONT
# 55    -48.665065           CITY_PLEASANTON
# 56     98.445579       CITY_PORTOLA VALLEY
# 57     51.721162         CITY_REDWOOD CITY
# 58     -0.410181            CITY_SAN BRUNO
# 59     65.975010           CITY_SAN CARLOS
# 60     45.367991        CITY_SAN FRANCISCO
# 61     -3.335520         CITY_SAN GREGORIO
# 62     12.875922             CITY_SAN JOSE
# 63    -62.276364          CITY_SAN LEANDRO
# 64    -10.855483          CITY_SAN LORENZO
# 65     -7.538965           CITY_SAN MARTIN
# 66     61.165597            CITY_SAN MATEO
# 67     33.833473          CITY_SANTA CLARA
# 68     77.708743             CITY_SARATOGA
# 69     -6.612609  CITY_SOUTH SAN FRANCISCO
# 70      0.326697             CITY_STANFORD
# 71     78.429128            CITY_SUNNYVALE
# 72     -0.000000                CITY_SUNOL
# 73    -44.512276           CITY_UNION CITY
# 74    161.829038             CITY_WOODSIDE

# %% [markdown]
# 3.2.3 Using zip as the only location info

# %%
X_train, X_test, y_train, y_test = split(df_zip_X, df_zip_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":zip_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7140411619740954
# Root Mean Squared Error: 260989893189831.78
#      Coefficients              Feature
# 0   -1.166116e+02                 BEDS
# 1    2.743136e+01                BATHS
# 2    7.893284e+02          SQUARE FEET
# 3    6.370197e+01             LOT SIZE
# 4   -6.363184e+01           YEAR BUILT
# 5   -6.701204e+01            HOA/MONTH
# 6   -1.025510e+13                  LOT
# 7   -3.224295e+01                  HOA
# 8   -1.359123e+14  PROPERTY TYPE_Condo
# 9   -1.685674e+14    PROPERTY TYPE_SFH
# 10  -1.129159e+14     PROPERTY TYPE_TH
# 11  -2.432805e+14            ZIP_94002
# 12  -1.366541e+14            ZIP_94005
# 13  -2.964880e+14            ZIP_94010
# 14  -1.936954e+14            ZIP_94014
# 15  -2.425654e+14            ZIP_94015
# 16  -9.827163e+13            ZIP_94018
# 17  -2.532946e+14            ZIP_94019
# 18  -8.669163e+13            ZIP_94020
# 19  -2.677726e+13            ZIP_94021
# 20  -2.418480e+14            ZIP_94022
# 21  -2.037099e+14            ZIP_94024
# 22  -3.035068e+14            ZIP_94025
# 23  -1.567906e+14            ZIP_94027
# 24  -1.652126e+14            ZIP_94028
# 25  -2.121374e+14            ZIP_94030
# 26  -1.139489e+14            ZIP_94037
# 27  -1.000703e+14            ZIP_94038
# 28  -1.708199e+14            ZIP_94040
# 29  -9.330416e+13            ZIP_94041
# 30  -1.930894e+14            ZIP_94043
# 31  -2.637760e+14            ZIP_94044
# 32  -5.884841e+13            ZIP_94060
# 33  -2.413685e+14            ZIP_94061
# 34  -2.482250e+14            ZIP_94062
# 35  -1.409171e+14            ZIP_94063
# 36  -9.947438e+13            ZIP_94065
# 37  -2.292871e+14            ZIP_94066
# 38  -2.941720e+14            ZIP_94070
# 39  -2.444456e+13            ZIP_94074
# 40  -2.676734e+14            ZIP_94080
# 41  -1.434128e+14            ZIP_94085
# 42  -1.494660e+14            ZIP_94086
# 43  -1.853411e+14            ZIP_94087
# 44  -6.464418e+13            ZIP_94089
# 45  -2.186421e+13            ZIP_94102
# 46  -1.893526e+13            ZIP_94103
# 47  -1.093261e+13            ZIP_94105
# 48  -3.456715e+13            ZIP_94107
# 49  -2.444456e+13            ZIP_94109
# 50  -8.027206e+13            ZIP_94110
# 51  -1.093261e+13            ZIP_94111
# 52  -1.281565e+14            ZIP_94112
# 53  -6.371498e+13            ZIP_94114
# 54  -3.456715e+13            ZIP_94115
# 55  -8.669163e+13            ZIP_94116
# 56  -3.941078e+13            ZIP_94117
# 57  -4.233266e+13            ZIP_94118
# 58  -5.126184e+13            ZIP_94121
# 59  -7.724661e+13            ZIP_94122
# 60  -3.786524e+13            ZIP_94123
# 61  -7.409694e+13            ZIP_94124
# 62  -8.246786e+13            ZIP_94127
# 63  -9.457072e+13            ZIP_94131
# 64  -5.678467e+13            ZIP_94132
# 65  -2.786894e+13            ZIP_94133
# 66  -8.027206e+13            ZIP_94134
# 67  -1.366541e+14            ZIP_94301
# 68  -2.580343e+14            ZIP_94303
# 69  -3.091875e+13            ZIP_94304
# 70  -2.186421e+13            ZIP_94305
# 71  -1.742301e+14            ZIP_94306
# 72  -2.039967e+14            ZIP_94401
# 73  -2.090886e+14            ZIP_94402
# 74  -2.305506e+14            ZIP_94403
# 75  -2.382266e+14            ZIP_94404
# 76  -2.731972e+14            ZIP_94501
# 77  -1.626968e+14            ZIP_94502
# 78  -2.154117e+14            ZIP_94536
# 79  -1.972904e+14            ZIP_94538
# 80  -1.918715e+14            ZIP_94539
# 81  -2.220706e+14            ZIP_94541
# 82  -1.290779e+14            ZIP_94542
# 83  -2.014003e+14            ZIP_94544
# 84  -1.575414e+14            ZIP_94545
# 85  -7.952656e+13            ZIP_94546
# 86  -2.663811e+14            ZIP_94550
# 87  -2.435184e+14            ZIP_94551
# 88  -5.126184e+13            ZIP_94552
# 89  -1.715076e+14            ZIP_94555
# 90  -2.812628e+14            ZIP_94560
# 91  -2.432805e+14            ZIP_94566
# 92  -2.489228e+14            ZIP_94568
# 93  -2.290335e+14            ZIP_94577
# 94  -1.732143e+14            ZIP_94578
# 95  -1.253513e+14            ZIP_94579
# 96  -8.389959e+13            ZIP_94580
# 97  -1.893526e+13            ZIP_94586
# 98  -2.832907e+14            ZIP_94587
# 99  -2.159524e+14            ZIP_94588
# 100 -1.006626e+14            ZIP_94601
# 101 -1.086130e+14            ZIP_94602
# 102 -1.304474e+14            ZIP_94603
# 103 -1.623342e+14            ZIP_94605
# 104 -7.724661e+13            ZIP_94606
# 105 -5.884841e+13            ZIP_94607
# 106 -1.299925e+14            ZIP_94608
# 107 -6.995954e+13            ZIP_94609
# 108 -1.344710e+14            ZIP_94610
# 109 -2.031351e+14            ZIP_94611
# 110 -2.677726e+13            ZIP_94612
# 111 -7.409694e+13            ZIP_94618
# 112 -1.190427e+14            ZIP_94619
# 113 -9.827163e+13            ZIP_94621
# 114 -1.417540e+14            ZIP_94702
# 115 -1.180418e+14            ZIP_94703
# 116 -5.241312e+13            ZIP_94704
# 117 -1.200352e+14            ZIP_94705
# 118 -1.840700e+14            ZIP_94706
# 119 -1.326981e+14            ZIP_94707
# 120 -1.286180e+14            ZIP_94708
# 121 -5.884841e+13            ZIP_94709
# 122 -7.568826e+13            ZIP_94710
# 123  1.045540e+14            ZIP_94979
# 124 -1.093261e+13            ZIP_94980
# 125 -1.893526e+13            ZIP_95002
# 126 -2.613634e+14            ZIP_95008
# 127 -2.519228e+14            ZIP_95014
# 128 -3.168522e+14            ZIP_95020
# 129 -1.093261e+13            ZIP_95025
# 130 -1.930894e+14            ZIP_95030
# 131 -2.121374e+14            ZIP_95032
# 132 -1.313524e+14            ZIP_95033
# 133 -2.933955e+14            ZIP_95035
# 134 -2.824814e+14            ZIP_95037
# 135 -3.625377e+13            ZIP_95046
# 136 -1.987684e+14            ZIP_95050
# 137 -1.990626e+14            ZIP_95051
# 138 -1.080648e+14            ZIP_95054
# 139 -2.523809e+14            ZIP_95070
# 140 -1.047142e+14            ZIP_95110
# 141 -9.071749e+13            ZIP_95111
# 142 -1.160137e+14            ZIP_95112
# 143 -2.677726e+13            ZIP_95113
# 144 -9.947438e+13            ZIP_95116
# 145 -7.952656e+13            ZIP_95117
# 146 -8.805421e+13            ZIP_95118
# 147 -4.372031e+13            ZIP_95119
# 148 -5.353959e+13            ZIP_95120
# 149 -6.277198e+13            ZIP_95121
# 150 -1.086130e+14            ZIP_95122
# 151 -1.458649e+14            ZIP_95123
# 152 -1.392279e+14            ZIP_95124
# 153 -1.379471e+14            ZIP_95125
# 154 -1.041451e+14            ZIP_95126
# 155 -1.392279e+14            ZIP_95127
# 156 -1.392279e+14            ZIP_95128
# 157 -1.129022e+14            ZIP_95129
# 158 -9.582040e+13            ZIP_95130
# 159 -5.572404e+13            ZIP_95131
# 160 -1.058430e+14            ZIP_95132
# 161 -6.556015e+13            ZIP_95133
# 162 -4.089787e+13            ZIP_95134
# 163 -5.782578e+13            ZIP_95135
# 164 -6.371498e+13            ZIP_95136
# 165 -4.506516e+13            ZIP_95138
# 166 -3.786524e+13            ZIP_95139
# 167 -5.884841e+13            ZIP_95148
# 168 -1.093261e+13            ZIP_95391

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":zip_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7140129817866487
# Root Mean Squared Error: 821823.7473672488
# Alpha: 0.005
#       Coefficients              Feature
# 0      -112.924683                 BEDS
# 1        37.388588                BATHS
# 2       774.430317          SQUARE FEET
# 3        64.244162             LOT SIZE
# 4       -62.784575           YEAR BUILT
# 5       -65.582100            HOA/MONTH
# 6         0.000000                  LOT
# 7       -32.450933                  HOA
# 8        -4.534887  PROPERTY TYPE_Condo
# 9        -0.362000    PROPERTY TYPE_SFH
# 10        5.868509     PROPERTY TYPE_TH
# 11       22.172860            ZIP_94002
# 12      -19.722189            ZIP_94005
# 13      107.861323            ZIP_94010
# 14      -27.443264            ZIP_94014
# 15      -23.131777            ZIP_94015
# 16      -20.530486            ZIP_94018
# 17      -49.567282            ZIP_94019
# 18      -15.905312            ZIP_94020
# 19       -8.523133            ZIP_94021
# 20      160.605448            ZIP_94022
# 21      111.740644            ZIP_94024
# 22      126.174354            ZIP_94025
# 23      279.387282            ZIP_94027
# 24       83.920080            ZIP_94028
# 25       12.590505            ZIP_94030
# 26      -21.766739            ZIP_94037
# 27      -15.550409            ZIP_94038
# 28       44.995617            ZIP_94040
# 29       25.647604            ZIP_94041
# 30       32.992095            ZIP_94043
# 31      -25.957751            ZIP_94044
# 32      -13.507388            ZIP_94060
# 33       22.305238            ZIP_94061
# 34      111.597383            ZIP_94062
# 35       -2.417561            ZIP_94063
# 36       16.209204            ZIP_94065
# 37      -17.897125            ZIP_94066
# 38       43.706504            ZIP_94070
# 39       -6.603785            ZIP_94074
# 40      -26.577101            ZIP_94080
# 41       13.314590            ZIP_94085
# 42       20.688634            ZIP_94086
# 43       54.887656            ZIP_94087
# 44       21.338408            ZIP_94089
# 45       -1.013096            ZIP_94102
# 46       -0.478947            ZIP_94103
# 47        7.412564            ZIP_94105
# 48        7.173186            ZIP_94107
# 49       11.126058            ZIP_94109
# 50       18.589653            ZIP_94110
# 51       -1.522231            ZIP_94111
# 52      -12.529611            ZIP_94112
# 53       28.152851            ZIP_94114
# 54        5.644075            ZIP_94115
# 55        1.016594            ZIP_94116
# 56       11.342001            ZIP_94117
# 57       25.136509            ZIP_94118
# 58        0.374737            ZIP_94121
# 59       -0.353141            ZIP_94122
# 60       39.728231            ZIP_94123
# 61      -11.665367            ZIP_94124
# 62        8.464010            ZIP_94127
# 63       25.745444            ZIP_94131
# 64       -0.032270            ZIP_94132
# 65   259892.227341            ZIP_94133
# 66       -5.927692            ZIP_94134
# 67      159.153635            ZIP_94301
# 68       36.687632            ZIP_94303
# 69       19.915350            ZIP_94304
# 70       -0.599352            ZIP_94305
# 71      103.653300            ZIP_94306
# 72        3.832893            ZIP_94401
# 73       35.342154            ZIP_94402
# 74       18.589365            ZIP_94403
# 75       23.394681            ZIP_94404
# 76      -51.173123            ZIP_94501
# 77      -21.626944            ZIP_94502
# 78      -25.906695            ZIP_94536
# 79      -18.118339            ZIP_94538
# 80       -9.530837            ZIP_94539
# 81      -61.738011            ZIP_94541
# 82      -71.598161            ZIP_94542
# 83      -49.326184            ZIP_94544
# 84      -38.877230            ZIP_94545
# 85      -23.488070            ZIP_94546
# 86      -89.041900            ZIP_94550
# 87      -58.563276            ZIP_94551
# 88      -18.259596            ZIP_94552
# 89      -24.844399            ZIP_94555
# 90      -49.454921            ZIP_94560
# 91      -66.126803            ZIP_94566
# 92      -75.023049            ZIP_94568
# 93      -66.712453            ZIP_94577
# 94      -45.472553            ZIP_94578
# 95      -31.292510            ZIP_94579
# 96      -16.219752            ZIP_94580
# 97       -3.032918            ZIP_94586
# 98      -66.262304            ZIP_94587
# 99      -39.581986            ZIP_94588
# 100     -31.455132            ZIP_94601
# 101     -20.862800            ZIP_94602
# 102     -38.403145            ZIP_94603
# 103     -50.303868            ZIP_94605
# 104     -22.354210            ZIP_94606
# 105     -13.891048            ZIP_94607
# 106     -16.375135            ZIP_94608
# 107      -9.290159            ZIP_94609
# 108     -13.067703            ZIP_94610
# 109     -21.513440            ZIP_94611
# 110      -5.037132            ZIP_94612
# 111      -8.864601            ZIP_94618
# 112     -29.062462            ZIP_94619
# 113     -30.777750            ZIP_94621
# 114     -10.762308            ZIP_94702
# 115     -18.935508            ZIP_94703
# 116      -4.415063            ZIP_94704
# 117     -25.272651            ZIP_94705
# 118     -14.005231            ZIP_94706
# 119     -17.000821            ZIP_94707
# 120     -27.629724            ZIP_94708
# 121     -10.559690            ZIP_94709
# 122      -3.150696            ZIP_94710
# 123  259892.227341            ZIP_94979
# 124      -3.175604            ZIP_94980
# 125      -0.983764            ZIP_95002
# 126       2.266743            ZIP_95008
# 127      61.562403            ZIP_95014
# 128    -103.759719            ZIP_95020
# 129       9.313116            ZIP_95025
# 130      32.138491            ZIP_95030
# 131      21.200497            ZIP_95032
# 132     -30.941623            ZIP_95033
# 133     -27.708859            ZIP_95035
# 134     -76.326479            ZIP_95037
# 135     -11.483550            ZIP_95046
# 136      -2.604963            ZIP_95050
# 137      21.847517            ZIP_95051
# 138       3.814869            ZIP_95054
# 139      57.858934            ZIP_95070
# 140      -8.359187            ZIP_95110
# 141      -8.421355            ZIP_95111
# 142     -14.793406            ZIP_95112
# 143       0.210365            ZIP_95113
# 144     -14.935807            ZIP_95116
# 145      -0.507594            ZIP_95117
# 146       0.549955            ZIP_95118
# 147      -1.942674            ZIP_95119
# 148       0.073051            ZIP_95120
# 149      -6.992606            ZIP_95121
# 150     -13.113059            ZIP_95122
# 151      -5.846221            ZIP_95123
# 152       2.958643            ZIP_95124
# 153       0.981269            ZIP_95125
# 154      -4.723103            ZIP_95126
# 155     -23.730942            ZIP_95127
# 156      -2.660722            ZIP_95128
# 157      20.030579            ZIP_95129
# 158       9.351502            ZIP_95130
# 159       2.456892            ZIP_95131
# 160      -6.365897            ZIP_95132
# 161      -3.070103            ZIP_95133
# 162      -1.804081            ZIP_95134
# 163      -3.545079            ZIP_95135
# 164      -4.931057            ZIP_95136
# 165      -3.951756            ZIP_95138
# 166      -5.256509            ZIP_95139
# 167     -12.883813            ZIP_95148
# 168      -2.061725            ZIP_95391

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":zip_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7139832267842356
# Root Mean Squared Error: 637.5154535154204
# Alpha: 0.005
#      Coefficients              Feature
# 0     -114.098371                 BEDS
# 1       26.351572                BATHS
# 2      788.981255          SQUARE FEET
# 3       63.015901             LOT SIZE
# 4      -63.125442           YEAR BUILT
# 5      -64.824932            HOA/MONTH
# 6        0.000000                  LOT
# 7      -32.551681                  HOA
# 8       -1.745932  PROPERTY TYPE_Condo
# 9        0.000000    PROPERTY TYPE_SFH
# 10       6.381497     PROPERTY TYPE_TH
# 11      41.028403            ZIP_94002
# 12      -8.110362            ZIP_94005
# 13     130.544156            ZIP_94010
# 14     -11.156468            ZIP_94014
# 15      -2.653761            ZIP_94015
# 16     -11.952844            ZIP_94018
# 17     -28.864907            ZIP_94019
# 18      -8.207409            ZIP_94020
# 19      -5.458877            ZIP_94021
# 20     179.261868            ZIP_94022
# 21     127.458659            ZIP_94024
# 22     150.146281            ZIP_94025
# 23     291.215395            ZIP_94027
# 24      96.252120            ZIP_94028
# 25      28.740776            ZIP_94030
# 26     -11.885989            ZIP_94037
# 27      -6.845709            ZIP_94038
# 28      57.765892            ZIP_94040
# 29      32.342536            ZIP_94041
# 30      47.642819            ZIP_94043
# 31      -3.885035            ZIP_94044
# 32      -7.904509            ZIP_94060
# 33      41.121536            ZIP_94061
# 34     130.403020            ZIP_94062
# 35       8.115638            ZIP_94063
# 36      23.517744            ZIP_94065
# 37       0.000000            ZIP_94066
# 38      66.597390            ZIP_94070
# 39      -3.747682            ZIP_94074
# 40      -4.350833            ZIP_94080
# 41      23.872316            ZIP_94085
# 42      31.743283            ZIP_94086
# 43      69.292696            ZIP_94087
# 44      25.985716            ZIP_94089
# 45       0.000000            ZIP_94102
# 46       0.184223            ZIP_94103
# 47       7.568103            ZIP_94105
# 48       9.125067            ZIP_94107
# 49      12.366938            ZIP_94109
# 50      24.366759            ZIP_94110
# 51      -0.000000            ZIP_94111
# 52      -1.453922            ZIP_94112
# 53      32.614707            ZIP_94114
# 54       7.589727            ZIP_94115
# 55       7.139468            ZIP_94116
# 56      13.600890            ZIP_94117
# 57      27.698181            ZIP_94118
# 58       3.591141            ZIP_94121
# 59       4.929506            ZIP_94122
# 60      42.003151            ZIP_94123
# 61      -4.969152            ZIP_94124
# 62      14.263828            ZIP_94127
# 63      32.707403            ZIP_94131
# 64       3.808385            ZIP_94132
# 65      -0.000000            ZIP_94133
# 66       0.000000            ZIP_94134
# 67     169.872479            ZIP_94301
# 68      56.782956            ZIP_94303
# 69      21.724443            ZIP_94304
# 70       0.270626            ZIP_94305
# 71     117.180758            ZIP_94306
# 72      19.109265            ZIP_94401
# 73      51.236136            ZIP_94402
# 74      36.451898            ZIP_94403
# 75      41.757171            ZIP_94404
# 76     -29.096166            ZIP_94501
# 77      -7.794936            ZIP_94502
# 78      -7.628046            ZIP_94536
# 79      -1.076898            ZIP_94538
# 80       5.076914            ZIP_94539
# 81     -43.292881            ZIP_94541
# 82     -61.085822            ZIP_94542
# 83     -32.374945            ZIP_94544
# 84     -25.291041            ZIP_94545
# 85     -16.452428            ZIP_94546
# 86     -67.246106            ZIP_94550
# 87     -38.152676            ZIP_94551
# 88     -13.448610            ZIP_94552
# 89     -10.116930            ZIP_94555
# 90     -25.812847            ZIP_94560
# 91     -46.485822            ZIP_94566
# 92     -54.410119            ZIP_94568
# 93     -48.050422            ZIP_94577
# 94     -31.000404            ZIP_94578
# 95     -20.467931            ZIP_94579
# 96      -8.692472            ZIP_94580
# 97      -0.559994            ZIP_94586
# 98     -42.752913            ZIP_94587
# 99     -21.523335            ZIP_94588
# 100    -22.820279            ZIP_94601
# 101    -11.552327            ZIP_94602
# 102    -27.358282            ZIP_94603
# 103    -36.785663            ZIP_94605
# 104    -15.489125            ZIP_94606
# 105     -8.472506            ZIP_94607
# 106     -5.411583            ZIP_94608
# 107     -2.906848            ZIP_94609
# 108     -1.891277            ZIP_94610
# 109     -5.104428            ZIP_94611
# 110     -2.075577            ZIP_94612
# 111     -2.403685            ZIP_94618
# 112    -18.900098            ZIP_94619
# 113    -22.191715            ZIP_94621
# 114      0.000000            ZIP_94702
# 115     -8.871068            ZIP_94703
# 116     -0.000000            ZIP_94704
# 117    -15.286057            ZIP_94705
# 118      0.000000            ZIP_94706
# 119     -5.884240            ZIP_94707
# 120    -16.713851            ZIP_94708
# 121     -5.275926            ZIP_94709
# 122      2.098777            ZIP_94710
# 123     -0.000000            ZIP_94979
# 124     -1.528545            ZIP_94980
# 125      0.000000            ZIP_95002
# 126     22.421504            ZIP_95008
# 127     81.294076            ZIP_95014
# 128    -78.111828            ZIP_95020
# 129      9.496243            ZIP_95025
# 130     46.387024            ZIP_95030
# 131     37.360717            ZIP_95032
# 132    -19.839999            ZIP_95033
# 133     -3.279817            ZIP_95035
# 134    -53.361984            ZIP_95037
# 135     -7.767314            ZIP_95046
# 136     12.224049            ZIP_95050
# 137     37.008094            ZIP_95051
# 138     11.597614            ZIP_95054
# 139     77.115948            ZIP_95070
# 140     -0.000000            ZIP_95110
# 141     -0.536298            ZIP_95111
# 142     -5.022331            ZIP_95112
# 143      1.326125            ZIP_95113
# 144     -6.386907            ZIP_95116
# 145      5.037178            ZIP_95117
# 146      6.747015            ZIP_95118
# 147      0.764682            ZIP_95119
# 148      3.467000            ZIP_95120
# 149     -1.288799            ZIP_95121
# 150     -3.726495            ZIP_95122
# 151      4.512805            ZIP_95123
# 152     13.293099            ZIP_95124
# 153     10.982267            ZIP_95125
# 154      2.541344            ZIP_95126
# 155    -12.073496            ZIP_95127
# 156      7.490643            ZIP_95128
# 157     28.303523            ZIP_95129
# 158     16.448231            ZIP_95130
# 159      6.105162            ZIP_95131
# 160      1.282856            ZIP_95132
# 161      1.165280            ZIP_95133
# 162      0.578751            ZIP_95134
# 163      0.000000            ZIP_95135
# 164      0.000000            ZIP_95136
# 165     -0.000000            ZIP_95138
# 166     -1.335330            ZIP_95139
# 167     -7.356472            ZIP_95148
# 168     -0.448162            ZIP_95391

# %% [markdown]
# # 3.3 Keep all location info

# %%
X_train, X_test, y_train, y_test = split(df_X, df_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":df_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7283258875255255
# Root Mean Squared Error: 3326962357014995.5
#      Coefficients                   Feature
# 0   -1.037627e+02                      BEDS
# 1    3.013020e+01                     BATHS
# 2    7.445445e+02               SQUARE FEET
# 3    5.451400e+01                  LOT SIZE
# 4   -5.127678e+01                YEAR BUILT
# 5   -6.763155e+01                 HOA/MONTH
# 6    3.218683e+15                       LOT
# 7   -2.734041e+01                       HOA
# 8   -8.644702e+11       PROPERTY TYPE_Condo
# 9   -1.072173e+12         PROPERTY TYPE_SFH
# 10  -7.182019e+11          PROPERTY TYPE_TH
# 11  -1.792864e+15              CITY_ALAMEDA
# 12  -2.593313e+14               CITY_ALBANY
# 13   4.897258e+14             CITY_ATHERTON
# 14  -4.607005e+14              CITY_BELMONT
# 15  -4.263367e+14             CITY_BERKELEY
# 16  -2.752852e+15             CITY_BRISBANE
# 17   1.577213e+13            CITY_BROADMOOR
# 18  -6.621527e+14           CITY_BURLINGAME
# 19   1.126868e+15             CITY_CAMPBELL
# 20   9.173124e+13        CITY_CASTRO VALLEY
# 21   4.986195e+13                CITY_COLMA
# 22   1.007897e+15            CITY_CUPERTINO
# 23   3.105717e+14            CITY_DALY CITY
# 24   1.173453e+15               CITY_DUBLIN
# 25  -1.309140e+15       CITY_EAST PALO ALTO
# 26   2.509371e+14           CITY_EL GRANADA
# 27   6.101251e+13        CITY_EMERALD HILLS
# 28  -1.294205e+14           CITY_EMERYVILLE
# 29   8.661360e+14          CITY_FOSTER CITY
# 30  -5.393129e+14              CITY_FREMONT
# 31   5.468781e+14               CITY_GILROY
# 32   4.091493e+14        CITY_HALF MOON BAY
# 33   3.940525e+14              CITY_HAYWARD
# 34  -5.342454e+14         CITY_HILLSBOROUGH
# 35   9.944395e+14             CITY_LA HONDA
# 36  -5.031906e+14            CITY_LIVERMORE
# 37  -1.556312e+15             CITY_LOMA MAR
# 38   4.414913e+15            CITY_LOS ALTOS
# 39   3.105584e+15      CITY_LOS ALTOS HILLS
# 40   3.065821e+14            CITY_LOS GATOS
# 41   9.619316e+14           CITY_MENLO PARK
# 42   6.945928e+14             CITY_MILLBRAE
# 43   1.794320e+15             CITY_MILPITAS
# 44   7.625013e+14              CITY_MONTARA
# 45   1.358616e+14         CITY_MONTE SERENO
# 46  -1.702054e+15          CITY_MORGAN HILL
# 47   1.174898e+15           CITY_MOSS BEACH
# 48  -2.138516e+15        CITY_MOUNTAIN VIEW
# 49   2.386637e+15               CITY_NEWARK
# 50  -5.139965e+14              CITY_OAKLAND
# 51   1.023128e+15             CITY_PACIFICA
# 52  -2.012261e+15            CITY_PALO ALTO
# 53  -3.687663e+14            CITY_PESCADERO
# 54  -2.824390e+14             CITY_PIEDMONT
# 55  -4.545727e+14           CITY_PLEASANTON
# 56   5.176730e+14       CITY_PORTOLA VALLEY
# 57   6.053330e+14         CITY_REDWOOD CITY
# 58  -2.588696e+15            CITY_SAN BRUNO
# 59  -2.214392e+15           CITY_SAN CARLOS
# 60   1.885041e+15        CITY_SAN FRANCISCO
# 61   1.986408e+15         CITY_SAN GREGORIO
# 62   6.092866e+14             CITY_SAN JOSE
# 63  -4.375157e+14          CITY_SAN LEANDRO
# 64  -1.169972e+14          CITY_SAN LORENZO
# 65   1.573318e+13           CITY_SAN MARTIN
# 66   1.462129e+15            CITY_SAN MATEO
# 67   2.080611e+15          CITY_SANTA CLARA
# 68  -3.383760e+15             CITY_SARATOGA
# 69  -2.857326e+14  CITY_SOUTH SAN FRANCISCO
# 70   7.051729e+14             CITY_STANFORD
# 71  -9.069606e+14            CITY_SUNNYVALE
# 72   1.078896e+15                CITY_SUNOL
# 73   7.707843e+14           CITY_UNION CITY
# 74   2.996745e+14             CITY_WOODSIDE
# 75   7.701869e+14                 ZIP_94002
# 76   2.926695e+15                 ZIP_94005
# 77   1.223173e+15                 ZIP_94010
# 78   4.881167e+13                 ZIP_94014
# 79   6.112702e+13                 ZIP_94015
# 80  -4.843861e+13                 ZIP_94018
# 81  -1.248502e+14                 ZIP_94019
# 82  -8.841558e+14                 ZIP_94020
# 83   1.590377e+15                 ZIP_94021
# 84  -4.191919e+15                 ZIP_94022
# 85  -3.530878e+15                 ZIP_94024
# 86  -5.711167e+14                 ZIP_94025
# 87  -2.950370e+14                 ZIP_94027
# 88  -3.108849e+14                 ZIP_94028
# 89  -4.247248e+14                 ZIP_94030
# 90  -6.175426e+14                 ZIP_94037
# 91  -1.047594e+15                 ZIP_94038
# 92   1.297075e+15                 ZIP_94040
# 93   7.084798e+14                 ZIP_94041
# 94   1.466172e+15                 ZIP_94043
# 95  -6.884159e+14                 ZIP_94044
# 96   4.436296e+14                 ZIP_94060
# 97  -1.189718e+14                 ZIP_94061
# 98  -1.223514e+14                 ZIP_94062
# 99  -6.945878e+13                 ZIP_94063
# 100 -4.903145e+13                 ZIP_94065
# 101  2.880381e+15                 ZIP_94066
# 102  2.588619e+15                 ZIP_94070
# 103 -1.955311e+15                 ZIP_94074
# 104  6.260211e+14                 ZIP_94080
# 105  4.229075e+14                 ZIP_94085
# 106  4.407577e+14                 ZIP_94086
# 107  5.465492e+14                 ZIP_94087
# 108  1.906281e+14                 ZIP_94089
# 109  9.145800e+13                 ZIP_94102
# 110  7.920618e+13                 ZIP_94103
# 111  4.573112e+13                 ZIP_94105
# 112  1.445944e+14                 ZIP_94107
# 113  1.022516e+14                 ZIP_94109
# 114  3.357780e+14                 ZIP_94110
# 115  4.573112e+13                 ZIP_94111
# 116  5.360788e+14                 ZIP_94112
# 117  2.665198e+14                 ZIP_94114
# 118  1.445944e+14                 ZIP_94115
# 119  3.626311e+14                 ZIP_94116
# 120  1.648553e+14                 ZIP_94117
# 121  1.770775e+14                 ZIP_94118
# 122  2.144283e+14                 ZIP_94121
# 123  3.231226e+14                 ZIP_94122
# 124  1.583903e+14                 ZIP_94123
# 125  3.099475e+14                 ZIP_94124
# 126  3.449630e+14                 ZIP_94127
# 127  3.955893e+14                 ZIP_94131
# 128  2.375303e+14                 ZIP_94132
# 129  1.092558e+15                 ZIP_94133
# 130  3.357780e+14                 ZIP_94134
# 131  1.005388e+15                 ZIP_94301
# 132  1.898403e+15                 ZIP_94303
# 133  2.274747e+14                 ZIP_94304
# 134 -7.106966e+14                 ZIP_94305
# 135  1.281841e+15                 ZIP_94306
# 136 -5.324009e+14                 ZIP_94401
# 137 -5.456899e+14                 ZIP_94402
# 138 -6.017026e+14                 ZIP_94403
# 139 -6.217356e+14                 ZIP_94404
# 140  1.029572e+15                 ZIP_94501
# 141  6.131402e+14                 ZIP_94502
# 142 -1.061776e+14                 ZIP_94536
# 143 -9.724551e+13                 ZIP_94538
# 144 -9.457449e+13                 ZIP_94539
# 145 -6.645884e+14                 ZIP_94541
# 146 -3.862900e+14                 ZIP_94542
# 147 -6.027286e+14                 ZIP_94544
# 148 -4.714724e+14                 ZIP_94545
# 149 -2.379983e+14                 ZIP_94546
# 150 -1.313007e+14                 ZIP_94550
# 151 -1.200315e+14                 ZIP_94551
# 152 -1.534108e+14                 ZIP_94552
# 153 -8.453699e+13                 ZIP_94555
# 154 -2.919126e+15                 ZIP_94560
# 155 -1.199143e+14                 ZIP_94566
# 156 -1.645150e+15                 ZIP_94568
# 157 -1.128918e+14                 ZIP_94577
# 158 -8.537827e+13                 ZIP_94578
# 159 -6.178630e+13                 ZIP_94579
# 160 -4.135455e+13                 ZIP_94580
# 161 -1.251446e+14                 ZIP_94586
# 162 -1.308851e+15                 ZIP_94587
# 163 -1.064441e+14                 ZIP_94588
# 164 -4.961713e+13                 ZIP_94601
# 165 -5.353594e+13                 ZIP_94602
# 166 -6.429823e+13                 ZIP_94603
# 167 -8.001538e+13                 ZIP_94605
# 168 -3.807527e+13                 ZIP_94606
# 169 -2.900670e+13                 ZIP_94607
# 170 -6.407401e+13                 ZIP_94608
# 171 -3.448343e+13                 ZIP_94609
# 172 -6.628145e+13                 ZIP_94610
# 173 -1.001264e+14                 ZIP_94611
# 174 -1.319865e+13                 ZIP_94612
# 175 -3.652278e+13                 ZIP_94618
# 176 -5.867680e+13                 ZIP_94619
# 177 -4.843861e+13                 ZIP_94621
# 178 -6.987128e+13                 ZIP_94702
# 179 -5.818344e+13                 ZIP_94703
# 180 -2.583471e+13                 ZIP_94704
# 181 -5.916599e+13                 ZIP_94705
# 182 -9.072906e+13                 ZIP_94706
# 183 -6.540758e+13                 ZIP_94707
# 184 -6.339651e+13                 ZIP_94708
# 185 -2.900670e+13                 ZIP_94709
# 186 -3.730715e+13                 ZIP_94710
# 187 -2.518920e+14                 ZIP_94979
# 188  2.556865e+13                 ZIP_94980
# 189 -2.887277e+13                 ZIP_95002
# 190 -1.192898e+15                 ZIP_95008
# 191 -1.071541e+15                 ZIP_95014
# 192 -6.269265e+14                 ZIP_95020
# 193 -2.057219e+13                 ZIP_95025
# 194 -2.549730e+14                 ZIP_95030
# 195 -2.801257e+14                 ZIP_95032
# 196 -1.734498e+14                 ZIP_95033
# 197 -1.868442e+15                 ZIP_95035
# 198  1.630689e+15                 ZIP_95037
# 199 -2.489220e+13                 ZIP_95046
# 200 -1.432596e+15                 ZIP_95050
# 201 -1.434716e+15                 ZIP_95051
# 202 -7.788617e+14                 ZIP_95054
# 203  3.319999e+15                 ZIP_95070
# 204 -1.596697e+14                 ZIP_95110
# 205 -1.383274e+14                 ZIP_95111
# 206 -1.768994e+14                 ZIP_95112
# 207 -4.083036e+13                 ZIP_95113
# 208 -1.516800e+14                 ZIP_95116
# 209 -1.212633e+14                 ZIP_95117
# 210 -1.342664e+14                 ZIP_95118
# 211 -6.666538e+13                 ZIP_95119
# 212 -8.163797e+13                 ZIP_95120
# 213 -9.571566e+13                 ZIP_95121
# 214 -1.656148e+14                 ZIP_95122
# 215 -2.224170e+14                 ZIP_95123
# 216 -2.122968e+14                 ZIP_95124
# 217 -2.103439e+14                 ZIP_95125
# 218 -1.588021e+14                 ZIP_95126
# 219 -2.122968e+14                 ZIP_95127
# 220 -2.122968e+14                 ZIP_95128
# 221 -1.721549e+14                 ZIP_95129
# 222 -1.461084e+14                 ZIP_95130
# 223 -8.496886e+13                 ZIP_95131
# 224 -1.613909e+14                 ZIP_95132
# 225 -9.996710e+13                 ZIP_95133
# 226 -6.236169e+13                 ZIP_95134
# 227 -8.817362e+13                 ZIP_95135
# 228 -9.715357e+13                 ZIP_95136
# 229 -6.871604e+13                 ZIP_95138
# 230 -5.773749e+13                 ZIP_95139
# 231 -8.973295e+13                 ZIP_95148
# 232 -5.388744e+12                 ZIP_95391
# 233  1.008070e+15            COUNTY_ALAMEDA
# 234 -3.308819e+15      COUNTY_SAN FRANCISCO
# 235 -1.915767e+15          COUNTY_SAN MATEO
# 236 -5.123264e+14        COUNTY_SANTA CLARA

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":df_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7290660976394299
# Root Mean Squared Error: 1529530.6961629551
# Alpha: 0.005
#       Coefficients                   Feature
# 0      -101.198845                      BEDS
# 1        34.674826                     BATHS
# 2       733.237741               SQUARE FEET
# 3        58.176293                  LOT SIZE
# 4       -53.823630                YEAR BUILT
# 5       -65.621312                 HOA/MONTH
# 6         0.000000                       LOT
# 7       -26.915140                       HOA
# 8        -7.736343       PROPERTY TYPE_Condo
# 9         3.625015         PROPERTY TYPE_SFH
# 10        3.767271          PROPERTY TYPE_TH
# 11      -13.040266              CITY_ALAMEDA
# 12        8.636604               CITY_ALBANY
# 13      200.664853             CITY_ATHERTON
# 14        5.681109              CITY_BELMONT
# 15      -13.973174             CITY_BERKELEY
# 16      -13.157458             CITY_BRISBANE
# 17       -3.634506            CITY_BROADMOOR
# 18        4.170181           CITY_BURLINGAME
# 19       -5.749567             CITY_CAMPBELL
# 20        6.478651        CITY_CASTRO VALLEY
# 21       -1.258335                CITY_COLMA
# 22       24.241061            CITY_CUPERTINO
# 23      -25.655266            CITY_DALY CITY
# 24      -26.293851               CITY_DUBLIN
# 25      -65.642752       CITY_EAST PALO ALTO
# 26       12.595380           CITY_EL GRANADA
# 27       -3.781997        CITY_EMERALD HILLS
# 28        1.225391           CITY_EMERYVILLE
# 29        9.453154          CITY_FOSTER CITY
# 30        4.737181              CITY_FREMONT
# 31      -60.207004               CITY_GILROY
# 32       12.823283        CITY_HALF MOON BAY
# 33      -42.425554              CITY_HAYWARD
# 34       75.080818         CITY_HILLSBOROUGH
# 35      -10.071909             CITY_LA HONDA
# 36      -48.818260            CITY_LIVERMORE
# 37       -4.828933             CITY_LOMA MAR
# 38       65.692734            CITY_LOS ALTOS
# 39       67.795326      CITY_LOS ALTOS HILLS
# 40       -0.714958            CITY_LOS GATOS
# 41       25.376528           CITY_MENLO PARK
# 42        1.683956             CITY_MILLBRAE
# 43      -22.262899             CITY_MILPITAS
# 44      -13.426190              CITY_MONTARA
# 45       10.029774         CITY_MONTE SERENO
# 46      -45.452094          CITY_MORGAN HILL
# 47      -10.017411           CITY_MOSS BEACH
# 48       22.589904        CITY_MOUNTAIN VIEW
# 49      -13.177285               CITY_NEWARK
# 50      -33.569780              CITY_OAKLAND
# 51      -16.720837             CITY_PACIFICA
# 52      133.018068            CITY_PALO ALTO
# 53       -7.588590            CITY_PESCADERO
# 54       20.116304             CITY_PIEDMONT
# 55      -32.591687           CITY_PLEASANTON
# 56       47.154910       CITY_PORTOLA VALLEY
# 57      -49.878356         CITY_REDWOOD CITY
# 58      -14.815807            CITY_SAN BRUNO
# 59       15.697732           CITY_SAN CARLOS
# 60        8.630613        CITY_SAN FRANCISCO
# 61       -3.664649         CITY_SAN GREGORIO
# 62      -24.568044             CITY_SAN JOSE
# 63      -17.188144          CITY_SAN LEANDRO
# 64      -22.762608          CITY_SAN LORENZO
# 65       -6.544192           CITY_SAN MARTIN
# 66        4.476961            CITY_SAN MATEO
# 67       -1.786509          CITY_SANTA CLARA
# 68       23.946107             CITY_SARATOGA
# 69      -20.380849  CITY_SOUTH SAN FRANCISCO
# 70       -0.656338             CITY_STANFORD
# 71       21.646445            CITY_SUNNYVALE
# 72   394935.324719                CITY_SUNOL
# 73      -21.186090           CITY_UNION CITY
# 74      110.198468             CITY_WOODSIDE
# 75        5.681109                 ZIP_94002
# 76      -13.157458                 ZIP_94005
# 77       50.637149                 ZIP_94010
# 78      -21.788628                 ZIP_94014
# 79      -15.466523                 ZIP_94015
# 80      -33.480305                 ZIP_94018
# 81      -75.695118                 ZIP_94019
# 82      -10.071909                 ZIP_94020
# 83       -4.828933                 ZIP_94021
# 84       79.941796                 ZIP_94022
# 85       49.325343                 ZIP_94024
# 86       88.814535                 ZIP_94025
# 87       83.302864                 ZIP_94027
# 88       33.173467                 ZIP_94028
# 89        1.683956                 ZIP_94030
# 90      -13.426190                 ZIP_94037
# 91      -10.017411                 ZIP_94038
# 92       21.813487                 ZIP_94040
# 93       13.028980                 ZIP_94041
# 94        6.197723                 ZIP_94043
# 95      -23.230240                 ZIP_94044
# 96       -7.588590                 ZIP_94060
# 97       45.646737                 ZIP_94061
# 98       49.041591                 ZIP_94062
# 99       10.550119                 ZIP_94063
# 100      25.784617                 ZIP_94065
# 101     -14.815807                 ZIP_94066
# 102      15.697732                 ZIP_94070
# 103      -3.664649                 ZIP_94074
# 104     -20.255825                 ZIP_94080
# 105      -5.976187                 ZIP_94085
# 106       0.827938                 ZIP_94086
# 107      30.789203                 ZIP_94087
# 108      12.608731                 ZIP_94089
# 109      -2.164471                 ZIP_94102
# 110      -1.486209                 ZIP_94103
# 111       6.650814                 ZIP_94105
# 112       4.984385                 ZIP_94107
# 113      10.479772                 ZIP_94109
# 114      14.088637                 ZIP_94110
# 115      -2.084194                 ZIP_94111
# 116     -20.645754                 ZIP_94112
# 117      25.023519                 ZIP_94114
# 118       3.720265                 ZIP_94115
# 119      -4.269675                 ZIP_94116
# 120       9.915235                 ZIP_94117
# 121      23.569555                 ZIP_94118
# 122      -2.391908                 ZIP_94121
# 123      -4.931890                 ZIP_94122
# 124      38.697593                 ZIP_94123
# 125     -16.423538                 ZIP_94124
# 126       3.991924                 ZIP_94127
# 127      20.588820                 ZIP_94131
# 128      -3.430117                 ZIP_94132
# 129  394935.324719                 ZIP_94133
# 130     -11.261690                 ZIP_94134
# 131      85.309072                 ZIP_94301
# 132      34.408289                 ZIP_94303
# 133       3.170731                 ZIP_94304
# 134      -0.656338                 ZIP_94305
# 135       7.749593                 ZIP_94306
# 136      -8.639613                 ZIP_94401
# 137      25.094371                 ZIP_94402
# 138       4.677798                 ZIP_94403
# 139       3.025719                 ZIP_94404
# 140     -14.735438                 ZIP_94501
# 141      -0.822836                 ZIP_94502
# 142     -10.504271                 ZIP_94536
# 143      -4.511651                 ZIP_94538
# 144       5.987905                 ZIP_94539
# 145     -16.829115                 ZIP_94541
# 146     -43.087975                 ZIP_94542
# 147      -9.229337                 ZIP_94544
# 148      -7.530341                 ZIP_94545
# 149     -19.929905                 ZIP_94546
# 150     -28.566381                 ZIP_94550
# 151      -5.318666                 ZIP_94551
# 152     -14.074828                 ZIP_94552
# 153     -12.080919                 ZIP_94555
# 154     -13.167757                 ZIP_94560
# 155     -17.431800                 ZIP_94566
# 156     -26.418548                 ZIP_94568
# 157     -33.928081                 ZIP_94577
# 158     -21.222918                 ZIP_94578
# 159     -14.022996                 ZIP_94579
# 160      12.420540                 ZIP_94580
# 161       0.484778                 ZIP_94586
# 162     -21.186090                 ZIP_94587
# 163       1.189382                 ZIP_94588
# 164     -13.286058                 ZIP_94601
# 165      -0.784509                 ZIP_94602
# 166     -15.712198                 ZIP_94603
# 167     -21.053631                 ZIP_94605
# 168      -8.168198                 ZIP_94606
# 169      -3.246058                 ZIP_94607
# 170       0.120398                 ZIP_94608
# 171       3.497378                 ZIP_94609
# 172      -2.291124                 ZIP_94610
# 173      -8.077306                 ZIP_94611
# 174      -0.157594                 ZIP_94612
# 175       2.753065                 ZIP_94618
# 176      -7.429313                 ZIP_94619
# 177     -13.473079                 ZIP_94621
# 178       8.122888                 ZIP_94702
# 179      -2.371664                 ZIP_94703
# 180       2.970767                 ZIP_94704
# 181      -6.277235                 ZIP_94705
# 182      -5.721440                 ZIP_94706
# 183       1.874158                 ZIP_94707
# 184      -8.786582                 ZIP_94708
# 185      -1.772094                 ZIP_94709
# 186       6.827732                 ZIP_94710
# 187  394935.324719                 ZIP_94979
# 188      -2.921617                 ZIP_94980
# 189      -1.212647                 ZIP_95002
# 190      -5.749567                 ZIP_95008
# 191      24.241061                 ZIP_95014
# 192     -60.207004                 ZIP_95020
# 193       7.839997                 ZIP_95025
# 194      20.184053                 ZIP_95030
# 195      11.926752                 ZIP_95032
# 196     -36.711064                 ZIP_95033
# 197     -22.262899                 ZIP_95035
# 198     -45.452094                 ZIP_95037
# 199      -6.544192                 ZIP_95046
# 200     -12.473419                 ZIP_95050
# 201      11.696148                 ZIP_95051
# 202      -1.664000                 ZIP_95054
# 203      23.946107                 ZIP_95070
# 204      -8.947133                 ZIP_95110
# 205      -9.264828                 ZIP_95111
# 206     -14.996324                 ZIP_95112
# 207      -0.006929                 ZIP_95113
# 208     -15.672537                 ZIP_95116
# 209      -0.861501                 ZIP_95117
# 210      -0.047248                 ZIP_95118
# 211      -2.352194                 ZIP_95119
# 212       0.225373                 ZIP_95120
# 213      -7.561000                 ZIP_95121
# 214     -14.326965                 ZIP_95122
# 215      -6.942439                 ZIP_95123
# 216       2.380080                 ZIP_95124
# 217       0.901509                 ZIP_95125
# 218      -5.012332                 ZIP_95126
# 219     -24.502091                 ZIP_95127
# 220      -3.382420                 ZIP_95128
# 221      19.670612                 ZIP_95129
# 222       8.799950                 ZIP_95130
# 223       1.987466                 ZIP_95131
# 224      -7.073622                 ZIP_95132
# 225      -3.669778                 ZIP_95133
# 226      -1.851463                 ZIP_95134
# 227      -3.623619                 ZIP_95135
# 228      -5.257910                 ZIP_95136
# 229      -4.054670                 ZIP_95138
# 230      -5.420088                 ZIP_95139
# 231     -12.844785                 ZIP_95148
# 232      -0.553447                 ZIP_95391
# 233     -85.396964            COUNTY_ALAMEDA
# 234       8.630613      COUNTY_SAN FRANCISCO
# 235      40.839298          COUNTY_SAN MATEO
# 236      42.450883        COUNTY_SANTA CLARA

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":df_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.728830691102647
# Root Mean Squared Error: 622.8640551619656
# Alpha: 0.008737642000038414
#      Coefficients                   Feature
# 0      -99.668533                      BEDS
# 1       25.295539                     BATHS
# 2      747.181082               SQUARE FEET
# 3       56.185538                  LOT SIZE
# 4      -56.644316                YEAR BUILT
# 5      -62.647432                 HOA/MONTH
# 6        0.000000                       LOT
# 7      -26.304741                       HOA
# 8       -9.031371       PROPERTY TYPE_Condo
# 9        0.000000         PROPERTY TYPE_SFH
# 10       0.611470          PROPERTY TYPE_TH
# 11       0.000000              CITY_ALAMEDA
# 12      18.827265               CITY_ALBANY
# 13     273.845805             CITY_ATHERTON
# 14       5.962463              CITY_BELMONT
# 15       0.509331             CITY_BERKELEY
# 16     -20.189776             CITY_BRISBANE
# 17      -2.968429            CITY_BROADMOOR
# 18       0.000000           CITY_BURLINGAME
# 19      -0.957770             CITY_CAMPBELL
# 20       0.000000        CITY_CASTRO VALLEY
# 21      -1.443725                CITY_COLMA
# 22      41.247844            CITY_CUPERTINO
# 23     -34.757339            CITY_DALY CITY
# 24      -9.838873               CITY_DUBLIN
# 25     -29.553835       CITY_EAST PALO ALTO
# 26      -0.000000           CITY_EL GRANADA
# 27       0.000000        CITY_EMERALD HILLS
# 28       5.010991           CITY_EMERYVILLE
# 29       6.541981          CITY_FOSTER CITY
# 30      21.167725              CITY_FREMONT
# 31    -106.670331               CITY_GILROY
# 32      -4.093134        CITY_HALF MOON BAY
# 33     -25.843897              CITY_HAYWARD
# 34      70.163717         CITY_HILLSBOROUGH
# 35     -15.738105             CITY_LA HONDA
# 36     -21.711064            CITY_LIVERMORE
# 37      -7.026783             CITY_LOMA MAR
# 38     134.407018            CITY_LOS ALTOS
# 39     115.157309      CITY_LOS ALTOS HILLS
# 40       0.000000            CITY_LOS GATOS
# 41     110.270019           CITY_MENLO PARK
# 42       3.447197             CITY_MILLBRAE
# 43     -31.205443             CITY_MILPITAS
# 44     -21.551427              CITY_MONTARA
# 45       9.289855         CITY_MONTE SERENO
# 46     -78.606116          CITY_MORGAN HILL
# 47     -15.366624           CITY_MOSS BEACH
# 48      39.644584        CITY_MOUNTAIN VIEW
# 49       0.000000               CITY_NEWARK
# 50     -15.205949              CITY_OAKLAND
# 51     -18.895205             CITY_PACIFICA
# 52     172.325439            CITY_PALO ALTO
# 53     -11.497487            CITY_PESCADERO
# 54      29.206561             CITY_PIEDMONT
# 55      -0.000000           CITY_PLEASANTON
# 56      83.024448       CITY_PORTOLA VALLEY
# 57       0.000000         CITY_REDWOOD CITY
# 58     -19.426754            CITY_SAN BRUNO
# 59      35.758794           CITY_SAN CARLOS
# 60       0.000000        CITY_SAN FRANCISCO
# 61      -4.802372         CITY_SAN GREGORIO
# 62     -28.385916             CITY_SAN JOSE
# 63     -22.379918          CITY_SAN LEANDRO
# 64      -1.772280          CITY_SAN LORENZO
# 65     -10.124060           CITY_SAN MARTIN
# 66       0.000000            CITY_SAN MATEO
# 67       0.000000          CITY_SANTA CLARA
# 68      49.397680             CITY_SARATOGA
# 69     -31.566695  CITY_SOUTH SAN FRANCISCO
# 70      -0.000000             CITY_STANFORD
# 71      20.962268            CITY_SUNNYVALE
# 72      -0.000000                CITY_SUNOL
# 73     -13.051074           CITY_UNION CITY
# 74     133.406731             CITY_WOODSIDE
# 75      11.063318                 ZIP_94002
# 76      -0.868312                 ZIP_94005
# 77      63.204749                 ZIP_94010
# 78      -9.295406                 ZIP_94014
# 79      -0.000000                 ZIP_94015
# 80     -20.662787                 ZIP_94018
# 81     -48.435536                 ZIP_94019
# 82      -0.534011                 ZIP_94020
# 83      -0.210756                 ZIP_94021
# 84      21.762249                 ZIP_94022
# 85       0.000000                 ZIP_94024
# 86      11.875181                 ZIP_94025
# 87      11.841429                 ZIP_94027
# 88       0.000000                 ZIP_94028
# 89       4.506349                 ZIP_94030
# 90      -0.545421                 ZIP_94037
# 91      -0.433136                 ZIP_94038
# 92      14.868252                 ZIP_94040
# 93       8.659272                 ZIP_94041
# 94       0.000000                 ZIP_94043
# 95     -11.881846                 ZIP_94044
# 96      -0.334385                 ZIP_94060
# 97      16.467949                 ZIP_94061
# 98      19.129078                 ZIP_94062
# 99      -4.174174                 ZIP_94063
# 100     12.929157                 ZIP_94065
# 101     -2.025291                 ZIP_94066
# 102      2.628805                 ZIP_94070
# 103     -0.182751                 ZIP_94074
# 104     -0.000000                 ZIP_94080
# 105     -0.000000                 ZIP_94085
# 106      4.280494                 ZIP_94086
# 107     35.817267                 ZIP_94087
# 108     13.594892                 ZIP_94089
# 109     -0.000000                 ZIP_94102
# 110     -0.000000                 ZIP_94103
# 111      5.860253                 ZIP_94105
# 112      5.092150                 ZIP_94107
# 113     10.247907                 ZIP_94109
# 114     16.233093                 ZIP_94110
# 115     -0.276744                 ZIP_94111
# 116    -13.577926                 ZIP_94112
# 117     26.545581                 ZIP_94114
# 118      3.794792                 ZIP_94115
# 119     -0.000000                 ZIP_94116
# 120     10.027568                 ZIP_94117
# 121     23.890043                 ZIP_94118
# 122     -0.000000                 ZIP_94121
# 123     -0.191017                 ZIP_94122
# 124     38.864285                 ZIP_94123
# 125    -11.823654                 ZIP_94124
# 126      6.181929                 ZIP_94127
# 127     23.511286                 ZIP_94131
# 128     -0.000000                 ZIP_94132
# 129     -0.000000                 ZIP_94133
# 130     -6.232628                 ZIP_94134
# 131     67.788256                 ZIP_94301
# 132      0.000000                 ZIP_94303
# 133     -0.000000                 ZIP_94304
# 134     -0.000000                 ZIP_94305
# 135    -11.553251                 ZIP_94306
# 136     -0.000000                 ZIP_94401
# 137     31.883524                 ZIP_94402
# 138     12.775212                 ZIP_94403
# 139     11.467654                 ZIP_94404
# 140     -0.000000                 ZIP_94501
# 141      6.443077                 ZIP_94502
# 142      0.000000                 ZIP_94536
# 143      4.748395                 ZIP_94538
# 144     14.484755                 ZIP_94539
# 145     -4.610050                 ZIP_94541
# 146    -36.039845                 ZIP_94542
# 147      0.000000                 ZIP_94544
# 148      0.000000                 ZIP_94545
# 149     -6.627073                 ZIP_94546
# 150    -22.285412                 ZIP_94550
# 151     -0.000000                 ZIP_94551
# 152     -5.688386                 ZIP_94552
# 153     -1.604916                 ZIP_94555
# 154      0.000000                 ZIP_94560
# 155    -18.202215                 ZIP_94566
# 156    -18.043441                 ZIP_94568
# 157     -7.447833                 ZIP_94577
# 158     -0.901818                 ZIP_94578
# 159     -0.000000                 ZIP_94579
# 160      0.000000                 ZIP_94580
# 161      0.000000                 ZIP_94586
# 162     -0.965243                 ZIP_94587
# 163     -0.000000                 ZIP_94588
# 164     -7.620840                 ZIP_94601
# 165      2.406008                 ZIP_94602
# 166     -8.633329                 ZIP_94603
# 167    -12.684754                 ZIP_94605
# 168     -3.551687                 ZIP_94606
# 169     -0.000000                 ZIP_94607
# 170      4.918461                 ZIP_94608
# 171      5.090933                 ZIP_94609
# 172      2.042579                 ZIP_94610
# 173      0.000000                 ZIP_94611
# 174      0.000000                 ZIP_94612
# 175      4.534961                 ZIP_94618
# 176     -0.872804                 ZIP_94619
# 177     -7.790423                 ZIP_94621
# 178     13.314967                 ZIP_94702
# 179      1.435133                 ZIP_94703
# 180      3.929217                 ZIP_94704
# 181     -0.000000                 ZIP_94705
# 182      0.000000                 ZIP_94706
# 183      6.056591                 ZIP_94707
# 184     -1.690741                 ZIP_94708
# 185      0.000000                 ZIP_94709
# 186      8.946821                 ZIP_94710
# 187     -0.000000                 ZIP_94979
# 188     -0.852785                 ZIP_94980
# 189     -0.000000                 ZIP_95002
# 190     -1.053864                 ZIP_95008
# 191     13.812327                 ZIP_95014
# 192     -2.782820                 ZIP_95020
# 193      3.890350                 ZIP_95025
# 194     24.299408                 ZIP_95030
# 195     16.364674                 ZIP_95032
# 196    -31.768899                 ZIP_95033
# 197     -2.563167                 ZIP_95035
# 198     -2.378724                 ZIP_95037
# 199     -0.269586                 ZIP_95046
# 200     -6.355832                 ZIP_95050
# 201     15.245091                 ZIP_95051
# 202      0.000000                 ZIP_95054
# 203      4.379438                 ZIP_95070
# 204     -3.613813                 ZIP_95110
# 205     -4.418841                 ZIP_95111
# 206     -9.323080                 ZIP_95112
# 207      0.000000                 ZIP_95113
# 208    -10.526657                 ZIP_95116
# 209      0.888793                 ZIP_95117
# 210      1.953263                 ZIP_95118
# 211     -0.000000                 ZIP_95119
# 212      0.793438                 ZIP_95120
# 213     -3.835053                 ZIP_95121
# 214     -8.743458                 ZIP_95122
# 215     -0.204106                 ZIP_95123
# 216      6.392161                 ZIP_95124
# 217      4.703497                 ZIP_95125
# 218     -0.000000                 ZIP_95126
# 219    -17.882703                 ZIP_95127
# 220      0.541787                 ZIP_95128
# 221     22.684791                 ZIP_95129
# 222     11.343781                 ZIP_95130
# 223      2.845306                 ZIP_95131
# 224     -1.527428                 ZIP_95132
# 225     -0.000000                 ZIP_95133
# 226     -0.000000                 ZIP_95134
# 227     -0.162656                 ZIP_95135
# 228     -1.362817                 ZIP_95136
# 229     -0.879952                 ZIP_95138
# 230     -2.439241                 ZIP_95139
# 231     -9.104781                 ZIP_95148
# 232      0.000000                 ZIP_95391
# 233   -187.187885            COUNTY_ALAMEDA
# 234      0.000000      COUNTY_SAN FRANCISCO
# 235      0.000000          COUNTY_SAN MATEO
# 236      0.000000        COUNTY_SANTA CLARA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32307 entries, 115 to 32413
# Data columns (total 13 columns):
# PROPERTY TYPE    32307 non-null object
# CITY             32307 non-null object
# ZIP              32307 non-null object
# PRICE IN K       32307 non-null float64
# BEDS             32307 non-null float64
# BATHS            32307 non-null float64
# SQUARE FEET      32307 non-null float64
# LOT SIZE         32307 non-null float64
# YEAR BUILT       32307 non-null float64
# HOA/MONTH        32307 non-null float64
# COUNTY           32307 non-null object
# LOT              32307 non-null int64
# HOA              32307 non-null int64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 4.7+ MB
