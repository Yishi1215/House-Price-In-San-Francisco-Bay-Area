# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.preprocessing import Imputer, scale
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV
from sklearn.metrics import mean_squared_error, accuracy_score
import statsmodels.api as sm
# Out:
# /Users/yishi/.ipython/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # 1. Prepare regression functions

# %%
def split(var, res, t_size, r_state):
    X_train, X_test, y_train, y_test = train_test_split(var, res, test_size=t_size, random_state=r_state)
    return X_train, X_test, y_train, y_test

# %%
def linear_regression(X_train, X_test, y_train, y_test):
    reg = LinearRegression()
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print('Simple Linear Regression')
    print('R^2: {}'.format(reg.score(X_train, y_train)))
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error: {}'.format(rmse))
    return reg.coef_

# %%
def ridge(X_train, X_test, y_train, y_test, alpha):
    regr_cv = RidgeCV(alphas=alpha, normalize=True)
    ridge = regr_cv.fit(X_train, y_train)
    ridge_pred=ridge.predict(X_test)
    print('Ridge')
    print('R^2: {}'.format(ridge.score(X_train, y_train)))
    rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))
    print('Root Mean Squared Error: {}'.format(rmse))
    print('Alpha: {}'.format(ridge.alpha_))
    return ridge.coef_

# %%
def lasso(X_train, X_test, y_train, y_test, alpha):
    regr_cv = LassoCV(alphas=alpha, normalize=True)
    lasso = regr_cv.fit(X_train, y_train)
    lasso_pred=lasso.predict(X_test)
    print('Lasso')
    print('R^2: {}'.format(lasso.score(X_train, y_train)))
    rmse = np.sqrt(mean_squared_error(y_test, lasso_pred))
    print('Root Mean Squared Error: {}'.format(rmse))
    print('Alpha: {}'.format(lasso.alpha_))
    return lasso.coef_

# %% [markdown]
# # 2. Preprocessing the data

# %%
filename = 'Preprocessing Data/cleaned_data.csv'
df = pd.read_csv(filename, index_col=0)
df['ZIP'] = df['ZIP'].astype(str)

# %% [markdown]
# ## 2.1 Seperate property type

# %%
df_sfh = df.loc[df['PROPERTY TYPE'] == 'SFH']
df_th = df.loc[df['PROPERTY TYPE'] == 'TH']
df_condo = df.loc[df['PROPERTY TYPE'] == 'Condo']

df_sfh = df_sfh.drop(['PROPERTY TYPE'], axis=1)
df_th = df_th.drop(['PROPERTY TYPE'], axis=1)
df_condo = df_condo.drop(['PROPERTY TYPE'], axis=1)

# %%
#delete some columns are not available for the specific property type
df_sfh = df_sfh.drop(['HOA/MONTH', 'COUNTY', 'CITY', 'LOT', 'HOA'], axis=1)
df_th = df_th.drop(['LOT SIZE', 'COUNTY', 'CITY', 'LOT', 'HOA'], axis=1)
df_condo = df_condo.drop(['LOT SIZE', 'COUNTY', 'CITY', 'LOT', 'HOA'], axis=1)

# %%
#encoding dummy variables
df_sfh_dummies = pd.get_dummies(df_sfh)
df_th_dummies = pd.get_dummies(df_th)
df_condo_dummies = pd.get_dummies(df_condo)
df_sfh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26792 entries, 0 to 32415
# Data columns (total 7 columns):
# ZIP            26792 non-null object
# PRICE IN K     26792 non-null float64
# BEDS           26792 non-null float64
# BATHS          26792 non-null float64
# SQUARE FEET    26792 non-null float64
# LOT SIZE       26792 non-null float64
# YEAR BUILT     26792 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 1.6+ MB

# %%
#split dataset into feature variables and results
df_sfh_y = df_sfh_dummies['PRICE IN K'].values.ravel() 
df_sfh_X = df_sfh_dummies.drop(['PRICE IN K'], axis=1)
sfh_col = df_sfh_X.columns

df_th_y = df_th_dummies['PRICE IN K'].values.ravel()
df_th_X = df_th_dummies.drop(['PRICE IN K'], axis=1)
th_col = df_th_X.columns

df_condo_y = df_condo_dummies['PRICE IN K'].values.ravel()
df_condo_X = df_condo_dummies.drop(['PRICE IN K'], axis=1)
condo_col = df_condo_X.columns

# %%
# scaling the data
df_sfh_X = scale(df_sfh_X)
df_th_X = scale(df_th_X)
df_condo_X = scale(df_condo_X)

# %% [markdown]
# ## 2.2 Use different location info but keep three property types together

# %% [markdown]
# 2.2.1 Using county as the only location info

# %%
df_county = df.drop(['CITY', 'ZIP'], axis=1)
df_county_dummies = pd.get_dummies(df_county)
#split dataset into feature variables and results
df_county_y = df_county_dummies['PRICE IN K']
df_county_X = df_county_dummies.drop(['PRICE IN K'], axis=1)
county_col = df_county_X.columns
# scaling the data
df_county_X = scale(df_county_X)

# %% [markdown]
# 2.2.2 Using city as the only location info

# %%
df_city = df.drop(['COUNTY', 'ZIP'], axis=1)
df_city_dummies = pd.get_dummies(df_city)
#split dataset into feature variables and results
df_city_y = df_city_dummies['PRICE IN K']
df_city_X = df_city_dummies.drop(['PRICE IN K'], axis=1)
city_col = df_city_X.columns
# scaling the data
df_city_X = scale(df_city_X)

# %% [markdown]
# 2.2.3 Using zip as the only location info

# %%
df_zip = df.drop(['COUNTY', 'CITY'], axis=1)
df_zip_dummies = pd.get_dummies(df_zip)
#split dataset into feature variables and results
df_zip_y = df_zip_dummies['PRICE IN K']
df_zip_X = df_zip_dummies.drop(['PRICE IN K'], axis=1)
zip_col = df_zip_X.columns
# scaling the data
df_zip_X = scale(df_zip_X)

# %% [markdown]
# ## 2.3 Keep all location info

# %%
df_dummies = pd.get_dummies(df)
df_y = df_dummies['PRICE IN K']
df_X = df_dummies.drop(['PRICE IN K'], axis=1)
df_col = df_X.columns
df_X = scale(df_X)

# %% [markdown]
# # 3. Regression

# %%
alpha = 10**np.linspace(10,-2,100)*0.5

# %% [markdown]
# ## 3.1 Based on different property type, no city or county, only zip is included for location

# %% [markdown]
# 3.1.1 Single family house

# %%
X_train, X_test, y_train, y_test = split(df_sfh_X, df_sfh_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":sfh_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7041927195308912
# Root Mean Squared Error: 615.9830443294132
#      Coefficients      Feature
# 0   -1.307868e+02         BEDS
# 1   -2.362748e-01        BATHS
# 2    8.433540e-01  SQUARE FEET
# 3    5.599712e-04     LOT SIZE
# 4   -3.217444e+00   YEAR BUILT
# 5    2.270818e+02    ZIP_94002
# 6   -3.033014e+02    ZIP_94005
# 7    7.847612e+02    ZIP_94010
# 8   -3.405534e+02    ZIP_94014
# 9   -1.622065e+02    ZIP_94015
# 10  -3.890893e+02    ZIP_94018
# 11  -4.197681e+02    ZIP_94019
# 12  -4.878419e+02    ZIP_94020
# 13  -4.681790e+02    ZIP_94021
# 14   1.403537e+03    ZIP_94022
# 15   1.111887e+03    ZIP_94024
# 16   8.815454e+02    ZIP_94025
# 17   3.533076e+03    ZIP_94027
# 18   9.001956e+02    ZIP_94028
# 19   1.320037e+02    ZIP_94030
# 20  -3.133331e+02    ZIP_94037
# 21  -2.798800e+02    ZIP_94038
# 22   8.710829e+02    ZIP_94040
# 23   5.447080e+02    ZIP_94041
# 24   6.032451e+02    ZIP_94043
# 25  -1.715597e+02    ZIP_94044
# 26  -1.749677e+02    ZIP_94060
# 27   2.430548e+02    ZIP_94061
# 28   8.410397e+02    ZIP_94062
# 29  -6.575653e+01    ZIP_94063
# 30   2.815802e+02    ZIP_94065
# 31  -1.407670e+02    ZIP_94066
# 32   3.170787e+02    ZIP_94070
# 33  -7.826987e+02    ZIP_94074
# 34  -2.109198e+02    ZIP_94080
# 35   1.895340e+02    ZIP_94085
# 36   3.752900e+02    ZIP_94086
# 37   7.236795e+02    ZIP_94087
# 38   7.063729e+02    ZIP_94089
# 39   1.700077e+02    ZIP_94102
# 40  -1.065702e+02    ZIP_94103
# 41   2.248931e+02    ZIP_94107
# 42   1.263359e+03    ZIP_94109
# 43   4.850093e+02    ZIP_94110
# 44  -1.905375e+02    ZIP_94112
# 45   8.013479e+02    ZIP_94114
# 46   4.872705e+02    ZIP_94115
# 47   2.530864e+01    ZIP_94116
# 48   5.386231e+02    ZIP_94117
# 49   1.498924e+03    ZIP_94118
# 50   8.015365e+01    ZIP_94121
# 51  -1.260184e+01    ZIP_94122
# 52   2.410902e+03    ZIP_94123
# 53  -2.626566e+02    ZIP_94124
# 54   2.644486e+02    ZIP_94127
# 55   6.148845e+02    ZIP_94131
# 56   1.630235e+01    ZIP_94132
# 57  -1.453122e+02    ZIP_94134
# 58   2.661171e+03    ZIP_94301
# 59   2.856378e+02    ZIP_94303
# 60   1.144911e+03    ZIP_94304
# 61  -3.607094e+02    ZIP_94305
# 62   1.346193e+03    ZIP_94306
# 63  -8.407972e+00    ZIP_94401
# 64   3.183801e+02    ZIP_94402
# 65   1.747053e+02    ZIP_94403
# 66   2.013525e+02    ZIP_94404
# 67  -4.405389e+02    ZIP_94501
# 68  -3.143268e+02    ZIP_94502
# 69  -2.355849e+02    ZIP_94536
# 70  -1.366743e+02    ZIP_94538
# 71  -7.086704e+01    ZIP_94539
# 72  -5.802358e+02    ZIP_94541
# 73  -1.134167e+03    ZIP_94542
# 74  -4.777138e+02    ZIP_94544
# 75  -4.763777e+02    ZIP_94545
# 76  -6.082240e+02    ZIP_94546
# 77  -6.265080e+02    ZIP_94550
# 78  -4.609773e+02    ZIP_94551
# 79  -9.219210e+02    ZIP_94552
# 80  -2.679681e+02    ZIP_94555
# 81  -3.388434e+02    ZIP_94560
# 82  -5.915556e+02    ZIP_94566
# 83  -6.003271e+02    ZIP_94568
# 84  -5.834769e+02    ZIP_94577
# 85  -5.084999e+02    ZIP_94578
# 86  -4.644206e+02    ZIP_94579
# 87  -3.735477e+02    ZIP_94580
# 88   2.177931e-13    ZIP_94584
# 89  -6.286471e+02    ZIP_94586
# 90  -4.681215e+02    ZIP_94587
# 91  -4.332526e+02    ZIP_94588
# 92  -6.121832e+02    ZIP_94601
# 93  -3.970614e+02    ZIP_94602
# 94  -5.576895e+02    ZIP_94603
# 95  -6.009673e+02    ZIP_94605
# 96  -5.704507e+02    ZIP_94606
# 97  -5.405196e+02    ZIP_94607
# 98  -4.065664e+02    ZIP_94608
# 99  -2.783754e+02    ZIP_94609
# 100 -1.838772e+02    ZIP_94610
# 101 -2.084080e+02    ZIP_94611
# 102 -4.642251e+02    ZIP_94612
# 103 -2.194408e+02    ZIP_94618
# 104 -4.868866e+02    ZIP_94619
# 105 -6.056935e+02    ZIP_94621
# 106 -1.638128e+02    ZIP_94702
# 107 -3.138375e+02    ZIP_94703
# 108 -3.372613e+02    ZIP_94704
# 109 -4.757762e+02    ZIP_94705
# 110 -1.689352e+02    ZIP_94706
# 111 -2.895347e+02    ZIP_94707
# 112 -4.281194e+02    ZIP_94708
# 113 -4.292047e+02    ZIP_94709
# 114 -5.992296e+01    ZIP_94710
# 115 -5.016299e+02    ZIP_94979
# 116 -4.830781e+02    ZIP_94980
# 117 -8.514259e+01    ZIP_95002
# 118  5.284649e+01    ZIP_95008
# 119  5.976139e+02    ZIP_95014
# 120 -6.755858e+02    ZIP_95020
# 121  1.670270e+03    ZIP_95025
# 122  3.302531e+02    ZIP_95030
# 123  2.527038e+02    ZIP_95032
# 124 -4.722885e+02    ZIP_95033
# 125 -2.086624e+02    ZIP_95035
# 126 -5.600763e+02    ZIP_95037
# 127 -7.463895e+02    ZIP_95046
# 128 -1.480439e+00    ZIP_95050
# 129  3.331856e+02    ZIP_95051
# 130 -2.752904e+01    ZIP_95054
# 131  5.283134e+02    ZIP_95070
# 132 -3.279668e+02    ZIP_95110
# 133 -2.336442e+02    ZIP_95111
# 134 -3.855300e+02    ZIP_95112
# 135 -3.795379e+02    ZIP_95116
# 136 -1.891540e+01    ZIP_95117
# 137  9.076683e+01    ZIP_95118
# 138 -1.004937e+02    ZIP_95119
# 139  5.581063e+01    ZIP_95120
# 140 -2.762808e+02    ZIP_95121
# 141 -2.380543e+02    ZIP_95122
# 142 -9.176292e+01    ZIP_95123
# 143  1.349614e+02    ZIP_95124
# 144  3.632443e+00    ZIP_95125
# 145 -1.570315e+02    ZIP_95126
# 146 -3.550026e+02    ZIP_95127
# 147 -9.635190e+01    ZIP_95128
# 148  5.847588e+02    ZIP_95129
# 149  2.402882e+02    ZIP_95130
# 150  2.672214e+02    ZIP_95131
# 151 -9.275706e+01    ZIP_95132
# 152 -4.273583e+02    ZIP_95133
# 153 -4.125562e+02    ZIP_95135
# 154 -1.833447e+02    ZIP_95136
# 155 -1.743703e+02    ZIP_95138
# 156 -1.210823e+02    ZIP_95139
# 157 -3.223998e+02    ZIP_95148
# 158 -3.317173e+02    ZIP_95391

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":sfh_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7041525091991406
# Root Mean Squared Error: 615.1894093126468
# Alpha: 0.005
#      Coefficients      Feature
# 0     -126.347067         BEDS
# 1        9.561111        BATHS
# 2        0.827860  SQUARE FEET
# 3        0.000564     LOT SIZE
# 4       -3.185660   YEAR BUILT
# 5      218.657736    ZIP_94002
# 6     -308.726934    ZIP_94005
# 7      781.217894    ZIP_94010
# 8     -346.744321    ZIP_94014
# 9     -172.592256    ZIP_94015
# 10    -394.040929    ZIP_94018
# 11    -422.492572    ZIP_94019
# 12    -489.834850    ZIP_94020
# 13    -475.742770    ZIP_94021
# 14    1396.401402    ZIP_94022
# 15    1103.318951    ZIP_94024
# 16     870.787297    ZIP_94025
# 17    3530.217881    ZIP_94027
# 18     897.603180    ZIP_94028
# 19     125.455576    ZIP_94030
# 20    -317.921088    ZIP_94037
# 21    -284.429348    ZIP_94038
# 22     859.442242    ZIP_94040
# 23     538.025808    ZIP_94041
# 24     590.753094    ZIP_94043
# 25    -180.592548    ZIP_94044
# 26    -179.009062    ZIP_94060
# 27     233.739013    ZIP_94061
# 28     838.475447    ZIP_94062
# 29     -71.634783    ZIP_94063
# 30     271.420526    ZIP_94065
# 31    -150.241703    ZIP_94066
# 32     309.695571    ZIP_94070
# 33    -781.266163    ZIP_94074
# 34    -218.694692    ZIP_94080
# 35     181.613028    ZIP_94085
# 36     366.886460    ZIP_94086
# 37     710.845830    ZIP_94087
# 38     690.050505    ZIP_94089
# 39     164.340224    ZIP_94102
# 40    -101.188136    ZIP_94103
# 41     220.865018    ZIP_94107
# 42    1254.504404    ZIP_94109
# 43     475.217720    ZIP_94110
# 44    -196.358435    ZIP_94112
# 45     791.771731    ZIP_94114
# 46     482.455237    ZIP_94115
# 47      20.102381    ZIP_94116
# 48     537.197813    ZIP_94117
# 49    1489.983365    ZIP_94118
# 50      77.596583    ZIP_94121
# 51     -16.696870    ZIP_94122
# 52    2400.087475    ZIP_94123
# 53    -268.362899    ZIP_94124
# 54     258.075279    ZIP_94127
# 55     605.639272    ZIP_94131
# 56       9.388853    ZIP_94132
# 57    -152.780607    ZIP_94134
# 58    2644.787660    ZIP_94301
# 59     275.973657    ZIP_94303
# 60    1131.858024    ZIP_94304
# 61    -343.950446    ZIP_94305
# 62    1332.493161    ZIP_94306
# 63     -15.248451    ZIP_94401
# 64     312.057587    ZIP_94402
# 65     165.706946    ZIP_94403
# 66     192.517039    ZIP_94404
# 67    -442.655322    ZIP_94501
# 68    -321.205943    ZIP_94502
# 69    -245.327515    ZIP_94536
# 70    -148.982714    ZIP_94538
# 71     -79.380176    ZIP_94539
# 72    -585.022229    ZIP_94541
# 73   -1131.561756    ZIP_94542
# 74    -485.495554    ZIP_94544
# 75    -486.647281    ZIP_94545
# 76    -611.448605    ZIP_94546
# 77    -631.663295    ZIP_94550
# 78    -469.284865    ZIP_94551
# 79    -920.476541    ZIP_94552
# 80    -278.324708    ZIP_94555
# 81    -348.870923    ZIP_94560
# 82    -593.026741    ZIP_94566
# 83    -607.362356    ZIP_94568
# 84    -585.482959    ZIP_94577
# 85    -513.142570    ZIP_94578
# 86    -471.067425    ZIP_94579
# 87    -380.384519    ZIP_94580
# 88       0.000000    ZIP_94584
# 89    -637.282183    ZIP_94586
# 90    -477.029546    ZIP_94587
# 91    -439.015757    ZIP_94588
# 92    -613.639565    ZIP_94601
# 93    -398.801631    ZIP_94602
# 94    -560.912647    ZIP_94603
# 95    -603.554916    ZIP_94605
# 96    -572.918404    ZIP_94606
# 97    -547.432609    ZIP_94607
# 98    -410.689946    ZIP_94608
# 99    -285.068649    ZIP_94609
# 100   -184.454482    ZIP_94610
# 101   -207.813485    ZIP_94611
# 102   -467.745351    ZIP_94612
# 103   -217.865468    ZIP_94618
# 104   -489.492901    ZIP_94619
# 105   -610.228530    ZIP_94621
# 106   -167.565452    ZIP_94702
# 107   -316.040289    ZIP_94703
# 108   -341.206746    ZIP_94704
# 109   -473.974781    ZIP_94705
# 110   -173.794083    ZIP_94706
# 111   -289.756458    ZIP_94707
# 112   -431.030439    ZIP_94708
# 113   -429.184482    ZIP_94709
# 114    -68.283249    ZIP_94710
# 115   -499.484105    ZIP_94979
# 116   -500.569206    ZIP_94980
# 117    -92.634688    ZIP_95002
# 118     44.309217    ZIP_95008
# 119    586.266295    ZIP_95014
# 120   -679.523610    ZIP_95020
# 121   1660.845642    ZIP_95025
# 122    328.022187    ZIP_95030
# 123    245.900755    ZIP_95032
# 124   -474.006685    ZIP_95033
# 125   -219.128405    ZIP_95035
# 126   -564.170076    ZIP_95037
# 127   -744.727504    ZIP_95046
# 128     -7.208413    ZIP_95050
# 129    321.294160    ZIP_95051
# 130    -38.013327    ZIP_95054
# 131    522.206632    ZIP_95070
# 132   -328.583844    ZIP_95110
# 133   -242.837520    ZIP_95111
# 134   -385.412788    ZIP_95112
# 135   -382.581464    ZIP_95116
# 136    -28.517322    ZIP_95117
# 137     79.229762    ZIP_95118
# 138   -106.076217    ZIP_95119
# 139     49.577305    ZIP_95120
# 140   -284.582919    ZIP_95121
# 141   -246.834550    ZIP_95122
# 142   -102.041887    ZIP_95123
# 143    124.836891    ZIP_95124
# 144      1.013773    ZIP_95125
# 145   -158.311983    ZIP_95126
# 146   -357.484847    ZIP_95127
# 147   -101.063272    ZIP_95128
# 148    570.835726    ZIP_95129
# 149    227.741703    ZIP_95130
# 150    254.935145    ZIP_95131
# 151   -103.285689    ZIP_95132
# 152   -435.712421    ZIP_95133
# 153   -415.967540    ZIP_95135
# 154   -193.005266    ZIP_95136
# 155   -182.162969    ZIP_95138
# 156   -131.883084    ZIP_95139
# 157   -330.895207    ZIP_95148
# 158   -341.465873    ZIP_95391

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":sfh_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7041161604290995
# Root Mean Squared Error: 615.5369161199044
# Alpha: 0.006609705742330144
#      Coefficients      Feature
# 0     -127.777663         BEDS
# 1        0.000000        BATHS
# 2        0.840700  SQUARE FEET
# 3        0.000550     LOT SIZE
# 4       -3.204548   YEAR BUILT
# 5      388.071574    ZIP_94002
# 6     -119.743271    ZIP_94005
# 7      948.642429    ZIP_94010
# 8     -162.744450    ZIP_94014
# 9        0.000000    ZIP_94015
# 10    -202.500065    ZIP_94018
# 11    -243.823722    ZIP_94019
# 12    -296.667740    ZIP_94020
# 13    -240.081224    ZIP_94021
# 14    1565.766813    ZIP_94022
# 15    1272.215293    ZIP_94024
# 16    1044.085201    ZIP_94025
# 17    3695.077168    ZIP_94027
# 18    1060.350696    ZIP_94028
# 19     292.352178    ZIP_94030
# 20    -129.795097    ZIP_94037
# 21     -94.450532    ZIP_94038
# 22    1023.590806    ZIP_94040
# 23     694.348836    ZIP_94041
# 24     755.330009    ZIP_94043
# 25      -0.000000    ZIP_94044
# 26      -0.000000    ZIP_94060
# 27     404.016212    ZIP_94061
# 28    1004.965628    ZIP_94062
# 29      90.529128    ZIP_94063
# 30     425.855053    ZIP_94065
# 31      19.259276    ZIP_94066
# 32     479.718198    ZIP_94070
# 33    -537.833092    ZIP_94074
# 34     -36.015894    ZIP_94080
# 35     343.120110    ZIP_94085
# 36     528.840673    ZIP_94086
# 37     880.755133    ZIP_94087
# 38     846.066987    ZIP_94089
# 39     239.543328    ZIP_94102
# 40       0.000000    ZIP_94103
# 41     324.146809    ZIP_94107
# 42    1352.301671    ZIP_94109
# 43     632.669734    ZIP_94110
# 44      -8.448816    ZIP_94112
# 45     944.718504    ZIP_94114
# 46     604.200853    ZIP_94115
# 47     175.068371    ZIP_94116
# 48     660.447651    ZIP_94117
# 49    1625.642429    ZIP_94118
# 50     216.987431    ZIP_94121
# 51     134.977091    ZIP_94122
# 52    2537.523124    ZIP_94123
# 53     -70.574148    ZIP_94124
# 54     412.349241    ZIP_94127
# 55     766.455136    ZIP_94131
# 56     156.805727    ZIP_94132
# 57       1.566825    ZIP_94134
# 58    2816.217823    ZIP_94301
# 59     446.570132    ZIP_94303
# 60    1263.404274    ZIP_94304
# 61     -47.288430    ZIP_94305
# 62    1503.384638    ZIP_94306
# 63     149.121305    ZIP_94401
# 64     478.316831    ZIP_94402
# 65     334.994533    ZIP_94403
# 66     358.816404    ZIP_94404
# 67    -264.158474    ZIP_94501
# 68    -132.758276    ZIP_94502
# 69     -59.152629    ZIP_94536
# 70      20.584691    ZIP_94538
# 71      86.980979    ZIP_94539
# 72    -403.451275    ZIP_94541
# 73    -951.788194    ZIP_94542
# 74    -301.245695    ZIP_94544
# 75    -298.004040    ZIP_94545
# 76    -416.870886    ZIP_94546
# 77    -452.265507    ZIP_94550
# 78    -286.141915    ZIP_94551
# 79    -715.255508    ZIP_94552
# 80     -90.696278    ZIP_94555
# 81    -165.142283    ZIP_94560
# 82    -415.740967    ZIP_94566
# 83    -425.835649    ZIP_94568
# 84    -406.393744    ZIP_94577
# 85    -329.739514    ZIP_94578
# 86    -281.825643    ZIP_94579
# 87    -185.565958    ZIP_94580
# 88       0.000000    ZIP_94584
# 89    -360.580216    ZIP_94586
# 90    -294.621594    ZIP_94587
# 91    -256.490308    ZIP_94588
# 92    -425.341012    ZIP_94601
# 93    -211.839151    ZIP_94602
# 94    -375.573579    ZIP_94603
# 95    -420.776729    ZIP_94605
# 96    -377.955998    ZIP_94606
# 97    -339.564780    ZIP_94607
# 98    -220.058163    ZIP_94608
# 99     -85.221492    ZIP_94609
# 100     -1.284255    ZIP_94610
# 101    -29.650425    ZIP_94611
# 102   -232.447299    ZIP_94612
# 103    -24.175172    ZIP_94618
# 104   -302.311169    ZIP_94619
# 105   -419.199476    ZIP_94621
# 106      0.000000    ZIP_94702
# 107   -129.294972    ZIP_94703
# 108   -124.952066    ZIP_94704
# 109   -290.800702    ZIP_94705
# 110      0.000000    ZIP_94706
# 111   -106.537780    ZIP_94707
# 112   -245.742540    ZIP_94708
# 113   -226.392011    ZIP_94709
# 114     84.593252    ZIP_94710
# 115   -191.308169    ZIP_94979
# 116   -175.700881    ZIP_94980
# 117      2.008076    ZIP_95002
# 118    213.203033    ZIP_95008
# 119    757.151194    ZIP_95014
# 120   -501.832517    ZIP_95020
# 121   1699.490874    ZIP_95025
# 122    490.634325    ZIP_95030
# 123    411.976454    ZIP_95032
# 124   -288.571412    ZIP_95033
# 125    -34.086033    ZIP_95035
# 126   -385.146000    ZIP_95037
# 127   -523.374529    ZIP_95046
# 128    157.094535    ZIP_95050
# 129    489.833664    ZIP_95051
# 130    114.159682    ZIP_95054
# 131    689.762332    ZIP_95070
# 132   -133.236925    ZIP_95110
# 133    -35.663800    ZIP_95111
# 134   -197.053487    ZIP_95112
# 135   -189.385226    ZIP_95116
# 136    117.980773    ZIP_95117
# 137    231.138646    ZIP_95118
# 138     25.419363    ZIP_95119
# 139    192.572704    ZIP_95120
# 140    -76.185981    ZIP_95121
# 141    -52.504309    ZIP_95122
# 142     48.707720    ZIP_95123
# 143    288.519945    ZIP_95124
# 144    159.844524    ZIP_95125
# 145      0.000000    ZIP_95126
# 146   -172.822890    ZIP_95127
# 147     58.708731    ZIP_95128
# 148    731.481834    ZIP_95129
# 149    389.570507    ZIP_95130
# 150    381.539176    ZIP_95131
# 151     49.325790    ZIP_95132
# 152   -215.550045    ZIP_95133
# 153   -191.465624    ZIP_95135
# 154     -0.000000    ZIP_95136
# 155     -0.000000    ZIP_95138
# 156      0.000000    ZIP_95139
# 157   -126.101301    ZIP_95148
# 158    -21.855773    ZIP_95391

# %% [markdown]
# 3.1.2 Townhouse

# %%
X_train, X_test, y_train, y_test = split(df_th_X, df_th_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":th_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.8461298173827818
# Root Mean Squared Error: 163.76773608514355
#      Coefficients      Feature
# 0    2.227403e+01         BEDS
# 1    8.950949e+01        BATHS
# 2    3.536231e-01  SQUARE FEET
# 3    2.646931e+00   YEAR BUILT
# 4    8.098575e-02    HOA/MONTH
# 5    1.266337e+02    ZIP_94002
# 6   -1.481966e+02    ZIP_94005
# 7    2.169163e+02    ZIP_94010
# 8   -4.803867e+01    ZIP_94014
# 9   -1.849877e+02    ZIP_94015
# 10  -1.259130e+02    ZIP_94019
# 11   8.109871e+02    ZIP_94022
# 12   4.735172e+02    ZIP_94024
# 13   6.897360e+02    ZIP_94025
# 14   4.780338e+02    ZIP_94040
# 15   5.211858e+02    ZIP_94041
# 16   3.312900e+02    ZIP_94043
# 17  -1.050380e+02    ZIP_94044
# 18   1.040715e+02    ZIP_94061
# 19  -3.664839e-13    ZIP_94062
# 20   2.178049e+02    ZIP_94063
# 21   3.348052e+02    ZIP_94065
# 22   1.652288e+02    ZIP_94070
# 23  -1.140416e+02    ZIP_94080
# 24   1.607444e+02    ZIP_94085
# 25   2.202550e+02    ZIP_94086
# 26   2.609736e+02    ZIP_94087
# 27   1.806021e+02    ZIP_94089
# 28   1.118084e-13    ZIP_94102
# 29  -5.681576e+01    ZIP_94111
# 30  -2.654746e+02    ZIP_94124
# 31   6.409390e+00    ZIP_94131
# 32   1.799017e+03    ZIP_94133
# 33  -7.546733e+02    ZIP_94134
# 34   9.259681e+02    ZIP_94301
# 35   5.519752e+02    ZIP_94303
# 36   7.439546e+02    ZIP_94306
# 37   3.918031e+01    ZIP_94401
# 38   2.033886e+02    ZIP_94402
# 39   3.152994e+02    ZIP_94403
# 40   2.301089e+02    ZIP_94404
# 41  -1.595220e+02    ZIP_94501
# 42  -2.370634e+02    ZIP_94502
# 43  -1.439496e+02    ZIP_94536
# 44  -1.484071e+02    ZIP_94538
# 45   1.202729e+01    ZIP_94539
# 46  -4.305295e+02    ZIP_94541
# 47  -4.026708e+02    ZIP_94544
# 48  -3.056771e+02    ZIP_94545
# 49  -3.769089e+02    ZIP_94550
# 50  -3.651114e+02    ZIP_94551
# 51  -2.121402e+02    ZIP_94552
# 52  -1.304251e+02    ZIP_94555
# 53  -2.896013e+02    ZIP_94560
# 54  -1.846831e+02    ZIP_94566
# 55  -2.769205e+02    ZIP_94568
# 56  -3.850033e+02    ZIP_94577
# 57  -3.406668e+02    ZIP_94578
# 58  -3.446987e+02    ZIP_94579
# 59  -2.766934e+02    ZIP_94586
# 60  -2.604927e+02    ZIP_94587
# 61  -2.277806e+02    ZIP_94588
# 62  -4.646343e+02    ZIP_94603
# 63  -4.599290e+02    ZIP_94605
# 64  -4.015206e+02    ZIP_94606
# 65  -1.822909e+02    ZIP_94608
# 66  -1.558542e+02    ZIP_94618
# 67  -3.324897e+02    ZIP_94619
# 68   1.350309e+02    ZIP_94703
# 69  -2.685628e+01    ZIP_94706
# 70   3.609472e+02    ZIP_94709
# 71  -3.891889e+01    ZIP_95008
# 72   3.682373e+02    ZIP_95014
# 73  -3.670950e+02    ZIP_95020
# 74   2.191653e+02    ZIP_95030
# 75   1.584590e+02    ZIP_95032
# 76  -1.469296e+02    ZIP_95035
# 77  -3.352519e+02    ZIP_95037
# 78   8.018797e+01    ZIP_95050
# 79   3.342964e+02    ZIP_95051
# 80   1.935897e+02    ZIP_95054
# 81   3.711117e+02    ZIP_95070
# 82   1.709166e+01    ZIP_95110
# 83  -1.937759e+02    ZIP_95111
# 84  -2.975511e+01    ZIP_95112
# 85  -2.511504e+02    ZIP_95116
# 86   7.617152e+01    ZIP_95117
# 87  -5.630994e+01    ZIP_95118
# 88  -1.506420e+02    ZIP_95119
# 89   4.872329e+01    ZIP_95120
# 90  -1.793365e+02    ZIP_95121
# 91  -1.989290e+02    ZIP_95122
# 92  -1.311076e+02    ZIP_95123
# 93  -5.486859e+01    ZIP_95124
# 94   1.918970e+01    ZIP_95125
# 95  -4.542028e+01    ZIP_95126
# 96  -1.384100e+02    ZIP_95127
# 97   1.066772e+02    ZIP_95128
# 98   4.653990e+02    ZIP_95129
# 99  -1.860825e+02    ZIP_95130
# 100 -6.866836e+01    ZIP_95131
# 101 -1.164084e+02    ZIP_95132
# 102 -9.122705e+01    ZIP_95133
# 103 -7.387683e+01    ZIP_95134
# 104 -2.458943e+02    ZIP_95136
# 105 -2.566254e+02    ZIP_95138
# 106 -1.603470e+02    ZIP_95139
# 107 -2.316621e+02    ZIP_95148

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":th_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.8460431758761436
# Root Mean Squared Error: 163.23280234129493
# Alpha: 0.01155064850041579
#      Coefficients      Feature
# 0       22.951711         BEDS
# 1       90.709954        BATHS
# 2        0.347337  SQUARE FEET
# 3        2.621867   YEAR BUILT
# 4        0.098677    HOA/MONTH
# 5      122.703372    ZIP_94002
# 6     -146.970489    ZIP_94005
# 7      211.787923    ZIP_94010
# 8      -50.084589    ZIP_94014
# 9     -185.170098    ZIP_94015
# 10    -127.067480    ZIP_94019
# 11     800.332094    ZIP_94022
# 12     461.936847    ZIP_94024
# 13     681.274265    ZIP_94025
# 14     469.207459    ZIP_94040
# 15     512.963756    ZIP_94041
# 16     324.553164    ZIP_94043
# 17    -107.061911    ZIP_94044
# 18     101.418024    ZIP_94061
# 19       0.000000    ZIP_94062
# 20     214.430542    ZIP_94063
# 21     328.771617    ZIP_94065
# 22     162.905139    ZIP_94070
# 23    -115.580394    ZIP_94080
# 24     157.343107    ZIP_94085
# 25     214.764877    ZIP_94086
# 26     254.673685    ZIP_94087
# 27     179.080512    ZIP_94089
# 28       0.000000    ZIP_94102
# 29     -57.893020    ZIP_94111
# 30    -259.944540    ZIP_94124
# 31      10.394392    ZIP_94131
# 32    1784.735707    ZIP_94133
# 33    -749.476246    ZIP_94134
# 34     911.851776    ZIP_94301
# 35     540.752585    ZIP_94303
# 36     734.683567    ZIP_94306
# 37      36.812680    ZIP_94401
# 38     199.120655    ZIP_94402
# 39     311.895349    ZIP_94403
# 40     225.414897    ZIP_94404
# 41    -161.807799    ZIP_94501
# 42    -237.007263    ZIP_94502
# 43    -143.979696    ZIP_94536
# 44    -147.615619    ZIP_94538
# 45      10.346735    ZIP_94539
# 46    -427.079143    ZIP_94541
# 47    -400.112275    ZIP_94544
# 48    -303.739015    ZIP_94545
# 49    -372.672124    ZIP_94550
# 50    -362.574967    ZIP_94551
# 51    -208.576752    ZIP_94552
# 52    -130.952517    ZIP_94555
# 53    -288.408057    ZIP_94560
# 54    -184.512423    ZIP_94566
# 55    -274.981020    ZIP_94568
# 56    -381.702889    ZIP_94577
# 57    -339.280580    ZIP_94578
# 58    -342.896995    ZIP_94579
# 59    -275.905105    ZIP_94586
# 60    -259.429142    ZIP_94587
# 61    -226.730193    ZIP_94588
# 62    -461.105571    ZIP_94603
# 63    -455.012200    ZIP_94605
# 64    -397.826950    ZIP_94606
# 65    -180.198777    ZIP_94608
# 66    -146.359753    ZIP_94618
# 67    -325.270239    ZIP_94619
# 68     134.323408    ZIP_94703
# 69     -31.013839    ZIP_94706
# 70     358.742318    ZIP_94709
# 71     -40.062259    ZIP_95008
# 72     361.252267    ZIP_95014
# 73    -363.648840    ZIP_95020
# 74     212.537694    ZIP_95030
# 75     153.216986    ZIP_95032
# 76    -147.512145    ZIP_95035
# 77    -332.336768    ZIP_95037
# 78      76.019553    ZIP_95050
# 79     328.165694    ZIP_95051
# 80     190.813654    ZIP_95054
# 81     366.113042    ZIP_95070
# 82      16.557424    ZIP_95110
# 83    -194.681259    ZIP_95111
# 84     -29.207935    ZIP_95112
# 85    -250.488123    ZIP_95116
# 86      73.585420    ZIP_95117
# 87     -57.688377    ZIP_95118
# 88    -151.203553    ZIP_95119
# 89      49.171579    ZIP_95120
# 90    -180.575327    ZIP_95121
# 91    -199.939005    ZIP_95122
# 92    -132.709009    ZIP_95123
# 93     -57.685113    ZIP_95124
# 94      16.831937    ZIP_95125
# 95     -46.669360    ZIP_95126
# 96    -138.442287    ZIP_95127
# 97     104.751204    ZIP_95128
# 98     457.575043    ZIP_95129
# 99    -183.882435    ZIP_95130
# 100    -69.827298    ZIP_95131
# 101   -117.179384    ZIP_95132
# 102    -93.004729    ZIP_95133
# 103    -73.104344    ZIP_95134
# 104   -245.024844    ZIP_95136
# 105   -256.782875    ZIP_95138
# 106   -161.644745    ZIP_95139
# 107   -230.823222    ZIP_95148

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":th_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.845664953990548
# Root Mean Squared Error: 163.42760530068205
# Alpha: 0.020185086292982747
#      Coefficients      Feature
# 0       16.984955         BEDS
# 1       90.781542        BATHS
# 2        0.360664  SQUARE FEET
# 3        2.494722   YEAR BUILT
# 4        0.085348    HOA/MONTH
# 5      221.771185    ZIP_94002
# 6      -30.773445    ZIP_94005
# 7      310.829101    ZIP_94010
# 8       44.040712    ZIP_94014
# 9      -73.193540    ZIP_94015
# 10     -14.788339    ZIP_94019
# 11     902.409008    ZIP_94022
# 12     557.967632    ZIP_94024
# 13     784.928938    ZIP_94025
# 14     570.645760    ZIP_94040
# 15     607.524425    ZIP_94041
# 16     431.746586    ZIP_94043
# 17      -0.000000    ZIP_94044
# 18     197.987574    ZIP_94061
# 19       0.000000    ZIP_94062
# 20     311.927018    ZIP_94063
# 21     430.026193    ZIP_94065
# 22     255.502236    ZIP_94070
# 23      -1.771583    ZIP_94080
# 24     255.019898    ZIP_94085
# 25     316.731573    ZIP_94086
# 26     359.095817    ZIP_94087
# 27     267.716642    ZIP_94089
# 28       0.000000    ZIP_94102
# 29       5.979671    ZIP_94111
# 30    -121.478004    ZIP_94124
# 31      70.302747    ZIP_94131
# 32    1850.118681    ZIP_94133
# 33    -611.322634    ZIP_94134
# 34    1013.186229    ZIP_94301
# 35     642.132478    ZIP_94303
# 36     835.594113    ZIP_94306
# 37     132.076675    ZIP_94401
# 38     295.759497    ZIP_94402
# 39     412.545843    ZIP_94403
# 40     330.344173    ZIP_94404
# 41     -52.082553    ZIP_94501
# 42    -130.019275    ZIP_94502
# 43     -31.756114    ZIP_94536
# 44     -35.923724    ZIP_94538
# 45     110.356188    ZIP_94539
# 46    -319.132966    ZIP_94541
# 47    -287.078313    ZIP_94544
# 48    -189.205802    ZIP_94545
# 49    -257.058195    ZIP_94550
# 50    -252.606719    ZIP_94551
# 51     -84.005797    ZIP_94552
# 52     -13.974612    ZIP_94555
# 53    -178.698028    ZIP_94560
# 54     -73.945799    ZIP_94566
# 55    -162.277161    ZIP_94568
# 56    -272.226993    ZIP_94577
# 57    -224.677418    ZIP_94578
# 58    -203.984870    ZIP_94579
# 59    -132.654371    ZIP_94586
# 60    -149.431515    ZIP_94587
# 61    -118.922711    ZIP_94588
# 62    -320.351156    ZIP_94603
# 63    -344.425336    ZIP_94605
# 64    -259.293347    ZIP_94606
# 65     -63.201918    ZIP_94608
# 66     -32.729588    ZIP_94618
# 67    -201.549767    ZIP_94619
# 68     215.727447    ZIP_94703
# 69      36.865227    ZIP_94706
# 70     429.456739    ZIP_94709
# 71      60.721107    ZIP_95008
# 72     466.669841    ZIP_95014
# 73    -253.874539    ZIP_95020
# 74     308.711137    ZIP_95030
# 75     256.229500    ZIP_95032
# 76     -36.282732    ZIP_95035
# 77    -225.830683    ZIP_95037
# 78     169.355694    ZIP_95050
# 79     426.702017    ZIP_95051
# 80     289.011459    ZIP_95054
# 81     466.877720    ZIP_95070
# 82      85.214701    ZIP_95110
# 83     -71.219911    ZIP_95111
# 84      50.775911    ZIP_95112
# 85    -124.150509    ZIP_95116
# 86     165.186600    ZIP_95117
# 87      31.579317    ZIP_95118
# 88     -11.505398    ZIP_95119
# 89     111.390188    ZIP_95120
# 90     -55.240528    ZIP_95121
# 91     -75.810897    ZIP_95122
# 92     -15.937484    ZIP_95123
# 93      25.279675    ZIP_95124
# 94     113.294615    ZIP_95125
# 95      41.805992    ZIP_95126
# 96     -18.441059    ZIP_95127
# 97     180.707050    ZIP_95128
# 98     560.237521    ZIP_95129
# 99     -51.744630    ZIP_95130
# 100     22.584646    ZIP_95131
# 101     -2.863003    ZIP_95132
# 102      0.000000    ZIP_95133
# 103     13.285832    ZIP_95134
# 104   -122.387593    ZIP_95136
# 105   -114.024810    ZIP_95138
# 106    -38.352876    ZIP_95139
# 107   -106.204103    ZIP_95148

# %% [markdown]
# 3.1.3 Condo

# %%
X_train, X_test, y_train, y_test = split(df_condo_X, df_condo_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":condo_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.8499255076777208
# Root Mean Squared Error: 143.74497762364484
#      Coefficients      Feature
# 0    1.620376e+01         BEDS
# 1    6.805300e+01        BATHS
# 2    4.324132e-01  SQUARE FEET
# 3    1.306473e+00   YEAR BUILT
# 4    2.688309e-02    HOA/MONTH
# 5    1.106271e+02    ZIP_94002
# 6   -1.248945e+02    ZIP_94005
# 7    1.696394e+02    ZIP_94010
# 8   -5.338251e+01    ZIP_94014
# 9   -5.842531e+01    ZIP_94015
# 10  -4.927922e+01    ZIP_94019
# 11   6.247019e+02    ZIP_94022
# 12   3.937690e+02    ZIP_94024
# 13   3.642356e+02    ZIP_94025
# 14   1.951158e+02    ZIP_94030
# 15   1.929418e+02    ZIP_94040
# 16   4.818867e+02    ZIP_94041
# 17   1.795322e+02    ZIP_94043
# 18  -8.972986e+01    ZIP_94044
# 19   2.307646e+01    ZIP_94061
# 20  -1.169228e+02    ZIP_94062
# 21   2.225284e+02    ZIP_94063
# 22   2.478651e+02    ZIP_94065
# 23   7.036329e+00    ZIP_94066
# 24   1.469025e+02    ZIP_94070
# 25  -4.275478e+01    ZIP_94080
# 26   9.293712e+01    ZIP_94085
# 27   8.533854e+01    ZIP_94086
# 28   1.778655e+02    ZIP_94087
# 29   2.585769e+02    ZIP_94089
# 30   2.849791e+02    ZIP_94102
# 31   5.988677e-13    ZIP_94105
# 32   2.129951e+02    ZIP_94107
# 33   2.508473e+02    ZIP_94109
# 34   1.669266e-13    ZIP_94110
# 35   2.305618e-13    ZIP_94115
# 36   4.595561e+02    ZIP_94117
# 37   2.498168e+02    ZIP_94121
# 38  -6.584644e+01    ZIP_94122
# 39   3.323984e+02    ZIP_94131
# 40  -1.630056e+01    ZIP_94134
# 41   7.855036e+02    ZIP_94301
# 42   1.467290e+02    ZIP_94303
# 43   1.200318e+02    ZIP_94305
# 44   4.557320e+02    ZIP_94306
# 45   6.806981e+01    ZIP_94401
# 46   3.058199e+02    ZIP_94402
# 47   1.224657e+02    ZIP_94403
# 48   9.764098e+01    ZIP_94404
# 49  -1.051620e+02    ZIP_94501
# 50  -1.812810e+02    ZIP_94502
# 51  -1.348138e+02    ZIP_94536
# 52  -1.167549e+02    ZIP_94538
# 53  -6.490438e+01    ZIP_94539
# 54  -3.586530e+02    ZIP_94541
# 55  -3.717063e+02    ZIP_94542
# 56  -3.009296e+02    ZIP_94544
# 57  -2.745541e+02    ZIP_94545
# 58  -2.862864e+02    ZIP_94546
# 59  -2.735001e+02    ZIP_94550
# 60  -3.127104e+02    ZIP_94551
# 61  -7.858116e+01    ZIP_94555
# 62  -2.741853e+02    ZIP_94560
# 63  -2.193413e+02    ZIP_94566
# 64  -2.763503e+02    ZIP_94568
# 65  -3.332191e+02    ZIP_94577
# 66  -2.702032e+02    ZIP_94578
# 67  -3.049994e+02    ZIP_94579
# 68  -1.705641e+02    ZIP_94587
# 69  -1.069419e+02    ZIP_94588
# 70  -2.941500e+02    ZIP_94601
# 71  -1.271326e+01    ZIP_94602
# 72  -1.453881e+02    ZIP_94605
# 73  -1.038159e+01    ZIP_94606
# 74  -2.754731e+01    ZIP_94607
# 75  -5.763238e+01    ZIP_94608
# 76  -9.262329e+01    ZIP_94609
# 77  -5.799299e+01    ZIP_94610
# 78   6.503217e+01    ZIP_94611
# 79  -3.543756e+02    ZIP_94612
# 80   1.521298e+02    ZIP_94618
# 81  -2.048160e+02    ZIP_94619
# 82   1.429947e+02    ZIP_94702
# 83  -1.670909e+02    ZIP_94703
# 84   1.236059e+02    ZIP_94704
# 85   2.426450e+02    ZIP_94705
# 86  -1.811403e+02    ZIP_94706
# 87   3.610166e+01    ZIP_94707
# 88   1.013120e+02    ZIP_94708
# 89   1.477956e+02    ZIP_94709
# 90  -5.142536e+01    ZIP_94710
# 91  -2.943017e+01    ZIP_95008
# 92   2.689654e+02    ZIP_95014
# 93  -3.243075e+02    ZIP_95020
# 94   1.604097e+02    ZIP_95030
# 95  -6.586804e+00    ZIP_95032
# 96  -1.317179e+02    ZIP_95035
# 97  -2.525581e+02    ZIP_95037
# 98  -3.106780e+01    ZIP_95050
# 99  -1.533543e+01    ZIP_95051
# 100  5.275421e+01    ZIP_95054
# 101  1.429289e+02    ZIP_95070
# 102 -5.699595e+01    ZIP_95110
# 103 -1.609666e+02    ZIP_95111
# 104 -7.686477e+01    ZIP_95112
# 105 -7.365260e+01    ZIP_95113
# 106 -1.429170e+02    ZIP_95116
# 107 -3.515183e+01    ZIP_95117
# 108 -7.286790e+01    ZIP_95118
# 109 -3.844784e+01    ZIP_95119
# 110 -1.307438e+02    ZIP_95121
# 111 -1.239308e+02    ZIP_95122
# 112 -1.066289e+02    ZIP_95123
# 113 -4.290253e+01    ZIP_95124
# 114  1.185731e+01    ZIP_95125
# 115 -3.221077e+00    ZIP_95126
# 116 -1.434159e+02    ZIP_95127
# 117  6.270294e+01    ZIP_95128
# 118  3.128542e+01    ZIP_95129
# 119  5.562652e+00    ZIP_95131
# 120 -2.772896e+01    ZIP_95132
# 121 -1.108962e+02    ZIP_95133
# 122  9.796972e+00    ZIP_95134
# 123 -1.403450e+02    ZIP_95135
# 124 -9.474282e+01    ZIP_95136
# 125 -1.611638e+02    ZIP_95138
# 126  0.000000e+00    ZIP_95148

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":condo_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.8496215978131221
# Root Mean Squared Error: 143.7823414571578
# Alpha: 0.020185086292982747
#      Coefficients      Feature
# 0       20.214531         BEDS
# 1       72.710304        BATHS
# 2        0.411159  SQUARE FEET
# 3        1.252959   YEAR BUILT
# 4        0.034129    HOA/MONTH
# 5       79.117127    ZIP_94002
# 6     -149.443255    ZIP_94005
# 7      139.572661    ZIP_94010
# 8      -82.478824    ZIP_94014
# 9      -88.860834    ZIP_94015
# 10     -80.377086    ZIP_94019
# 11     586.287830    ZIP_94022
# 12     357.039084    ZIP_94024
# 13     328.475822    ZIP_94025
# 14     163.843086    ZIP_94030
# 15     159.355123    ZIP_94040
# 16     445.583059    ZIP_94041
# 17     145.035081    ZIP_94043
# 18    -115.965075    ZIP_94044
# 19      -7.649827    ZIP_94061
# 20    -127.326280    ZIP_94062
# 21     193.771883    ZIP_94063
# 22     213.809976    ZIP_94065
# 23     -25.275797    ZIP_94066
# 24     114.495747    ZIP_94070
# 25     -72.601045    ZIP_94080
# 26      60.890471    ZIP_94085
# 27      52.668944    ZIP_94086
# 28     143.311030    ZIP_94087
# 29     222.571008    ZIP_94089
# 30     248.623816    ZIP_94102
# 31       0.000000    ZIP_94105
# 32     177.732285    ZIP_94107
# 33     214.042494    ZIP_94109
# 34       0.000000    ZIP_94110
# 35       0.000000    ZIP_94115
# 36     423.766386    ZIP_94117
# 37     211.697266    ZIP_94121
# 38     -89.074365    ZIP_94122
# 39     297.217415    ZIP_94131
# 40     -44.075052    ZIP_94134
# 41     739.350747    ZIP_94301
# 42     112.806892    ZIP_94303
# 43      91.376227    ZIP_94305
# 44     417.688578    ZIP_94306
# 45      37.639124    ZIP_94401
# 46     275.155809    ZIP_94402
# 47      88.413830    ZIP_94403
# 48      66.956075    ZIP_94404
# 49    -132.930306    ZIP_94501
# 50    -202.172144    ZIP_94502
# 51    -162.544605    ZIP_94536
# 52    -145.092499    ZIP_94538
# 53     -92.903961    ZIP_94539
# 54    -381.892633    ZIP_94541
# 55    -392.559167    ZIP_94542
# 56    -323.272158    ZIP_94544
# 57    -301.162845    ZIP_94545
# 58    -311.565931    ZIP_94546
# 59    -295.740302    ZIP_94550
# 60    -330.622070    ZIP_94551
# 61    -108.266529    ZIP_94555
# 62    -298.143674    ZIP_94560
# 63    -244.431474    ZIP_94566
# 64    -295.824989    ZIP_94568
# 65    -355.282062    ZIP_94577
# 66    -297.215218    ZIP_94578
# 67    -331.946994    ZIP_94579
# 68    -199.741146    ZIP_94587
# 69    -135.849827    ZIP_94588
# 70    -316.446854    ZIP_94601
# 71     -45.017926    ZIP_94602
# 72    -167.717805    ZIP_94605
# 73     -38.838785    ZIP_94606
# 74     -55.603943    ZIP_94607
# 75     -86.629923    ZIP_94608
# 76    -128.858920    ZIP_94609
# 77     -84.456001    ZIP_94610
# 78      33.467937    ZIP_94611
# 79    -377.136965    ZIP_94612
# 80     120.355401    ZIP_94618
# 81    -235.505179    ZIP_94619
# 82     104.920194    ZIP_94702
# 83    -194.527268    ZIP_94703
# 84      88.786195    ZIP_94704
# 85     207.676170    ZIP_94705
# 86    -206.005157    ZIP_94706
# 87       5.269831    ZIP_94707
# 88      71.604203    ZIP_94708
# 89     112.589823    ZIP_94709
# 90     -77.008675    ZIP_94710
# 91     -58.883774    ZIP_95008
# 92     236.404073    ZIP_95014
# 93    -346.003763    ZIP_95020
# 94     133.512357    ZIP_95030
# 95     -36.397686    ZIP_95032
# 96    -158.570837    ZIP_95035
# 97    -275.793260    ZIP_95037
# 98     -59.052699    ZIP_95050
# 99     -47.471619    ZIP_95051
# 100     24.534789    ZIP_95054
# 101    110.424545    ZIP_95070
# 102    -84.403084    ZIP_95110
# 103   -188.302159    ZIP_95111
# 104   -103.391493    ZIP_95112
# 105    -99.814239    ZIP_95113
# 106   -171.857442    ZIP_95116
# 107    -66.357584    ZIP_95117
# 108   -102.924664    ZIP_95118
# 109    -72.504418    ZIP_95119
# 110   -159.717511    ZIP_95121
# 111   -152.450410    ZIP_95122
# 112   -135.532103    ZIP_95123
# 113    -73.041918    ZIP_95124
# 114    -18.735315    ZIP_95125
# 115    -30.702658    ZIP_95126
# 116   -171.443467    ZIP_95127
# 117     32.246611    ZIP_95128
# 118      0.754601    ZIP_95129
# 119    -23.452594    ZIP_95131
# 120    -57.829350    ZIP_95132
# 121   -140.545929    ZIP_95133
# 122    -16.219041    ZIP_95134
# 123   -167.780508    ZIP_95135
# 124   -122.340655    ZIP_95136
# 125   -183.884126    ZIP_95138
# 126      0.000000    ZIP_95148

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":condo_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.848567261494281
# Root Mean Squared Error: 144.02890723514878
# Alpha: 0.020185086292982747
#      Coefficients      Feature
# 0        9.832738         BEDS
# 1       68.601663        BATHS
# 2        0.440653  SQUARE FEET
# 3        1.009166   YEAR BUILT
# 4        0.029694    HOA/MONTH
# 5      115.982531    ZIP_94002
# 6      -83.385406    ZIP_94005
# 7      187.536292    ZIP_94010
# 8      -14.336059    ZIP_94014
# 9      -26.947858    ZIP_94015
# 10     -11.041793    ZIP_94019
# 11     641.020584    ZIP_94022
# 12     384.428393    ZIP_94024
# 13     375.478939    ZIP_94025
# 14     213.237431    ZIP_94030
# 15     208.033363    ZIP_94040
# 16     487.562069    ZIP_94041
# 17     196.725425    ZIP_94043
# 18     -46.642689    ZIP_94044
# 19      34.786529    ZIP_94061
# 20     -79.238312    ZIP_94062
# 21     235.323727    ZIP_94063
# 22     258.747572    ZIP_94065
# 23      18.220107    ZIP_94066
# 24     163.797814    ZIP_94070
# 25      -8.611090    ZIP_94080
# 26     110.790093    ZIP_94085
# 27     102.824261    ZIP_94086
# 28     191.621172    ZIP_94087
# 29     238.511936    ZIP_94089
# 30     263.572957    ZIP_94102
# 31       0.000000    ZIP_94105
# 32     206.943893    ZIP_94107
# 33     200.866645    ZIP_94109
# 34       0.000000    ZIP_94110
# 35       0.000000    ZIP_94115
# 36     409.790929    ZIP_94117
# 37     224.490675    ZIP_94121
# 38      -6.015469    ZIP_94122
# 39     312.901013    ZIP_94131
# 40       0.000000    ZIP_94134
# 41     796.470931    ZIP_94301
# 42     164.021041    ZIP_94303
# 43     104.426107    ZIP_94305
# 44     469.937557    ZIP_94306
# 45      83.764229    ZIP_94401
# 46     314.956446    ZIP_94402
# 47     136.004784    ZIP_94403
# 48     113.839279    ZIP_94404
# 49     -78.329183    ZIP_94501
# 50    -131.039860    ZIP_94502
# 51     -97.399882    ZIP_94536
# 52     -75.438639    ZIP_94538
# 53     -19.970434    ZIP_94539
# 54    -314.067332    ZIP_94541
# 55    -305.850384    ZIP_94542
# 56    -257.675358    ZIP_94544
# 57    -221.528715    ZIP_94545
# 58    -239.712041    ZIP_94546
# 59    -224.773042    ZIP_94550
# 60    -257.383982    ZIP_94551
# 61     -31.164672    ZIP_94555
# 62    -232.615046    ZIP_94560
# 63    -168.231566    ZIP_94566
# 64    -232.538384    ZIP_94568
# 65    -296.778558    ZIP_94577
# 66    -224.957271    ZIP_94578
# 67    -240.617213    ZIP_94579
# 68    -131.506575    ZIP_94587
# 69     -58.400898    ZIP_94588
# 70    -229.596720    ZIP_94601
# 71       0.000000    ZIP_94602
# 72     -93.266634    ZIP_94605
# 73       0.000000    ZIP_94606
# 74       0.000000    ZIP_94607
# 75     -26.884244    ZIP_94608
# 76     -34.317970    ZIP_94609
# 77     -26.679668    ZIP_94610
# 78      60.827158    ZIP_94611
# 79    -288.494373    ZIP_94612
# 80     139.499080    ZIP_94618
# 81    -146.919148    ZIP_94619
# 82     133.071924    ZIP_94702
# 83    -109.635125    ZIP_94703
# 84     124.741976    ZIP_94704
# 85     230.254888    ZIP_94705
# 86    -143.267507    ZIP_94706
# 87      20.145814    ZIP_94707
# 88      60.382931    ZIP_94708
# 89     130.509722    ZIP_94709
# 90      -4.629168    ZIP_94710
# 91      -0.000000    ZIP_95008
# 92     289.728350    ZIP_95014
# 93    -287.029752    ZIP_95020
# 94     161.737101    ZIP_95030
# 95       6.483012    ZIP_95032
# 96     -95.611602    ZIP_95035
# 97    -218.068427    ZIP_95037
# 98      -0.000000    ZIP_95050
# 99       1.048808    ZIP_95051
# 100     72.255632    ZIP_95054
# 101    157.202526    ZIP_95070
# 102    -20.586025    ZIP_95110
# 103   -123.654231    ZIP_95111
# 104    -39.259994    ZIP_95112
# 105    -19.486528    ZIP_95113
# 106   -104.279172    ZIP_95116
# 107     -0.000000    ZIP_95117
# 108    -36.159463    ZIP_95118
# 109     -0.000000    ZIP_95119
# 110    -70.806440    ZIP_95121
# 111    -85.886175    ZIP_95122
# 112    -76.656653    ZIP_95123
# 113     -7.459980    ZIP_95124
# 114     23.455696    ZIP_95125
# 115     10.532594    ZIP_95126
# 116   -101.174388    ZIP_95127
# 117     80.440652    ZIP_95128
# 118     42.838472    ZIP_95129
# 119     11.449724    ZIP_95131
# 120     -0.000000    ZIP_95132
# 121    -73.804448    ZIP_95133
# 122     13.799889    ZIP_95134
# 123   -105.614176    ZIP_95135
# 124    -51.512144    ZIP_95136
# 125    -95.637591    ZIP_95138
# 126      0.000000    ZIP_95148

# %% [markdown]
# ##  3.2 Use different location info but keep three property types together

# %% [markdown]
# 3.2.1 Using county as the only location info

# %%
X_train, X_test, y_train, y_test = split(df_county_X, df_county_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":county_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.5849331210933051
# Root Mean Squared Error: 768.6122851666054
#     Coefficients               Feature
# 0  -1.757964e+02                  BEDS
# 1   7.137616e+01                 BATHS
# 2   9.770633e+02           SQUARE FEET
# 3   3.857218e+01              LOT SIZE
# 4  -1.779170e+02            YEAR BUILT
# 5  -2.313948e+01             HOA/MONTH
# 6   5.219218e+12                   LOT
# 7  -1.102825e+02                   HOA
# 8  -2.643202e+15   PROPERTY TYPE_Condo
# 9  -3.278285e+15     PROPERTY TYPE_SFH
# 10 -2.195970e+15      PROPERTY TYPE_TH
# 11 -1.075667e+15        COUNTY_ALAMEDA
# 12 -3.311006e+14  COUNTY_SAN FRANCISCO
# 13 -1.068087e+15      COUNTY_SAN MATEO
# 14 -1.065757e+15    COUNTY_SANTA CLARA

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":county_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.5851022030546079
# Root Mean Squared Error: 768.3835109861017
# Alpha: 0.005
#     Coefficients               Feature
# 0    -173.596116                  BEDS
# 1      96.638714                 BATHS
# 2     963.257711           SQUARE FEET
# 3      39.128928              LOT SIZE
# 4    -177.410357            YEAR BUILT
# 5     -20.993383             HOA/MONTH
# 6       0.000000                   LOT
# 7    -108.282272                   HOA
# 8      31.573817   PROPERTY TYPE_Condo
# 9     -40.265234     PROPERTY TYPE_SFH
# 10     22.112727      PROPERTY TYPE_TH
# 11   -192.958054        COUNTY_ALAMEDA
# 12      7.940489  COUNTY_SAN FRANCISCO
# 13     88.866926      COUNTY_SAN MATEO
# 14    102.427076    COUNTY_SANTA CLARA

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":county_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.5850483288352191
# Root Mean Squared Error: 768.3360457241216
# Alpha: 0.015269277544167062
#     Coefficients               Feature
# 0    -170.019510                  BEDS
# 1      79.443534                 BATHS
# 2     975.316525           SQUARE FEET
# 3      36.867942              LOT SIZE
# 4    -174.243780            YEAR BUILT
# 5     -10.746063             HOA/MONTH
# 6       0.000000                   LOT
# 7    -103.326630                   HOA
# 8       1.318424   PROPERTY TYPE_Condo
# 9     -62.795382     PROPERTY TYPE_SFH
# 10      0.000000      PROPERTY TYPE_TH
# 11   -281.595592        COUNTY_ALAMEDA
# 12    -16.529802  COUNTY_SAN FRANCISCO
# 13      0.000000      COUNTY_SAN MATEO
# 14     12.139720    COUNTY_SANTA CLARA

# %% [markdown]
# 3.2.2 Using city as the only location info

# %%
X_train, X_test, y_train, y_test = split(df_city_X, df_city_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":city_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7190211519265912
# Root Mean Squared Error: 642.7695276667723
#     Coefficients                   Feature
# 0  -9.676342e+01                      BEDS
# 1   2.020482e+01                     BATHS
# 2   7.615612e+02               SQUARE FEET
# 3   4.532207e+01                  LOT SIZE
# 4  -6.795604e+01                YEAR BUILT
# 5  -5.775225e+01                 HOA/MONTH
# 6  -4.085878e+13                       LOT
# 7  -3.120107e+01                       HOA
# 8  -1.407309e+15       PROPERTY TYPE_Condo
# 9  -1.745443e+15         PROPERTY TYPE_SFH
# 10 -1.169191e+15          PROPERTY TYPE_TH
# 11 -4.562557e+13              CITY_ALAMEDA
# 12 -2.659628e+13               CITY_ALBANY
# 13 -2.239736e+13             CITY_ATHERTON
# 14 -3.509088e+13              CITY_BELMONT
# 15 -4.372389e+13             CITY_BERKELEY
# 16 -1.971104e+13             CITY_BRISBANE
# 17 -2.230073e+12            CITY_BROADMOOR
# 18 -3.347204e+13           CITY_BURLINGAME
# 19 -3.769916e+13             CITY_CAMPBELL
# 20 -1.210171e+13        CITY_CASTRO VALLEY
# 21 -7.050144e+12                CITY_COLMA
# 22 -3.633744e+13            CITY_CUPERTINO
# 23 -4.391279e+13            CITY_DALY CITY
# 24 -3.593821e+13               CITY_DUBLIN
# 25 -3.103200e+13       CITY_EAST PALO ALTO
# 26 -2.050673e+13           CITY_EL GRANADA
# 27 -4.985977e+12        CITY_EMERALD HILLS
# 28 -1.327299e+13           CITY_EMERYVILLE
# 29 -3.218242e+13          CITY_FOSTER CITY
# 30 -5.531045e+13              CITY_FREMONT
# 31 -4.570290e+13               CITY_GILROY
# 32 -3.343592e+13        CITY_HALF MOON BAY
# 33 -5.198569e+13              CITY_HAYWARD
# 34 -2.700628e+13         CITY_HILLSBOROUGH
# 35 -1.250443e+13             CITY_LA HONDA
# 36 -5.160583e+13            CITY_LIVERMORE
# 37 -3.862360e+12             CITY_LOMA MAR
# 38 -3.728338e+13            CITY_LOS ALTOS
# 39 -2.622625e+13      CITY_LOS ALTOS HILLS
# 40 -4.141153e+13            CITY_LOS GATOS
# 41 -4.399347e+13           CITY_MENLO PARK
# 42 -3.059878e+13             CITY_MILLBRAE
# 43 -4.231950e+13             CITY_MILPITAS
# 44 -1.643603e+13              CITY_MONTARA
# 45 -1.835147e+13         CITY_MONTE SERENO
# 46 -4.074524e+13          CITY_MORGAN HILL
# 47 -1.443417e+13           CITY_MOSS BEACH
# 48 -3.931503e+13        CITY_MOUNTAIN VIEW
# 49 -4.059882e+13               CITY_NEWARK
# 50 -5.271406e+13              CITY_OAKLAND
# 51 -3.801567e+13             CITY_PACIFICA
# 52 -3.814148e+13            CITY_PALO ALTO
# 53 -8.488315e+12            CITY_PESCADERO
# 54 -2.896614e+13             CITY_PIEDMONT
# 55 -4.661970e+13           CITY_PLEASANTON
# 56 -2.367551e+13       CITY_PORTOLA VALLEY
# 57 -4.946821e+13         CITY_REDWOOD CITY
# 58 -3.307246e+13            CITY_SAN BRUNO
# 59 -4.243150e+13           CITY_SAN CARLOS
# 60 -4.112329e+13        CITY_SAN FRANCISCO
# 61 -3.525891e+12         CITY_SAN GREGORIO
# 62 -6.908140e+13             CITY_SAN JOSE
# 63 -4.487038e+13          CITY_SAN LEANDRO
# 64 -1.199890e+13          CITY_SAN LORENZO
# 65 -5.229255e+12           CITY_SAN MARTIN
# 66 -5.432739e+13            CITY_SAN MATEO
# 67 -4.315171e+13          CITY_SANTA CLARA
# 68 -3.640353e+13             CITY_SARATOGA
# 69 -3.864030e+13  CITY_SOUTH SAN FRANCISCO
# 70 -3.153701e+12             CITY_STANFORD
# 71 -4.086197e+13            CITY_SUNNYVALE
# 72 -1.576924e+12                CITY_SUNOL
# 73 -4.092020e+13           CITY_UNION CITY
# 74 -2.448957e+13             CITY_WOODSIDE

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":city_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7190604099922211
# Root Mean Squared Error: 642.548667124333
# Alpha: 0.005
#     Coefficients                   Feature
# 0     -99.944605                      BEDS
# 1      39.605322                     BATHS
# 2     748.415376               SQUARE FEET
# 3      46.243613                  LOT SIZE
# 4     -67.550961                YEAR BUILT
# 5     -55.882533                 HOA/MONTH
# 6       0.000000                       LOT
# 7     -31.011278                       HOA
# 8      -6.471388       PROPERTY TYPE_Condo
# 9       0.616498         PROPERTY TYPE_SFH
# 10      6.706848          PROPERTY TYPE_TH
# 11    -56.657155              CITY_ALAMEDA
# 12    -14.707446               CITY_ALBANY
# 13    299.302479             CITY_ATHERTON
# 14     23.580602              CITY_BELMONT
# 15    -43.193133             CITY_BERKELEY
# 16    -19.274773             CITY_BRISBANE
# 17     -3.764049            CITY_BROADMOOR
# 18     52.768046           CITY_BURLINGAME
# 19     -0.460344             CITY_CAMPBELL
# 20    -23.086738        CITY_CASTRO VALLEY
# 21     -5.059335                CITY_COLMA
# 22     60.451016            CITY_CUPERTINO
# 23    -36.661332            CITY_DALY CITY
# 24    -75.091027               CITY_DUBLIN
# 25    -25.847021       CITY_EAST PALO ALTO
# 26    -25.986258           CITY_EL GRANADA
# 27      3.740854        CITY_EMERALD HILLS
# 28     -7.205959           CITY_EMERYVILLE
# 29     22.127636          CITY_FOSTER CITY
# 30    -39.184726              CITY_FREMONT
# 31   -103.891668               CITY_GILROY
# 32    -45.637361        CITY_HALF MOON BAY
# 33   -108.503660              CITY_HAYWARD
# 34    102.385989         CITY_HILLSBOROUGH
# 35    -14.804234             CITY_LA HONDA
# 36   -103.718231            CITY_LIVERMORE
# 37     -6.837367             CITY_LOMA MAR
# 38    148.141855            CITY_LOS ALTOS
# 39    120.462425      CITY_LOS ALTOS HILLS
# 40     10.656139            CITY_LOS GATOS
# 41    124.667176           CITY_MENLO PARK
# 42     12.441664             CITY_MILLBRAE
# 43    -28.526466             CITY_MILPITAS
# 44    -19.796949              CITY_MONTARA
# 45     24.622378         CITY_MONTE SERENO
# 46    -74.452597          CITY_MORGAN HILL
# 47    -14.533347           CITY_MOSS BEACH
# 48     57.318955        CITY_MOUNTAIN VIEW
# 49    -51.292030               CITY_NEWARK
# 50    -93.317202              CITY_OAKLAND
# 51    -27.167696             CITY_PACIFICA
# 52    203.576357            CITY_PALO ALTO
# 53     -6.218773            CITY_PESCADERO
# 54     -7.636145             CITY_PIEDMONT
# 55    -76.589657           CITY_PLEASANTON
# 56     85.473251       CITY_PORTOLA VALLEY
# 57     26.421668         CITY_REDWOOD CITY
# 58    -18.142998            CITY_SAN BRUNO
# 59     43.502106           CITY_SAN CARLOS
# 60     23.909390        CITY_SAN FRANCISCO
# 61    -10.151365         CITY_SAN GREGORIO
# 62    -21.493775             CITY_SAN JOSE
# 63    -85.846591          CITY_SAN LEANDRO
# 64    -18.927200          CITY_SAN LORENZO
# 65     -9.119101           CITY_SAN MARTIN
# 66     30.902509            CITY_SAN MATEO
# 67     12.156017          CITY_SANTA CLARA
# 68     58.638517             CITY_SARATOGA
# 69    -26.935498  CITY_SOUTH SAN FRANCISCO
# 70     -0.619890             CITY_STANFORD
# 71     55.018246            CITY_SUNNYVALE
# 72     -3.622531                CITY_SUNOL
# 73    -67.895093           CITY_UNION CITY
# 74    160.836279             CITY_WOODSIDE

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":city_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7190024742201006
# Root Mean Squared Error: 642.4307932826421
# Alpha: 0.008737642000038414
#     Coefficients                   Feature
# 0     -98.281092                      BEDS
# 1      27.582496                     BATHS
# 2     762.652135               SQUARE FEET
# 3      44.451523                  LOT SIZE
# 4     -68.507639                YEAR BUILT
# 5     -53.546124                 HOA/MONTH
# 6       0.000000                       LOT
# 7     -30.961668                       HOA
# 8      -4.355346       PROPERTY TYPE_Condo
# 9       0.000000         PROPERTY TYPE_SFH
# 10      5.813026          PROPERTY TYPE_TH
# 11    -31.590207              CITY_ALAMEDA
# 12     -0.000000               CITY_ALBANY
# 13    309.878102             CITY_ATHERTON
# 14     41.042944              CITY_BELMONT
# 15    -19.124983             CITY_BERKELEY
# 16     -7.480894             CITY_BRISBANE
# 17     -1.391086            CITY_BROADMOOR
# 18     69.213580           CITY_BURLINGAME
# 19     18.209681             CITY_CAMPBELL
# 20    -15.290618        CITY_CASTRO VALLEY
# 21     -0.000000                CITY_COLMA
# 22     78.728360            CITY_CUPERTINO
# 23    -11.752611            CITY_DALY CITY
# 24    -54.824373               CITY_DUBLIN
# 25     -8.033778       CITY_EAST PALO ALTO
# 26    -13.625777           CITY_EL GRANADA
# 27      4.967711        CITY_EMERALD HILLS
# 28     -0.000000           CITY_EMERYVILLE
# 29     37.942355          CITY_FOSTER CITY
# 30     -7.994994              CITY_FREMONT
# 31    -78.674053               CITY_GILROY
# 32    -26.829690        CITY_HALF MOON BAY
# 33    -79.736459              CITY_HAYWARD
# 34    114.850392         CITY_HILLSBOROUGH
# 35     -6.715635             CITY_LA HONDA
# 36    -75.085978            CITY_LIVERMORE
# 37     -3.456548             CITY_LOMA MAR
# 38    166.844374            CITY_LOS ALTOS
# 39    132.894983      CITY_LOS ALTOS HILLS
# 40     31.087955            CITY_LOS GATOS
# 41    147.145631           CITY_MENLO PARK
# 42     27.322679             CITY_MILLBRAE
# 43     -4.456295             CITY_MILPITAS
# 44     -9.630278              CITY_MONTARA
# 45     32.729138         CITY_MONTE SERENO
# 46    -51.753481          CITY_MORGAN HILL
# 47     -5.476862           CITY_MOSS BEACH
# 48     76.810282        CITY_MOUNTAIN VIEW
# 49    -28.040685               CITY_NEWARK
# 50    -64.499607              CITY_OAKLAND
# 51     -5.383131             CITY_PACIFICA
# 52    223.217662            CITY_PALO ALTO
# 53     -0.086243            CITY_PESCADERO
# 54      5.721964             CITY_PIEDMONT
# 55    -50.972072           CITY_PLEASANTON
# 56     96.601579       CITY_PORTOLA VALLEY
# 57     51.620629         CITY_REDWOOD CITY
# 58     -0.000000            CITY_SAN BRUNO
# 59     64.837274           CITY_SAN CARLOS
# 60     44.528403        CITY_SAN FRANCISCO
# 61     -6.647670         CITY_SAN GREGORIO
# 62     13.335825             CITY_SAN JOSE
# 63    -61.016033          CITY_SAN LEANDRO
# 64    -11.168478          CITY_SAN LORENZO
# 65     -4.854074           CITY_SAN MARTIN
# 66     58.313776            CITY_SAN MATEO
# 67     33.531684          CITY_SANTA CLARA
# 68     76.409799             CITY_SARATOGA
# 69     -5.054494  CITY_SOUTH SAN FRANCISCO
# 70      0.000000             CITY_STANFORD
# 71     75.606926            CITY_SUNNYVALE
# 72     -1.548081                CITY_SUNOL
# 73    -44.812786           CITY_UNION CITY
# 74    172.418679             CITY_WOODSIDE

# %% [markdown]
# 3.2.3 Using zip as the only location info

# %%
X_train, X_test, y_train, y_test = split(df_zip_X, df_zip_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":zip_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.7147095123373166
# Root Mean Squared Error: 318280779212354.1
#      Coefficients              Feature
# 0   -1.042169e+02                 BEDS
# 1   -1.814021e+00                BATHS
# 2    8.015086e+02          SQUARE FEET
# 3    5.487754e+01             LOT SIZE
# 4   -5.911551e+01           YEAR BUILT
# 5   -6.647507e+01            HOA/MONTH
# 6   -1.114012e+14                  LOT
# 7   -2.835888e+01                  HOA
# 8   -1.931480e+15  PROPERTY TYPE_Condo
# 9   -2.395557e+15    PROPERTY TYPE_SFH
# 10  -1.604672e+15     PROPERTY TYPE_TH
# 11   2.439508e+14            ZIP_94002
# 12   1.370306e+14            ZIP_94005
# 13   2.973050e+14            ZIP_94010
# 14   1.942290e+14            ZIP_94014
# 15   2.432337e+14            ZIP_94015
# 16   9.854235e+13            ZIP_94018
# 17   2.539925e+14            ZIP_94019
# 18   8.693045e+13            ZIP_94020
# 19   2.685102e+13            ZIP_94021
# 20   2.425143e+14            ZIP_94022
# 21   2.042712e+14            ZIP_94024
# 22   3.043431e+14            ZIP_94025
# 23   1.572226e+14            ZIP_94027
# 24   1.656678e+14            ZIP_94028
# 25   2.127218e+14            ZIP_94030
# 26   1.142628e+14            ZIP_94037
# 27   1.003460e+14            ZIP_94038
# 28   1.712905e+14            ZIP_94040
# 29   9.356119e+13            ZIP_94041
# 30   1.936214e+14            ZIP_94043
# 31   2.645028e+14            ZIP_94044
# 32   5.901053e+13            ZIP_94060
# 33   2.420335e+14            ZIP_94061
# 34   2.489089e+14            ZIP_94062
# 35   1.413053e+14            ZIP_94063
# 36   9.974841e+13            ZIP_94065
# 37   2.299188e+14            ZIP_94066
# 38   2.949826e+14            ZIP_94070
# 39   2.451190e+13            ZIP_94074
# 40   2.684110e+14            ZIP_94080
# 41   1.438079e+14            ZIP_94085
# 42   1.498778e+14            ZIP_94086
# 43   1.858517e+14            ZIP_94087
# 44   6.482226e+13            ZIP_94089
# 45   2.192445e+13            ZIP_94102
# 46   1.898742e+13            ZIP_94103
# 47   1.096273e+13            ZIP_94105
# 48   3.466237e+13            ZIP_94107
# 49   2.451190e+13            ZIP_94109
# 50   8.049319e+13            ZIP_94110
# 51   1.096273e+13            ZIP_94111
# 52   1.285096e+14            ZIP_94112
# 53   6.389051e+13            ZIP_94114
# 54   3.466237e+13            ZIP_94115
# 55   8.693045e+13            ZIP_94116
# 56   3.951935e+13            ZIP_94117
# 57   4.244928e+13            ZIP_94118
# 58   5.140306e+13            ZIP_94121
# 59   7.745941e+13            ZIP_94122
# 60   3.796955e+13            ZIP_94123
# 61   7.430106e+13            ZIP_94124
# 62   8.269505e+13            ZIP_94127
# 63   9.483125e+13            ZIP_94131
# 64   5.694110e+13            ZIP_94132
# 65   1.116764e+14            ZIP_94133
# 66   8.049319e+13            ZIP_94134
# 67   1.370306e+14            ZIP_94301
# 68   2.587453e+14            ZIP_94303
# 69   3.100393e+13            ZIP_94304
# 70   2.192445e+13            ZIP_94305
# 71   1.747101e+14            ZIP_94306
# 72   2.045588e+14            ZIP_94401
# 73   2.096647e+14            ZIP_94402
# 74   2.311859e+14            ZIP_94403
# 75   2.388829e+14            ZIP_94404
# 76   2.739499e+14            ZIP_94501
# 77   1.631451e+14            ZIP_94502
# 78   2.160052e+14            ZIP_94536
# 79   1.978340e+14            ZIP_94538
# 80   1.924001e+14            ZIP_94539
# 81   2.226824e+14            ZIP_94541
# 82   1.294335e+14            ZIP_94542
# 83   2.019552e+14            ZIP_94544
# 84   1.579754e+14            ZIP_94545
# 85   7.974564e+13            ZIP_94546
# 86   2.671151e+14            ZIP_94550
# 87   2.441893e+14            ZIP_94551
# 88   5.140306e+13            ZIP_94552
# 89   1.719801e+14            ZIP_94555
# 90   2.820378e+14            ZIP_94560
# 91   2.439508e+14            ZIP_94566
# 92   2.496087e+14            ZIP_94568
# 93   2.296645e+14            ZIP_94577
# 94   1.740318e+14            ZIP_94578
# 95   1.256966e+14            ZIP_94579
# 96   8.413072e+13            ZIP_94580
# 97   1.115474e+14            ZIP_94584
# 98   1.898742e+13            ZIP_94586
# 99   2.840713e+14            ZIP_94587
# 100  2.165474e+14            ZIP_94588
# 101  1.009399e+14            ZIP_94601
# 102  1.089122e+14            ZIP_94602
# 103  1.308068e+14            ZIP_94603
# 104  1.627814e+14            ZIP_94605
# 105  7.745941e+13            ZIP_94606
# 106  5.901053e+13            ZIP_94607
# 107  1.303506e+14            ZIP_94608
# 108  7.015227e+13            ZIP_94609
# 109  1.348414e+14            ZIP_94610
# 110  2.036948e+14            ZIP_94611
# 111  2.685102e+13            ZIP_94612
# 112  7.430106e+13            ZIP_94618
# 113  1.193707e+14            ZIP_94619
# 114  9.854235e+13            ZIP_94621
# 115  1.421445e+14            ZIP_94702
# 116  1.183670e+14            ZIP_94703
# 117  5.255751e+13            ZIP_94704
# 118  1.203659e+14            ZIP_94705
# 119  1.845771e+14            ZIP_94706
# 120  1.330636e+14            ZIP_94707
# 121  1.289724e+14            ZIP_94708
# 122  5.901053e+13            ZIP_94709
# 123  7.589677e+13            ZIP_94710
# 124  1.096273e+13            ZIP_94979
# 125  1.096273e+13            ZIP_94980
# 126  1.898742e+13            ZIP_95002
# 127  2.620835e+14            ZIP_95008
# 128  2.526169e+14            ZIP_95014
# 129  3.177253e+14            ZIP_95020
# 130  1.096273e+13            ZIP_95025
# 131  1.936214e+14            ZIP_95030
# 132  2.127218e+14            ZIP_95032
# 133  1.317143e+14            ZIP_95033
# 134  2.942040e+14            ZIP_95035
# 135  2.832598e+14            ZIP_95037
# 136  3.635364e+13            ZIP_95046
# 137  1.993160e+14            ZIP_95050
# 138  1.996111e+14            ZIP_95051
# 139  1.083625e+14            ZIP_95054
# 140  2.530763e+14            ZIP_95070
# 141  1.050026e+14            ZIP_95110
# 142  9.096741e+13            ZIP_95111
# 143  1.163333e+14            ZIP_95112
# 144  2.685102e+13            ZIP_95113
# 145  9.974841e+13            ZIP_95116
# 146  7.974564e+13            ZIP_95117
# 147  8.829678e+13            ZIP_95118
# 148  4.384075e+13            ZIP_95119
# 149  5.368708e+13            ZIP_95120
# 150  6.294490e+13            ZIP_95121
# 151  1.089122e+14            ZIP_95122
# 152  1.462668e+14            ZIP_95123
# 153  1.396114e+14            ZIP_95124
# 154  1.383272e+14            ZIP_95125
# 155  1.044320e+14            ZIP_95126
# 156  1.396114e+14            ZIP_95127
# 157  1.396114e+14            ZIP_95128
# 158  1.132132e+14            ZIP_95129
# 159  9.608437e+13            ZIP_95130
# 160  5.587755e+13            ZIP_95131
# 161  1.061345e+14            ZIP_95132
# 162  6.574075e+13            ZIP_95133
# 163  4.101053e+13            ZIP_95134
# 164  5.798508e+13            ZIP_95135
# 165  6.389051e+13            ZIP_95136
# 166  4.518931e+13            ZIP_95138
# 167  3.796955e+13            ZIP_95139
# 168  5.901053e+13            ZIP_95148
# 169  1.096273e+13            ZIP_95391

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":zip_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.714785983235428
# Root Mean Squared Error: 94969.29942411854
# Alpha: 0.005
#      Coefficients              Feature
# 0     -112.446912                 BEDS
# 1       24.609894                BATHS
# 2      786.956097          SQUARE FEET
# 3       54.822379             LOT SIZE
# 4      -58.744433           YEAR BUILT
# 5      -65.685207            HOA/MONTH
# 6        0.000000                  LOT
# 7      -32.216921                  HOA
# 8       -4.626358  PROPERTY TYPE_Condo
# 9       -0.617695    PROPERTY TYPE_SFH
# 10       6.352478     PROPERTY TYPE_TH
# 11      23.782947            ZIP_94002
# 12     -18.846113            ZIP_94005
# 13     100.955246            ZIP_94010
# 14     -27.161810            ZIP_94014
# 15     -23.339921            ZIP_94015
# 16     -20.233665            ZIP_94018
# 17     -50.669087            ZIP_94019
# 18     -14.657490            ZIP_94020
# 19      -7.053761            ZIP_94021
# 20     152.389985            ZIP_94022
# 21     110.908090            ZIP_94024
# 22     123.719046            ZIP_94025
# 23     291.661972            ZIP_94027
# 24      82.995661            ZIP_94028
# 25      12.650837            ZIP_94030
# 26     -20.183011            ZIP_94037
# 27     -14.846340            ZIP_94038
# 28      44.446566            ZIP_94040
# 29      24.735068            ZIP_94041
# 30      32.995531            ZIP_94043
# 31     -25.734562            ZIP_94044
# 32      -7.431646            ZIP_94060
# 33      23.724557            ZIP_94061
# 34     117.635315            ZIP_94062
# 35      -2.630144            ZIP_94063
# 36      15.710642            ZIP_94065
# 37     -16.841397            ZIP_94066
# 38      43.530430            ZIP_94070
# 39     -10.783288            ZIP_94074
# 40     -25.373118            ZIP_94080
# 41      13.142921            ZIP_94085
# 42      21.589648            ZIP_94086
# 43      53.328945            ZIP_94087
# 44      20.872560            ZIP_94089
# 45      -0.978147            ZIP_94102
# 46      -3.749700            ZIP_94103
# 47       7.396814            ZIP_94105
# 48       6.285956            ZIP_94107
# 49      10.204176            ZIP_94109
# 50      17.857539            ZIP_94110
# 51      -1.473075            ZIP_94111
# 52     -12.260080            ZIP_94112
# 53      27.773622            ZIP_94114
# 54       5.714158            ZIP_94115
# 55       1.306996            ZIP_94116
# 56      11.184714            ZIP_94117
# 57      25.196840            ZIP_94118
# 58       1.358314            ZIP_94121
# 59      -1.258036            ZIP_94122
# 60      46.889077            ZIP_94123
# 61     -10.268274            ZIP_94124
# 62       8.335743            ZIP_94127
# 63      21.963685            ZIP_94131
# 64       0.042982            ZIP_94132
# 65  -30030.234795            ZIP_94133
# 66      -6.422065            ZIP_94134
# 67     157.970551            ZIP_94301
# 68      37.053915            ZIP_94303
# 69      23.250503            ZIP_94304
# 70      -0.701434            ZIP_94305
# 71     105.432343            ZIP_94306
# 72       3.128725            ZIP_94401
# 73      34.942724            ZIP_94402
# 74      18.046745            ZIP_94403
# 75      24.263024            ZIP_94404
# 76     -51.622173            ZIP_94501
# 77     -22.147754            ZIP_94502
# 78     -25.611919            ZIP_94536
# 79     -17.994052            ZIP_94538
# 80      -9.118609            ZIP_94539
# 81     -61.576127            ZIP_94541
# 82     -71.369166            ZIP_94542
# 83     -49.053232            ZIP_94544
# 84     -39.065513            ZIP_94545
# 85     -24.041571            ZIP_94546
# 86     -89.529021            ZIP_94550
# 87     -57.589803            ZIP_94551
# 88     -19.118346            ZIP_94552
# 89     -24.969756            ZIP_94555
# 90     -49.708069            ZIP_94560
# 91     -69.549547            ZIP_94566
# 92     -76.067969            ZIP_94568
# 93     -66.285089            ZIP_94577
# 94     -44.904293            ZIP_94578
# 95     -30.811237            ZIP_94579
# 96     -17.061222            ZIP_94580
# 97  -30030.234795            ZIP_94584
# 98      -4.046278            ZIP_94586
# 99     -66.940332            ZIP_94587
# 100    -39.362074            ZIP_94588
# 101    -30.879971            ZIP_94601
# 102    -19.565715            ZIP_94602
# 103    -38.589795            ZIP_94603
# 104    -50.565064            ZIP_94605
# 105    -20.943773            ZIP_94606
# 106    -12.736225            ZIP_94607
# 107    -16.330552            ZIP_94608
# 108     -9.300140            ZIP_94609
# 109    -12.587047            ZIP_94610
# 110    -20.881898            ZIP_94611
# 111     -4.557533            ZIP_94612
# 112     -8.638459            ZIP_94618
# 113    -27.885988            ZIP_94619
# 114    -30.525476            ZIP_94621
# 115     -9.877019            ZIP_94702
# 116    -17.342420            ZIP_94703
# 117     -2.621554            ZIP_94704
# 118    -24.247984            ZIP_94705
# 119    -14.391395            ZIP_94706
# 120    -16.497262            ZIP_94707
# 121    -27.525061            ZIP_94708
# 122     -9.456584            ZIP_94709
# 123     -2.442362            ZIP_94710
# 124     -2.782819            ZIP_94979
# 125     -3.121474            ZIP_94980
# 126     -0.962030            ZIP_95002
# 127      0.479642            ZIP_95008
# 128     61.528367            ZIP_95014
# 129   -104.659094            ZIP_95020
# 130      9.303598            ZIP_95025
# 131     30.856110            ZIP_95030
# 132     18.968770            ZIP_95032
# 133    -30.119421            ZIP_95033
# 134    -27.124134            ZIP_95035
# 135    -75.236319            ZIP_95037
# 136     -9.137283            ZIP_95046
# 137     -2.510899            ZIP_95050
# 138     22.600893            ZIP_95051
# 139      3.475734            ZIP_95054
# 140     57.669819            ZIP_95070
# 141     -8.904891            ZIP_95110
# 142     -8.723463            ZIP_95111
# 143    -14.010391            ZIP_95112
# 144      0.073692            ZIP_95113
# 145    -15.141319            ZIP_95116
# 146     -0.652414            ZIP_95117
# 147     -0.037304            ZIP_95118
# 148     -1.682783            ZIP_95119
# 149      0.055240            ZIP_95120
# 150     -6.329059            ZIP_95121
# 151    -13.057340            ZIP_95122
# 152     -5.918040            ZIP_95123
# 153      3.368461            ZIP_95124
# 154      0.256391            ZIP_95125
# 155     -5.048680            ZIP_95126
# 156    -22.150537            ZIP_95127
# 157     -2.783354            ZIP_95128
# 158     21.288819            ZIP_95129
# 159      9.997949            ZIP_95130
# 160      2.173895            ZIP_95131
# 161     -5.536008            ZIP_95132
# 162     -3.118547            ZIP_95133
# 163     -1.929466            ZIP_95134
# 164     -4.141702            ZIP_95135
# 165     -5.078195            ZIP_95136
# 166     -4.902260            ZIP_95138
# 167     -5.557791            ZIP_95139
# 168    -11.346682            ZIP_95148
# 169     -2.031355            ZIP_95391

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":zip_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7146164830124967
# Root Mean Squared Error: 644.7071412717312
# Alpha: 0.008737642000038414
#      Coefficients              Feature
# 0     -110.780028                 BEDS
# 1       11.353506                BATHS
# 2      801.314259          SQUARE FEET
# 3       52.934638             LOT SIZE
# 4      -58.830850           YEAR BUILT
# 5      -63.201966            HOA/MONTH
# 6        0.000000                  LOT
# 7      -32.901438                  HOA
# 8       -0.134651  PROPERTY TYPE_Condo
# 9        0.000000    PROPERTY TYPE_SFH
# 10       6.565889     PROPERTY TYPE_TH
# 11      42.724374            ZIP_94002
# 12      -6.267621            ZIP_94005
# 13     123.917801            ZIP_94010
# 14      -9.813043            ZIP_94014
# 15      -1.654568            ZIP_94015
# 16     -10.707746            ZIP_94018
# 17     -28.662591            ZIP_94019
# 18      -6.017762            ZIP_94020
# 19      -3.515715            ZIP_94021
# 20     171.064914            ZIP_94022
# 21     126.581911            ZIP_94024
# 22     147.907775            ZIP_94025
# 23     303.458286            ZIP_94027
# 24      95.265028            ZIP_94028
# 25      28.785322            ZIP_94030
# 26      -9.344066            ZIP_94037
# 27      -5.200009            ZIP_94038
# 28      56.899413            ZIP_94040
# 29      31.077844            ZIP_94041
# 30      47.353923            ZIP_94043
# 31      -2.359752            ZIP_94044
# 32      -0.934318            ZIP_94060
# 33      42.630851            ZIP_94061
# 34     136.782687            ZIP_94062
# 35       7.668899            ZIP_94063
# 36      22.652027            ZIP_94065
# 37       0.863387            ZIP_94066
# 38      66.619091            ZIP_94070
# 39      -7.133792            ZIP_94074
# 40      -1.981239            ZIP_94080
# 41      23.452493            ZIP_94085
# 42      32.338598            ZIP_94086
# 43      67.554738            ZIP_94087
# 44      25.155677            ZIP_94089
# 45       0.000000            ZIP_94102
# 46      -0.767469            ZIP_94103
# 47       6.984969            ZIP_94105
# 48       7.760130            ZIP_94107
# 49      10.834798            ZIP_94109
# 50      23.381760            ZIP_94110
# 51      -0.000000            ZIP_94111
# 52      -0.281815            ZIP_94112
# 53      31.889020            ZIP_94114
# 54       7.138658            ZIP_94115
# 55       7.132196            ZIP_94116
# 56      12.805152            ZIP_94117
# 57      27.226302            ZIP_94118
# 58       4.125971            ZIP_94121
# 59       3.710760            ZIP_94122
# 60      48.900319            ZIP_94123
# 61      -2.769744            ZIP_94124
# 62      13.705099            ZIP_94127
# 63      28.620054            ZIP_94131
# 64       3.494864            ZIP_94132
# 65      -0.000000            ZIP_94133
# 66       0.000000            ZIP_94134
# 67     168.346549            ZIP_94301
# 68      57.188353            ZIP_94303
# 69      24.492682            ZIP_94304
# 70       0.000000            ZIP_94305
# 71     118.743221            ZIP_94306
# 72      18.189911            ZIP_94401
# 73      50.775610            ZIP_94402
# 74      35.913390            ZIP_94403
# 75      42.525194            ZIP_94404
# 76     -28.285990            ZIP_94501
# 77      -7.296583            ZIP_94502
# 78      -6.162274            ZIP_94536
# 79      -0.000000            ZIP_94538
# 80       5.412351            ZIP_94539
# 81     -41.956959            ZIP_94541
# 82     -59.854277            ZIP_94542
# 83     -31.031597            ZIP_94544
# 84     -24.487731            ZIP_94545
# 85     -16.206225            ZIP_94546
# 86     -66.486070            ZIP_94550
# 87     -35.925211            ZIP_94551
# 88     -13.625933            ZIP_94552
# 89      -9.210276            ZIP_94555
# 90     -24.817190            ZIP_94560
# 91     -48.645374            ZIP_94566
# 92     -54.258677            ZIP_94568
# 93     -46.381742            ZIP_94577
# 94     -29.362832            ZIP_94578
# 95     -19.024912            ZIP_94579
# 96      -8.670001            ZIP_94580
# 97      -0.000000            ZIP_94584
# 98      -1.170080            ZIP_94586
# 99     -42.250098            ZIP_94587
# 100    -20.123841            ZIP_94588
# 101    -21.337268            ZIP_94601
# 102     -9.256878            ZIP_94602
# 103    -26.573262            ZIP_94603
# 104    -35.975364            ZIP_94605
# 105    -13.281074            ZIP_94606
# 106     -6.512216            ZIP_94607
# 107     -4.462676            ZIP_94608
# 108     -2.124963            ZIP_94609
# 109     -0.449913            ZIP_94610
# 110     -3.129010            ZIP_94611
# 111     -0.308681            ZIP_94612
# 112     -1.376265            ZIP_94618
# 113    -16.700918            ZIP_94619
# 114    -21.036599            ZIP_94621
# 115      0.401889            ZIP_94702
# 116     -6.309398            ZIP_94703
# 117      0.164537            ZIP_94704
# 118    -13.259693            ZIP_94705
# 119      0.000000            ZIP_94706
# 120     -4.421171            ZIP_94707
# 121    -15.620448            ZIP_94708
# 122     -3.457769            ZIP_94709
# 123      2.425536            ZIP_94710
# 124     -0.686839            ZIP_94979
# 125     -0.907104            ZIP_94980
# 126      0.000000            ZIP_95002
# 127     20.633174            ZIP_95008
# 128     81.249088            ZIP_95014
# 129    -77.588738            ZIP_95020
# 130      8.985022            ZIP_95025
# 131     45.151439            ZIP_95030
# 132     35.008676            ZIP_95032
# 133    -17.955275            ZIP_95033
# 134     -1.462352            ZIP_95035
# 135    -50.889649            ZIP_95037
# 136     -4.650625            ZIP_95046
# 137     12.139839            ZIP_95050
# 138     37.477217            ZIP_95051
# 139     10.845390            ZIP_95054
# 140     76.932981            ZIP_95070
# 141     -0.000000            ZIP_95110
# 142     -0.102017            ZIP_95111
# 143     -3.367071            ZIP_95112
# 144      0.541409            ZIP_95113
# 145     -5.780346            ZIP_95116
# 146      4.498621            ZIP_95117
# 147      5.712835            ZIP_95118
# 148      0.532095            ZIP_95119
# 149      3.142296            ZIP_95120
# 150     -0.000000            ZIP_95121
# 151     -2.911264            ZIP_95122
# 152      3.939403            ZIP_95123
# 153     13.426766            ZIP_95124
# 154     10.051373            ZIP_95125
# 155      1.878398            ZIP_95126
# 156     -9.505602            ZIP_95127
# 157      7.006917            ZIP_95128
# 158     29.231862            ZIP_95129
# 159     16.801244            ZIP_95130
# 160      5.285708            ZIP_95131
# 161      1.764492            ZIP_95132
# 162      0.589568            ZIP_95133
# 163      0.000000            ZIP_95134
# 164      0.000000            ZIP_95135
# 165      0.000000            ZIP_95136
# 166     -0.000000            ZIP_95138
# 167     -0.911246            ZIP_95139
# 168     -5.144246            ZIP_95148
# 169     -0.000000            ZIP_95391

# %% [markdown]
# # 3.3 Keep all location info

# %%
X_train, X_test, y_train, y_test = split(df_X, df_y, 0.2, 42)
linear_coef = linear_regression(X_train, X_test, y_train, y_test)
coefficients = pd.DataFrame({"Feature":df_col,"Coefficients":np.transpose(linear_coef)})
print(coefficients.to_string())
# Out:
# Simple Linear Regression
# R^2: 0.729749579356009
# Root Mean Squared Error: 3505353926924246.0
#      Coefficients                   Feature
# 0   -9.164715e+01                      BEDS
# 1    3.966209e+00                     BATHS
# 2    7.596230e+02               SQUARE FEET
# 3    4.876433e+01                  LOT SIZE
# 4   -5.183713e+01                YEAR BUILT
# 5   -6.801736e+01                 HOA/MONTH
# 6   -5.337201e+14                       LOT
# 7   -3.340126e+01                       HOA
# 8   -8.687974e+14       PROPERTY TYPE_Condo
# 9   -1.077543e+15         PROPERTY TYPE_SFH
# 10  -7.217960e+14          PROPERTY TYPE_TH
# 11   2.975133e+15              CITY_ALAMEDA
# 12  -6.936487e+14               CITY_ALBANY
# 13   3.407825e+14             CITY_ATHERTON
# 14   1.906112e+15              CITY_BELMONT
# 15  -1.140348e+15             CITY_BERKELEY
# 16  -1.809380e+15             CITY_BRISBANE
# 17   7.833172e+13            CITY_BROADMOOR
# 18  -2.099246e+15           CITY_BURLINGAME
# 19  -2.227255e+15             CITY_CAMPBELL
# 20   1.710631e+13        CITY_CASTRO VALLEY
# 21   2.476376e+14                CITY_COLMA
# 22  -1.713057e+14            CITY_CUPERTINO
# 23   1.542445e+15            CITY_DALY CITY
# 24   7.630521e+14               CITY_DUBLIN
# 25  -3.449281e+15       CITY_EAST PALO ALTO
# 26   2.726610e+14           CITY_EL GRANADA
# 27   6.629441e+13        CITY_EMERALD HILLS
# 28  -3.461685e+14           CITY_EMERYVILLE
# 29  -6.154352e+14          CITY_FOSTER CITY
# 30   5.296808e+14              CITY_FREMONT
# 31  -4.670248e+14               CITY_GILROY
# 32   4.445698e+14        CITY_HALF MOON BAY
# 33   7.348415e+13              CITY_HAYWARD
# 34  -1.693737e+15         CITY_HILLSBOROUGH
# 35   1.146848e+15             CITY_LA HONDA
# 36   4.942036e+14            CITY_LIVERMORE
# 37  -1.858439e+15             CITY_LOMA MAR
# 38   1.357586e+14            CITY_LOS ALTOS
# 39   9.549666e+13      CITY_LOS ALTOS HILLS
# 40   3.191716e+14            CITY_LOS GATOS
# 41   6.693738e+14           CITY_MENLO PARK
# 42   9.909722e+14             CITY_MILLBRAE
# 43   2.374553e+15             CITY_MILPITAS
# 44  -1.760684e+15              CITY_MONTARA
# 45   1.414405e+14         CITY_MONTE SERENO
# 46  -2.417573e+15          CITY_MORGAN HILL
# 47   2.008260e+15           CITY_MOSS BEACH
# 48   1.738808e+15        CITY_MOUNTAIN VIEW
# 49  -1.636932e+15               CITY_NEWARK
# 50  -1.374818e+15              CITY_OAKLAND
# 51  -7.269862e+14             CITY_PACIFICA
# 52  -3.600238e+15            CITY_PALO ALTO
# 53  -7.757096e+14            CITY_PESCADERO
# 54  -7.554562e+14             CITY_PIEDMONT
# 55   4.464539e+14           CITY_PLEASANTON
# 56   3.602300e+14       CITY_PORTOLA VALLEY
# 57   6.577378e+14         CITY_REDWOOD CITY
# 58  -4.897796e+15            CITY_SAN BRUNO
# 59   1.371602e+15           CITY_SAN CARLOS
# 60  -4.985267e+15        CITY_SAN FRANCISCO
# 61  -1.568903e+14         CITY_SAN GREGORIO
# 62   1.068104e+15             CITY_SAN JOSE
# 63   4.297015e+14          CITY_SAN LEANDRO
# 64   1.149075e+14          CITY_SAN LORENZO
# 65   4.939568e+14           CITY_SAN MARTIN
# 66  -1.038921e+15            CITY_SAN MATEO
# 67   8.236458e+14          CITY_SANTA CLARA
# 68  -2.871894e+15             CITY_SARATOGA
# 69  -2.144644e+14  CITY_SOUTH SAN FRANCISCO
# 70  -2.062658e+14             CITY_STANFORD
# 71   1.150111e+15            CITY_SUNNYVALE
# 72   3.348178e+13                CITY_SUNOL
# 73  -9.752644e+14           CITY_UNION CITY
# 74   3.256176e+14             CITY_WOODSIDE
# 75  -1.656033e+15                 ZIP_94002
# 76   1.949853e+15                 ZIP_94005
# 77   2.986876e+15                 ZIP_94010
# 78  -7.822437e+14                 ZIP_94014
# 79  -9.796068e+14                 ZIP_94015
# 80  -8.745202e+13                 ZIP_94018
# 81  -2.254072e+14                 ZIP_94019
# 82  -1.057734e+15                 ZIP_94020
# 83   1.885965e+15                 ZIP_94021
# 84   7.062678e+14                 ZIP_94022
# 85   5.948933e+14                 ZIP_94024
# 86  -3.541066e+14                 ZIP_94025
# 87  -1.829302e+14                 ZIP_94027
# 88  -1.927563e+14                 ZIP_94028
# 89  -7.729069e+14                 ZIP_94030
# 90   1.877817e+15                 ZIP_94037
# 91  -1.905394e+15                 ZIP_94038
# 92  -5.011664e+14                 ZIP_94040
# 93  -2.737438e+14                 ZIP_94041
# 94  -5.665026e+14                 ZIP_94043
# 95   9.987355e+14                 ZIP_94044
# 96   8.362025e+14                 ZIP_94060
# 97  -2.147941e+14                 ZIP_94061
# 98  -2.208958e+14                 ZIP_94062
# 99  -1.254023e+14                 ZIP_94063
# 100 -8.852235e+13                 ZIP_94065
# 101  5.133490e+15                 ZIP_94066
# 102 -1.069210e+15                 ZIP_94070
# 103  1.820179e+14                 ZIP_94074
# 104  4.894458e+14                 ZIP_94080
# 105 -8.810039e+13                 ZIP_94085
# 106 -9.181895e+13                 ZIP_94086
# 107 -1.138575e+14                 ZIP_94087
# 108 -3.971177e+13                 ZIP_94089
# 109  2.892709e+14                 ZIP_94102
# 110  2.505199e+14                 ZIP_94103
# 111  1.446422e+14                 ZIP_94105
# 112  4.573350e+14                 ZIP_94107
# 113  3.234097e+14                 ZIP_94109
# 114  1.062026e+15                 ZIP_94110
# 115  1.446422e+14                 ZIP_94111
# 116  1.695555e+15                 ZIP_94112
# 117  8.429708e+14                 ZIP_94114
# 118  4.573350e+14                 ZIP_94115
# 119  1.146960e+15                 ZIP_94116
# 120  5.214180e+14                 ZIP_94117
# 121  5.600754e+14                 ZIP_94118
# 122  6.782115e+14                 ZIP_94121
# 123  1.021999e+15                 ZIP_94122
# 124  5.009699e+14                 ZIP_94123
# 125  9.803276e+14                 ZIP_94124
# 126  1.091078e+15                 ZIP_94127
# 127  1.251203e+15                 ZIP_94131
# 128  7.512804e+14                 ZIP_94132
# 129  4.089139e+14                 ZIP_94133
# 130  1.062026e+15                 ZIP_94134
# 131  2.331402e+15                 ZIP_94301
# 132  4.402223e+15                 ZIP_94303
# 133  5.274925e+14                 ZIP_94304
# 134  2.815992e+14                 ZIP_94305
# 135  2.972471e+15                 ZIP_94306
# 136  7.723929e+14                 ZIP_94401
# 137  7.916723e+14                 ZIP_94402
# 138  8.729341e+14                 ZIP_94403
# 139  9.019975e+14                 ZIP_94404
# 140 -3.840429e+15                 ZIP_94501
# 141 -2.287086e+15                 ZIP_94502
# 142 -1.299602e+15                 ZIP_94536
# 143 -1.190274e+15                 ZIP_94538
# 144 -1.157581e+15                 ZIP_94539
# 145 -1.078303e+15                 ZIP_94541
# 146 -6.267602e+14                 ZIP_94542
# 147 -9.779346e+14                 ZIP_94544
# 148 -7.649698e+14                 ZIP_94545
# 149 -3.861551e+14                 ZIP_94546
# 150 -1.607106e+15                 ZIP_94550
# 151 -1.469172e+15                 ZIP_94551
# 152 -2.489108e+14                 ZIP_94552
# 153 -1.034723e+15                 ZIP_94555
# 154  3.273742e+14                 ZIP_94560
# 155 -1.467737e+15                 ZIP_94566
# 156 -1.920277e+15                 ZIP_94568
# 157 -1.381783e+15                 ZIP_94577
# 158 -1.047067e+15                 ZIP_94578
# 159 -7.562572e+14                 ZIP_94579
# 160 -5.061749e+14                 ZIP_94580
# 161  1.526955e+15                 ZIP_94584
# 162 -1.460731e+14                 ZIP_94586
# 163 -3.439316e+14                 ZIP_94587
# 164 -1.302864e+15                 ZIP_94588
# 165 -8.957975e+13                 ZIP_94601
# 166 -9.665484e+13                 ZIP_94602
# 167 -1.160853e+14                 ZIP_94603
# 168 -1.444614e+14                 ZIP_94605
# 169 -6.874183e+13                 ZIP_94606
# 170 -5.236926e+13                 ZIP_94607
# 171 -1.156805e+14                 ZIP_94608
# 172 -6.225706e+13                 ZIP_94609
# 173 -1.196658e+14                 ZIP_94610
# 174 -1.807702e+14                 ZIP_94611
# 175 -2.382910e+13                 ZIP_94612
# 176 -6.593894e+13                 ZIP_94618
# 177 -1.059363e+14                 ZIP_94619
# 178 -8.745202e+13                 ZIP_94621
# 179 -1.261470e+14                 ZIP_94702
# 180 -1.050455e+14                 ZIP_94703
# 181 -4.664249e+13                 ZIP_94704
# 182 -1.068195e+14                 ZIP_94705
# 183 -1.638041e+14                 ZIP_94706
# 184 -1.180881e+14                 ZIP_94707
# 185 -1.144573e+14                 ZIP_94708
# 186 -5.236926e+13                 ZIP_94709
# 187 -6.735505e+13                 ZIP_94710
# 188 -6.595759e+13                 ZIP_94979
# 189  1.999048e+13                 ZIP_94980
# 190  2.301272e+13                 ZIP_95002
# 191  3.127787e+15                 ZIP_95008
# 192  1.039309e+15                 ZIP_95014
# 193  1.558744e+15                 ZIP_95020
# 194 -1.275526e+13                 ZIP_95025
# 195  4.506335e+14                 ZIP_95030
# 196  4.950878e+14                 ZIP_95032
# 197  3.065511e+14                 ZIP_95033
# 198 -1.363654e+15                 ZIP_95035
# 199  3.390867e+15                 ZIP_95037
# 200 -3.690440e+14                 ZIP_95046
# 201  1.376206e+14                 ZIP_95050
# 202  1.378243e+14                 ZIP_95051
# 203  7.482039e+13                 ZIP_95054
# 204  3.741476e+15                 ZIP_95070
# 205  1.272630e+14                 ZIP_95110
# 206  1.102523e+14                 ZIP_95111
# 207  1.409957e+14                 ZIP_95112
# 208  3.254339e+13                 ZIP_95113
# 209  1.208949e+14                 ZIP_95116
# 210  9.665157e+13                 ZIP_95117
# 211  1.070155e+14                 ZIP_95118
# 212  5.313491e+13                 ZIP_95119
# 213  6.506864e+13                 ZIP_95120
# 214  7.628911e+13                 ZIP_95121
# 215  1.320014e+14                 ZIP_95122
# 216  1.772750e+14                 ZIP_95123
# 217  1.692088e+14                 ZIP_95124
# 218  1.676523e+14                 ZIP_95125
# 219  1.265714e+14                 ZIP_95126
# 220  1.692088e+14                 ZIP_95127
# 221  1.692088e+14                 ZIP_95128
# 222  1.372142e+14                 ZIP_95129
# 223  1.164541e+14                 ZIP_95130
# 224  6.772349e+13                 ZIP_95131
# 225  1.286349e+14                 ZIP_95132
# 226  7.967767e+13                 ZIP_95133
# 227  4.970469e+13                 ZIP_95134
# 228  7.027781e+13                 ZIP_95135
# 229  7.743518e+13                 ZIP_95136
# 230  5.476936e+13                 ZIP_95138
# 231  4.601903e+13                 ZIP_95139
# 232  7.152066e+13                 ZIP_95148
# 233 -6.595759e+13                 ZIP_95391
# 234  3.673139e+15            COUNTY_ALAMEDA
# 235  1.017655e+15      COUNTY_SAN FRANCISCO
# 236 -1.576411e+15          COUNTY_SAN MATEO
# 237 -3.791565e+15        COUNTY_SANTA CLARA

# %%
ridge_coef=ridge(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":df_col,"Coefficients":np.transpose(ridge_coef)})
print(coefficients.to_string())
# Out:
# Ridge
# R^2: 0.7304875652379814
# Root Mean Squared Error: 102539.55302553985
# Alpha: 0.005
#      Coefficients                   Feature
# 0     -101.056738                      BEDS
# 1       22.244475                     BATHS
# 2      748.487517               SQUARE FEET
# 3       48.931907                  LOT SIZE
# 4      -51.285160                YEAR BUILT
# 5      -66.435573                 HOA/MONTH
# 6        0.000000                       LOT
# 7      -27.196459                       HOA
# 8       -7.330644       PROPERTY TYPE_Condo
# 9        2.814905         PROPERTY TYPE_SFH
# 10       4.482230          PROPERTY TYPE_TH
# 11     -13.403181              CITY_ALAMEDA
# 12       6.691355               CITY_ALBANY
# 13     220.563868             CITY_ATHERTON
# 14       6.477242              CITY_BELMONT
# 15     -15.835281             CITY_BERKELEY
# 16     -12.680289             CITY_BRISBANE
# 17      -3.716877            CITY_BROADMOOR
# 18       7.279785           CITY_BURLINGAME
# 19      -6.546735             CITY_CAMPBELL
# 20       7.105148        CITY_CASTRO VALLEY
# 21      -2.156134                CITY_COLMA
# 22      24.358742            CITY_CUPERTINO
# 23     -25.619937            CITY_DALY CITY
# 24     -26.661957               CITY_DUBLIN
# 25     -64.798370       CITY_EAST PALO ALTO
# 26      13.407602           CITY_EL GRANADA
# 27      -4.639747        CITY_EMERALD HILLS
# 28       0.554831           CITY_EMERYVILLE
# 29       9.893121          CITY_FOSTER CITY
# 30       5.348490              CITY_FREMONT
# 31     -60.451928               CITY_GILROY
# 32      15.326520        CITY_HALF MOON BAY
# 33     -42.250373              CITY_HAYWARD
# 34      67.286270         CITY_HILLSBOROUGH
# 35      -9.429639             CITY_LA HONDA
# 36     -43.464119            CITY_LIVERMORE
# 37      -4.127758             CITY_LOMA MAR
# 38      66.537840            CITY_LOS ALTOS
# 39      60.161225      CITY_LOS ALTOS HILLS
# 40       0.677781            CITY_LOS GATOS
# 41      18.205121           CITY_MENLO PARK
# 42       1.709901             CITY_MILLBRAE
# 43     -21.762189             CITY_MILPITAS
# 44     -12.657638              CITY_MONTARA
# 45       6.020922         CITY_MONTE SERENO
# 46     -44.784593          CITY_MORGAN HILL
# 47      -9.682626           CITY_MOSS BEACH
# 48      22.487618        CITY_MOUNTAIN VIEW
# 49     -13.233323               CITY_NEWARK
# 50     -34.156284              CITY_OAKLAND
# 51     -17.369355             CITY_PACIFICA
# 52     133.692878            CITY_PALO ALTO
# 53      -4.599143            CITY_PESCADERO
# 54      18.481687             CITY_PIEDMONT
# 55     -33.730487           CITY_PLEASANTON
# 56      44.552863       CITY_PORTOLA VALLEY
# 57     -52.698745         CITY_REDWOOD CITY
# 58     -14.226891            CITY_SAN BRUNO
# 59      15.635515           CITY_SAN CARLOS
# 60       8.694405        CITY_SAN FRANCISCO
# 61      -5.739333         CITY_SAN GREGORIO
# 62     -23.622335             CITY_SAN JOSE
# 63     -16.337566          CITY_SAN LEANDRO
# 64     -23.852472          CITY_SAN LORENZO
# 65      -5.405274           CITY_SAN MARTIN
# 66       4.354462            CITY_SAN MATEO
# 67      -1.365373          CITY_SANTA CLARA
# 68      23.850472             CITY_SARATOGA
# 69     -19.680537  CITY_SOUTH SAN FRANCISCO
# 70      -0.703228             CITY_STANFORD
# 71      20.760473            CITY_SUNNYVALE
# 72      -2.887976                CITY_SUNOL
# 73     -21.499283           CITY_UNION CITY
# 74     120.767910             CITY_WOODSIDE
# 75       6.477242                 ZIP_94002
# 76     -12.680289                 ZIP_94005
# 77      46.887852                 ZIP_94010
# 78     -21.242628                 ZIP_94014
# 79     -15.446570                 ZIP_94015
# 80     -33.730646                 ZIP_94018
# 81     -79.210739                 ZIP_94019
# 82      -9.429639                 ZIP_94020
# 83      -4.127758                 ZIP_94021
# 84      75.425022                 ZIP_94022
# 85      49.228264                 ZIP_94024
# 86      93.472394                 ZIP_94025
# 87      75.553912                 ZIP_94027
# 88      34.855644                 ZIP_94028
# 89       1.709901                 ZIP_94030
# 90     -12.657638                 ZIP_94037
# 91      -9.682626                 ZIP_94038
# 92      21.530275                 ZIP_94040
# 93      12.282687                 ZIP_94041
# 94       6.588532                 ZIP_94043
# 95     -22.131389                 ZIP_94044
# 96      -4.599143                 ZIP_94060
# 97      49.134306                 ZIP_94061
# 98      50.294446                 ZIP_94062
# 99      11.590023                 ZIP_94063
# 100     26.218269                 ZIP_94065
# 101    -14.226891                 ZIP_94066
# 102     15.635515                 ZIP_94070
# 103     -5.739333                 ZIP_94074
# 104    -19.560305                 ZIP_94080
# 105     -5.542565                 ZIP_94085
# 106      2.439642                 ZIP_94086
# 107     30.001473                 ZIP_94087
# 108     12.410282                 ZIP_94089
# 109     -2.157059                 ZIP_94102
# 110     -4.838517                 ZIP_94103
# 111      6.663161                 ZIP_94105
# 112      4.042387                 ZIP_94107
# 113      9.517578                 ZIP_94109
# 114     13.274385                 ZIP_94110
# 115     -2.039683                 ZIP_94111
# 116    -20.392745                 ZIP_94112
# 117     24.495871                 ZIP_94114
# 118      3.759087                 ZIP_94115
# 119     -4.084571                 ZIP_94116
# 120      9.522901                 ZIP_94117
# 121     23.557542                 ZIP_94118
# 122     -1.501868                 ZIP_94121
# 123     -5.869179                 ZIP_94122
# 124     45.842357                 ZIP_94123
# 125    -15.161496                 ZIP_94124
# 126      3.767559                 ZIP_94127
# 127     16.664568                 ZIP_94131
# 128     -3.388026                 ZIP_94132
# 129 -32423.465350                 ZIP_94133
# 130    -11.758279                 ZIP_94134
# 131     83.731011                 ZIP_94301
# 132     34.349487                 ZIP_94303
# 133      6.463242                 ZIP_94304
# 134     -0.703228                 ZIP_94305
# 135      9.216474                 ZIP_94306
# 136     -9.132495                 ZIP_94401
# 137     24.771705                 ZIP_94402
# 138      4.326628                 ZIP_94403
# 139      3.646188                 ZIP_94404
# 140    -14.973259                 ZIP_94501
# 141     -1.019915                 ZIP_94502
# 142    -10.470153                 ZIP_94536
# 143     -4.607325                 ZIP_94538
# 144      6.034345                 ZIP_94539
# 145    -16.719137                 ZIP_94541
# 146    -43.069651                 ZIP_94542
# 147     -8.964909                 ZIP_94544
# 148     -7.681333                 ZIP_94545
# 149    -20.902640                 ZIP_94546
# 150    -32.974451                 ZIP_94550
# 151     -7.881978                 ZIP_94551
# 152    -15.018506                 ZIP_94552
# 153    -12.432564                 ZIP_94555
# 154    -13.223755                 ZIP_94560
# 155    -20.018693                 ZIP_94566
# 156    -26.971478                 ZIP_94568
# 157    -34.196102                 ZIP_94577
# 158    -21.061886                 ZIP_94578
# 159    -13.880388                 ZIP_94579
# 160     12.680923                 ZIP_94580
# 161 -32423.465350                 ZIP_94584
# 162      0.545550                 ZIP_94586
# 163    -21.468690                 ZIP_94587
# 164      2.219341                 ZIP_94588
# 165    -12.638888                 ZIP_94601
# 166      0.548135                 ZIP_94602
# 167    -15.677657                 ZIP_94603
# 168    -21.093728                 ZIP_94605
# 169     -6.749176                 ZIP_94606
# 170     -2.072951                 ZIP_94607
# 171      0.644358                 ZIP_94608
# 172      3.507102                 ZIP_94609
# 173      0.164493                 ZIP_94610
# 174     -7.168598                 ZIP_94611
# 175      0.431014                 ZIP_94612
# 176      3.149632                 ZIP_94618
# 177     -6.180194                 ZIP_94619
# 178    -13.100326                 ZIP_94621
# 179      9.798024                 ZIP_94702
# 180     -0.261193                 ZIP_94703
# 181      4.896681                 ZIP_94704
# 182     -4.785237                 ZIP_94705
# 183     -4.301776                 ZIP_94706
# 184      3.047881                 ZIP_94707
# 185     -8.200574                 ZIP_94708
# 186     -0.392598                 ZIP_94709
# 187      7.917427                 ZIP_94710
# 188     -1.294781                 ZIP_94979
# 189     -2.888308                 ZIP_94980
# 190     -1.202342                 ZIP_95002
# 191     -6.546735                 ZIP_95008
# 192     24.358742                 ZIP_95014
# 193    -60.451928                 ZIP_95020
# 194      8.093592                 ZIP_95025
# 195     21.013987                 ZIP_95030
# 196      8.843393                 ZIP_95032
# 197    -36.437917                 ZIP_95033
# 198    -21.762189                 ZIP_95035
# 199    -44.784593                 ZIP_95037
# 200     -5.405274                 ZIP_95046
# 201    -12.446048                 ZIP_95050
# 202     12.457287                 ZIP_95051
# 203     -1.954788                 ZIP_95054
# 204     23.850472                 ZIP_95070
# 205     -9.520642                 ZIP_95110
# 206     -9.580681                 ZIP_95111
# 207    -14.346585                 ZIP_95112
# 208     -0.117770                 ZIP_95113
# 209    -15.942790                 ZIP_95116
# 210     -1.063741                 ZIP_95117
# 211     -0.686646                 ZIP_95118
# 212     -2.124768                 ZIP_95119
# 213      0.150133                 ZIP_95120
# 214     -6.953416                 ZIP_95121
# 215    -14.305038                 ZIP_95122
# 216     -7.065318                 ZIP_95123
# 217      2.669908                 ZIP_95124
# 218      0.090179                 ZIP_95125
# 219     -5.438695                 ZIP_95126
# 220    -23.179772                 ZIP_95127
# 221     -3.613089                 ZIP_95128
# 222     20.841706                 ZIP_95129
# 223      9.351253                 ZIP_95130
# 224      1.715996                 ZIP_95131
# 225     -6.361062                 ZIP_95132
# 226     -3.743757                 ZIP_95133
# 227     -1.988636                 ZIP_95134
# 228     -4.185369                 ZIP_95135
# 229     -5.444476                 ZIP_95136
# 230     -4.919585                 ZIP_95138
# 231     -5.696283                 ZIP_95139
# 232    -11.474884                 ZIP_95148
# 233     -0.551865                 ZIP_95391
# 234    -85.091016            COUNTY_ALAMEDA
# 235      8.694405      COUNTY_SAN FRANCISCO
# 236     40.609025          COUNTY_SAN MATEO
# 237     42.095462        COUNTY_SANTA CLARA

# %%
lasso_coef=lasso(X_train, X_test, y_train, y_test, alpha)
coefficients = pd.DataFrame({"Feature":df_col,"Coefficients":np.transpose(lasso_coef)})
print(coefficients.to_string())
# Out:
# Lasso
# R^2: 0.7301107813287581
# Root Mean Squared Error: 633.8348203768114
# Alpha: 0.01155064850041579
#      Coefficients                   Feature
# 0      -97.611482                      BEDS
# 1       11.957595                     BATHS
# 2      762.691686               SQUARE FEET
# 3       46.417516                  LOT SIZE
# 4      -54.701831                YEAR BUILT
# 5      -62.118518                 HOA/MONTH
# 6        0.000000                       LOT
# 7      -26.358544                       HOA
# 8       -7.806785       PROPERTY TYPE_Condo
# 9        0.000000         PROPERTY TYPE_SFH
# 10       1.294893          PROPERTY TYPE_TH
# 11      -0.000000              CITY_ALAMEDA
# 12      18.132876               CITY_ALBANY
# 13     297.254187             CITY_ATHERTON
# 14       7.151117              CITY_BELMONT
# 15       3.664621             CITY_BERKELEY
# 16     -18.865349             CITY_BRISBANE
# 17      -2.639909            CITY_BROADMOOR
# 18       0.000000           CITY_BURLINGAME
# 19      -1.554021             CITY_CAMPBELL
# 20       0.000000        CITY_CASTRO VALLEY
# 21      -2.070886                CITY_COLMA
# 22      41.460785            CITY_CUPERTINO
# 23     -34.384551            CITY_DALY CITY
# 24      -8.916351               CITY_DUBLIN
# 25     -28.372392       CITY_EAST PALO ALTO
# 26      -0.000000           CITY_EL GRANADA
# 27       0.000000        CITY_EMERALD HILLS
# 28       4.872226           CITY_EMERYVILLE
# 29       6.821904          CITY_FOSTER CITY
# 30      21.670981              CITY_FREMONT
# 31    -106.885675               CITY_GILROY
# 32      -2.566476        CITY_HALF MOON BAY
# 33     -25.317582              CITY_HAYWARD
# 34      59.466636         CITY_HILLSBOROUGH
# 35     -13.879702             CITY_LA HONDA
# 36     -19.346651            CITY_LIVERMORE
# 37      -5.469049             CITY_LOMA MAR
# 38     134.448012            CITY_LOS ALTOS
# 39     106.749233      CITY_LOS ALTOS HILLS
# 40       0.000000            CITY_LOS GATOS
# 41     104.352106           CITY_MENLO PARK
# 42       3.100297             CITY_MILLBRAE
# 43     -29.467001             CITY_MILPITAS
# 44     -19.405867              CITY_MONTARA
# 45       4.344749         CITY_MONTE SERENO
# 46     -76.577926          CITY_MORGAN HILL
# 47     -14.085601           CITY_MOSS BEACH
# 48      39.946171        CITY_MOUNTAIN VIEW
# 49       0.000000               CITY_NEWARK
# 50     -12.613228              CITY_OAKLAND
# 51     -22.534862             CITY_PACIFICA
# 52     172.024599            CITY_PALO ALTO
# 53      -4.963597            CITY_PESCADERO
# 54      28.423558             CITY_PIEDMONT
# 55      -0.000000           CITY_PLEASANTON
# 56      81.591090       CITY_PORTOLA VALLEY
# 57       0.000000         CITY_REDWOOD CITY
# 58     -17.738205            CITY_SAN BRUNO
# 59      35.083377           CITY_SAN CARLOS
# 60       0.000000        CITY_SAN FRANCISCO
# 61      -8.367317         CITY_SAN GREGORIO
# 62     -27.497546             CITY_SAN JOSE
# 63     -21.678864          CITY_SAN LEANDRO
# 64      -2.077956          CITY_SAN LORENZO
# 65      -7.425827           CITY_SAN MARTIN
# 66       0.000000            CITY_SAN MATEO
# 67       0.000000          CITY_SANTA CLARA
# 68      48.769056             CITY_SARATOGA
# 69     -29.881548  CITY_SOUTH SAN FRANCISCO
# 70      -0.000000             CITY_STANFORD
# 71      21.100141            CITY_SUNNYVALE
# 72      -0.000000                CITY_SUNOL
# 73     -12.884605           CITY_UNION CITY
# 74     145.288995             CITY_WOODSIDE
# 75      10.988348                 ZIP_94002
# 76      -0.788446                 ZIP_94005
# 77      63.063403                 ZIP_94010
# 78      -8.685432                 ZIP_94014
# 79      -0.000000                 ZIP_94015
# 80     -19.791897                 ZIP_94018
# 81     -50.410298                 ZIP_94019
# 82      -0.601710                 ZIP_94020
# 83      -0.234754                 ZIP_94021
# 84      17.529573                 ZIP_94022
# 85       0.000000                 ZIP_94024
# 86      14.763452                 ZIP_94025
# 87       0.000000                 ZIP_94027
# 88       0.000000                 ZIP_94028
# 89       4.433577                 ZIP_94030
# 90      -0.675016                 ZIP_94037
# 91      -0.519505                 ZIP_94038
# 92      13.800613                 ZIP_94040
# 93       7.327975                 ZIP_94041
# 94       0.000000                 ZIP_94043
# 95      -7.395648                 ZIP_94044
# 96      -0.375932                 ZIP_94060
# 97      17.520607                 ZIP_94061
# 98      17.878670                 ZIP_94062
# 99      -3.774020                 ZIP_94063
# 100     12.038094                 ZIP_94065
# 101     -2.085655                 ZIP_94066
# 102      2.665489                 ZIP_94070
# 103     -0.190781                 ZIP_94074
# 104     -0.000000                 ZIP_94080
# 105     -0.000000                 ZIP_94085
# 106      4.867593                 ZIP_94086
# 107     33.809500                 ZIP_94087
# 108     12.775490                 ZIP_94089
# 109     -0.000000                 ZIP_94102
# 110     -2.041302                 ZIP_94103
# 111      5.444425                 ZIP_94105
# 112      3.804775                 ZIP_94107
# 113      8.654341                 ZIP_94109
# 114     15.144378                 ZIP_94110
# 115     -0.000000                 ZIP_94111
# 116    -12.950784                 ZIP_94112
# 117     25.616170                 ZIP_94114
# 118      3.380516                 ZIP_94115
# 119     -0.000000                 ZIP_94116
# 120      9.005176                 ZIP_94117
# 121     23.341608                 ZIP_94118
# 122      0.000000                 ZIP_94121
# 123     -0.665235                 ZIP_94122
# 124     45.818003                 ZIP_94123
# 125    -10.068138                 ZIP_94124
# 126      5.404736                 ZIP_94127
# 127     19.166213                 ZIP_94131
# 128     -0.000000                 ZIP_94132
# 129     -0.000000                 ZIP_94133
# 130     -6.212330                 ZIP_94134
# 131     66.081826                 ZIP_94301
# 132      0.000000                 ZIP_94303
# 133      1.077888                 ZIP_94304
# 134     -0.000000                 ZIP_94305
# 135     -9.101730                 ZIP_94306
# 136     -0.000000                 ZIP_94401
# 137     30.898780                 ZIP_94402
# 138     11.831103                 ZIP_94403
# 139     11.634345                 ZIP_94404
# 140     -0.000000                 ZIP_94501
# 141      5.719118                 ZIP_94502
# 142      0.000000                 ZIP_94536
# 143      4.442038                 ZIP_94538
# 144     14.314356                 ZIP_94539
# 145     -4.030638                 ZIP_94541
# 146    -35.550080                 ZIP_94542
# 147      0.000000                 ZIP_94544
# 148      0.000000                 ZIP_94545
# 149     -6.621201                 ZIP_94546
# 150    -23.843827                 ZIP_94550
# 151     -0.000000                 ZIP_94551
# 152     -6.123758                 ZIP_94552
# 153     -1.288122                 ZIP_94555
# 154      0.000000                 ZIP_94560
# 155    -21.028268                 ZIP_94566
# 156    -19.264444                 ZIP_94568
# 157     -6.898709                 ZIP_94577
# 158     -0.000000                 ZIP_94578
# 159      0.000000                 ZIP_94579
# 160     -0.000000                 ZIP_94580
# 161     -0.000000                 ZIP_94584
# 162     -0.000000                 ZIP_94586
# 163     -1.063518                 ZIP_94587
# 164      0.000000                 ZIP_94588
# 165     -7.290423                 ZIP_94601
# 166      2.376863                 ZIP_94602
# 167     -9.111977                 ZIP_94603
# 168    -13.518985                 ZIP_94605
# 169     -2.304647                 ZIP_94606
# 170      0.000000                 ZIP_94607
# 171      4.195434                 ZIP_94608
# 172      4.136626                 ZIP_94609
# 173      3.289606                 ZIP_94610
# 174      0.000000                 ZIP_94611
# 175      0.000000                 ZIP_94612
# 176      4.056606                 ZIP_94618
# 177     -0.016813                 ZIP_94619
# 178     -7.698410                 ZIP_94621
# 179     12.306726                 ZIP_94702
# 180      1.277376                 ZIP_94703
# 181      4.505380                 ZIP_94704
# 182     -0.000000                 ZIP_94705
# 183      0.000000                 ZIP_94706
# 184      4.853501                 ZIP_94707
# 185     -2.653435                 ZIP_94708
# 186      0.000000                 ZIP_94709
# 187      8.449189                 ZIP_94710
# 188     -0.000000                 ZIP_94979
# 189     -0.458077                 ZIP_94980
# 190     -0.000000                 ZIP_95002
# 191     -1.688618                 ZIP_95008
# 192     13.282521                 ZIP_95014
# 193     -2.674594                 ZIP_95020
# 194      3.699568                 ZIP_95025
# 195     25.790550                 ZIP_95030
# 196     13.712492                 ZIP_95032
# 197    -30.368713                 ZIP_95033
# 198     -2.924977                 ZIP_95035
# 199     -2.656304                 ZIP_95037
# 200     -0.297536                 ZIP_95046
# 201     -5.658636                 ZIP_95050
# 202     15.702980                 ZIP_95051
# 203      0.000000                 ZIP_95054
# 204      4.222274                 ZIP_95070
# 205     -3.755445                 ZIP_95110
# 206     -4.310838                 ZIP_95111
# 207     -8.242920                 ZIP_95112
# 208      0.000000                 ZIP_95113
# 209    -10.343841                 ZIP_95116
# 210      0.257155                 ZIP_95117
# 211      0.846294                 ZIP_95118
# 212     -0.000000                 ZIP_95119
# 213      0.460232                 ZIP_95120
# 214     -2.839503                 ZIP_95121
# 215     -8.350961                 ZIP_95122
# 216     -0.000000                 ZIP_95123
# 217      6.237156                 ZIP_95124
# 218      3.466204                 ZIP_95125
# 219     -0.000000                 ZIP_95126
# 220    -16.049565                 ZIP_95127
# 221      0.000000                 ZIP_95128
# 222     23.433182                 ZIP_95129
# 223     11.501862                 ZIP_95130
# 224      2.074936                 ZIP_95131
# 225     -0.426921                 ZIP_95132
# 226     -0.000000                 ZIP_95133
# 227     -0.000000                 ZIP_95134
# 228     -0.355170                 ZIP_95135
# 229     -1.096142                 ZIP_95136
# 230     -1.394947                 ZIP_95138
# 231     -2.259619                 ZIP_95139
# 232     -7.424796                 ZIP_95148
# 233      0.000000                 ZIP_95391
# 234   -187.819257            COUNTY_ALAMEDA
# 235      0.000000      COUNTY_SAN FRANCISCO
# 236      0.000000          COUNTY_SAN MATEO
# 237      0.000000        COUNTY_SANTA CLARA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32309 entries, 115 to 32415
# Data columns (total 13 columns):
# PROPERTY TYPE    32309 non-null object
# CITY             32309 non-null object
# ZIP              32309 non-null object
# PRICE IN K       32309 non-null float64
# BEDS             32309 non-null float64
# BATHS            32309 non-null float64
# SQUARE FEET      32309 non-null float64
# LOT SIZE         32309 non-null float64
# YEAR BUILT       32309 non-null float64
# HOA/MONTH        32309 non-null float64
# COUNTY           32309 non-null object
# LOT              32309 non-null int64
# HOA              32309 non-null int64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 4.7+ MB
