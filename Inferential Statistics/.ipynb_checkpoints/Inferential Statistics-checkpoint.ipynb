# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df = pd.read_csv('../Data/cleaned_data.csv', index_col=0)
df = df.dropna(subset = ['PRICE IN K', 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', '$/SQUARE FEET'])

# %%
San_mateo = df.loc[df['COUNTY'] == 'SAN MATEO']
Santa_clara = df.loc[df['COUNTY'] == 'SANTA CLARA']
Alameda = df.loc[df['COUNTY'] == 'ALAMEDA']
San_Francisco = df.loc[df['COUNTY'] == 'SAN FRANCISCO']

# %%
San_mateo_mean = San_mateo['PRICE IN K'].mean()
Santa_clara_mean = Santa_clara['PRICE IN K'].mean()
Alameda_mean = Alameda['PRICE IN K'].mean()
San_Francisco_mean = San_Francisco['PRICE IN K'].mean()
print('San_mateo_mean: ', San_mateo_mean)
print('Santa_clara_mean: ', Santa_clara_mean)
print('Alameda_mean: ', Alameda_mean)
print('San_Francisco_mean: ', San_Francisco_mean)
# Out:
# San_mateo_mean:  1662.12939606
# Santa_clara_mean:  1357.92507948
# Alameda_mean:  910.135455492
# San_Francisco_mean:  1570.3867464

# %% [markdown]
# ** House Price in Different Counties **

# %%
stats.f_oneway(San_mateo['PRICE IN K'], Alameda['PRICE IN K'], Santa_clara['PRICE IN K'], San_Francisco['PRICE IN K'])
# Out:
# F_onewayResult(statistic=701.89235869373374, pvalue=0.0)

# %%
# statistical significance
print(stats.f_oneway(San_mateo['PRICE IN K'], Alameda['PRICE IN K']))
print(stats.f_oneway(San_mateo['PRICE IN K'], Santa_clara['PRICE IN K']))
print(stats.f_oneway(San_mateo['PRICE IN K'], San_Francisco['PRICE IN K']))

print(stats.f_oneway(Santa_clara['PRICE IN K'], Alameda['PRICE IN K']))
print(stats.f_oneway(Santa_clara['PRICE IN K'], San_Francisco['PRICE IN K']))

print(stats.f_oneway(Alameda['PRICE IN K'], San_Francisco['PRICE IN K']))
# Out:
# F_onewayResult(statistic=1930.2587647738399, pvalue=0.0)
# F_onewayResult(statistic=230.07765038243699, pvalue=1.0826385977844193e-51)
# F_onewayResult(statistic=1.953198964730829, pvalue=0.16227032901717772)
# F_onewayResult(statistic=1391.8530208978918, pvalue=4.365242162292131e-295)
# F_onewayResult(statistic=22.592584529071143, pvalue=2.027774220733777e-06)
# F_onewayResult(statistic=881.69197419837133, pvalue=9.9813375495188256e-187)

# %% [markdown]
# ** Property Type & Price per Square Foot **

# %%
Single_family = df.loc[df['PROPERTY TYPE'] == 'SFH']
Condo = df.loc[df['PROPERTY TYPE'] == 'Condo']
Townhouse = df.loc[df['PROPERTY TYPE'] == 'TH']

# %%
Single_family_mean = Single_family['$/SQUARE FEET'].mean()
Condo_mean = Condo['$/SQUARE FEET'].mean()
Townhouse_mean = Townhouse['$/SQUARE FEET'].mean()
print('Single family unit price: ', Single_family_mean)
print('Condo unit price: ', Condo_mean)
print('Townhouse unit price: ', Townhouse_mean)
# Out:
# Single family unit price:  745.013722577
# Condo unit price:  660.100563119
# Townhouse unit price:  621.915805403

# %%
stats.f_oneway(Single_family['$/SQUARE FEET'], Condo['$/SQUARE FEET'], Townhouse['$/SQUARE FEET'])
# Out:
# F_onewayResult(statistic=162.84708301804633, pvalue=4.2601657309347746e-71)

# %%
print(stats.f_oneway(Condo['$/SQUARE FEET'], Townhouse['$/SQUARE FEET']))
print(stats.f_oneway(Single_family['$/SQUARE FEET'], Condo['$/SQUARE FEET']))
print(stats.f_oneway(Single_family['$/SQUARE FEET'], Townhouse['$/SQUARE FEET']))
# Out:
# F_onewayResult(statistic=46.239459342510457, pvalue=1.157077235756399e-11)
# F_onewayResult(statistic=138.20533002755874, pvalue=7.7111581388442671e-32)
# F_onewayResult(statistic=193.33679380685822, pvalue=8.2098459180176224e-44)

# %% [markdown]
# ** Single Family House: Number of Bedrooms & House Price **

# %%
# delete some outliers
Single_family = Single_family.sort_values(by='BEDS', ascending=False)

Single_family.reset_index(drop=True)
Single_family = Single_family.iloc[1:]

Single_family = Single_family.sort_values(by='BEDS')

Single_family.reset_index(drop=True)
Single_family = Single_family.iloc[8:]

# %%
x = [a for a in Single_family['BEDS']]
y = list(Single_family['PRICE IN K'])
slope, intercept = np.polyfit(x, y, deg=1)
r = np.corrcoef(x, y)[0,1]
print('Slope:' , slope)
print('Intercept: ', intercept)
print('Pearson r: ', r)
# Out:
# Slope: 521.453768484
# Intercept:  -332.141365739
# Pearson r:  0.363462429781

# %%
y_pred = [i * slope + intercept for i in x]
fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(x, y,alpha=0.2, color='green')
plt.plot(x, y_pred, linewidth=3, color='red')
ax.set_xlim([0, max(x)])
ax.set_xlabel('Number of Bedrooms', fontsize=12)
ax.set_ylabel('House Price in K', fontsize=12)
ax.set_title('Single Family House: Number of Bedrooms vs. House Price', fontsize=14)

ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ** Single Family House: Lot size & House Price **

# %%
# delete some outliers
Single_family = Single_family[Single_family['LOT SIZE'] < 1000000]
Single_family = Single_family[Single_family['LOT SIZE'] > 1000]
Single_family = Single_family[Single_family['PRICE IN K'] > 300]
Single_family = Single_family[Single_family['PRICE IN K'] < 50000]

# %%
x = [a for a in Single_family['LOT SIZE']]
y = list(Single_family['PRICE IN K'])
slope, intercept = np.polyfit(x, y, deg=1)
r = np.corrcoef(x, y)[0,1]
print('Slope:' , slope)
print('Intercept: ', intercept)
print('Pearson r: ', r)
# Out:
# Slope: 0.011323455197
# Intercept:  1322.21139055
# Pearson r:  0.289605494398

# %%
y_pred = [i * slope + intercept for i in x]
fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(x, y,alpha=0.2, color='green')
plt.plot(x, y_pred, linewidth=3, color='red')
ax.set_xlim([0, max(x)])
ax.set_xlabel('LOT SIZE', fontsize=12)
ax.set_ylabel('House Price in K', fontsize=12)
ax.set_title('Single Family House: LOT SIZE vs. House Price', fontsize=14)

ax.grid(True)
fig.tight_layout()
plt.show()

# %%
# delete more outliers
Single_family = Single_family[Single_family['LOT SIZE'] < 200000]
Single_family = Single_family[Single_family['LOT SIZE'] > 1000]
Single_family = Single_family[Single_family['PRICE IN K'] > 300]
Single_family = Single_family[Single_family['PRICE IN K'] < 10000]

# %%
x = [a for a in Single_family['LOT SIZE']]
y = list(Single_family['PRICE IN K'])
slope, intercept = np.polyfit(x, y, deg=1)
r = np.corrcoef(x, y)[0,1]
print('Slope:' , slope)
print('Intercept: ', intercept)
print('Pearson r: ', r)
# Out:
# Slope: 0.0306291812876
# Intercept:  1106.05184961
# Pearson r:  0.441411040919

# %%
y_pred = [i * slope + intercept for i in x]
fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(x, y,alpha=0.2, color='green')
plt.plot(x, y_pred, linewidth=3, color='red')
ax.set_xlim([0, max(x)])
ax.set_xlabel('LOT SIZE', fontsize=12)
ax.set_ylabel('House Price in K', fontsize=12)
ax.set_title('Single Family House: LOT SIZE vs. House Price', fontsize=14)

ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ** Other factors **

# %%
import seaborn as sns
# %matplotlib inline

# calculate the correlation matrix
corr = Single_family.corr()

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_8644b6b8_6878_11e8_a420_a860b623bdcb th {
#           font-size: 7pt;
#     }    #T_8644b6b8_6878_11e8_a420_a860b623bdcb td {
#           padding: 0em 0em;
#     }    #T_8644b6b8_6878_11e8_a420_a860b623bdcb th:hover {
#           font-size: 12pt;
#     }    #T_8644b6b8_6878_11e8_a420_a860b623bdcb tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col1 {
#             background-color:  #d94764;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col2 {
#             background-color:  #e890a1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col3 {
#             background-color:  #e3788d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col4 {
#             background-color:  #e4798e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col5 {
#             background-color:  #e88d9f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col6 {
#             background-color:  #eda7b5;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col7 {
#             background-color:  #da4966;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col8 {
#             background-color:  #e16c84;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col9 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow0_col10 {
#             background-color:  #8faed6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col2 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col3 {
#             background-color:  #c0d2e8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col4 {
#             background-color:  #a0bbdc;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col5 {
#             background-color:  #dde7f3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col6 {
#             background-color:  #eca4b3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col7 {
#             background-color:  #b0c6e2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col8 {
#             background-color:  #f3c6cf;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col9 {
#             background-color:  #de5f79;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow1_col10 {
#             background-color:  #de5b75;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col0 {
#             background-color:  #e06880;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col1 {
#             background-color:  #fae6ea;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col3 {
#             background-color:  #9eb9db;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col4 {
#             background-color:  #a4bede;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col5 {
#             background-color:  #eda6b4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col6 {
#             background-color:  #fae4e9;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col7 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col8 {
#             background-color:  #dd5a74;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col9 {
#             background-color:  #df627b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow2_col10 {
#             background-color:  #e78a9d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col1 {
#             background-color:  #d4e0ef;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col2 {
#             background-color:  #a2bcdd;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col3 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col4 {
#             background-color:  #789ece;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col5 {
#             background-color:  #f1b9c4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col6 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col7 {
#             background-color:  #d83e5d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col8 {
#             background-color:  #e88d9f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col9 {
#             background-color:  #df627b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow3_col10 {
#             background-color:  #df627b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow4_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow4_col1 {
#             background-color:  #b0c6e2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_8644b6b8_6878_11e8_a420_a860b623bdcbrow4_col2

# %%
# calculate the correlation matrix
corr = Townhouse.corr()

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_86775e68_6878_11e8_93ba_a860b623bdcb th {
#           font-size: 7pt;
#     }    #T_86775e68_6878_11e8_93ba_a860b623bdcb td {
#           padding: 0em 0em;
#     }    #T_86775e68_6878_11e8_93ba_a860b623bdcb th:hover {
#           font-size: 12pt;
#     }    #T_86775e68_6878_11e8_93ba_a860b623bdcb tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col1 {
#             background-color:  #df637c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col2 {
#             background-color:  #f0b5c1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col3 {
#             background-color:  #e7879b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col4 {
#             background-color:  #e7899c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col5 {
#             background-color:  #e57f93;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col6 {
#             background-color:  #ea9aaa;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col7 {
#             background-color:  #e0667e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col8 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col9 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow0_col10 {
#             background-color:  #94b2d8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col0 {
#             background-color:  #d8415f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col2 {
#             background-color:  #f4c9d2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col3 {
#             background-color:  #dce6f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col4 {
#             background-color:  #b2c8e3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col5 {
#             background-color:  #e993a4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col6 {
#             background-color:  #f2bfca;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col7 {
#             background-color:  #7fa3d0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col8 {
#             background-color:  #ebf1f8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col9 {
#             background-color:  #dc526e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow1_col10 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col0 {
#             background-color:  #e3788d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col1 {
#             background-color:  #eeabb8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col3 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col4 {
#             background-color:  #d3dfef;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col5 {
#             background-color:  #dc516d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col6 {
#             background-color:  #e47c91;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col7 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col8 {
#             background-color:  #df617a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col9 {
#             background-color:  #e88ea0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow2_col10 {
#             background-color:  #e16d85;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col0 {
#             background-color:  #d94261;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col1 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col2 {
#             background-color:  #ecf2f8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col3 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col4 {
#             background-color:  #a9c1e0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col5 {
#             background-color:  #e27288;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col6 {
#             background-color:  #e0e9f4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col7 {
#             background-color:  #e7899c;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col8 {
#             background-color:  #e78a9d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col9 {
#             background-color:  #eda6b4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow3_col10 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow4_col0 {
#             background-color:  #db4e6a;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow4_col1 {
#             background-color:  #bccfe7;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86775e68_6878_11e8_93ba_a860b623bdcbrow4_col2

# %%
# calculate the correlation matrix
corr = Condo.corr()

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_86a9c940_6878_11e8_b5ab_a860b623bdcb th {
#           font-size: 7pt;
#     }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcb td {
#           padding: 0em 0em;
#     }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcb th:hover {
#           font-size: 12pt;
#     }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcb tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col0 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col1 {
#             background-color:  #dc526e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col2 {
#             background-color:  #eb9ead;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col3 {
#             background-color:  #e58094;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col4 {
#             background-color:  #e68699;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col5 {
#             background-color:  #e3788d;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col6 {
#             background-color:  #f6d1d8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col7 {
#             background-color:  #da4865;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col8 {
#             background-color:  #e88ea0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col9 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow0_col10 {
#             background-color:  #82a5d1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col1 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col2 {
#             background-color:  #d1deee;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col3 {
#             background-color:  #b2c8e3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col4 {
#             background-color:  #90afd6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col5 {
#             background-color:  #e88d9f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col6 {
#             background-color:  #f3c6cf;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col7 {
#             background-color:  #95b3d8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col8 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col9 {
#             background-color:  #eeabb8;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow1_col10 {
#             background-color:  #dc5570;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col0 {
#             background-color:  #dc546f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col1 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col2 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col3 {
#             background-color:  #a9c1e0;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col4 {
#             background-color:  #9cb8db;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col5 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col6 {
#             background-color:  #e88d9f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col7 {
#             background-color:  #dc546f;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col8 {
#             background-color:  #e47a90;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col9 {
#             background-color:  #e57f93;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow2_col10 {
#             background-color:  #e06880;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col1 {
#             background-color:  #c3d4e9;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col2 {
#             background-color:  #a4bede;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col3 {
#             background-color:  #4479bb;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col4 {
#             background-color:  #87a9d3;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col5 {
#             background-color:  #e26f86;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col6 {
#             background-color:  #f5ced6;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col7 {
#             background-color:  #e78c9e;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col8 {
#             background-color:  #eda6b4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col9 {
#             background-color:  #f1b9c4;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow3_col10 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow4_col0 {
#             background-color:  #d73c5b;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow4_col1 {
#             background-color:  #9cb8db;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_86a9c940_6878_11e8_b5ab_a860b623bdcbrow4_col2
